# %%
import math
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import time
from sklearn.metrics import accuracy_score
dtype = torch.FloatTensor
os.chdir('/cloud-home/U1039935/Autosurv/autobin')
# Define the new model for binary classification
class BinaryClassifier(nn.Module):
    def __init__(self, input_n, level_2_dim, Dropout_Rate_1, Dropout_Rate_2):
        super(BinaryClassifier, self).__init__()
        self.input_n = input_n
        self.level_2_dim = level_2_dim
        self.tanh = nn.Tanh()

        # Binary classification fc layers
        self.bn_input = nn.BatchNorm1d(self.input_n)
        self.fc1 = nn.Linear(self.input_n + 4, self.level_2_dim)
        self.bn2 = nn.BatchNorm1d(self.level_2_dim)
        self.fc2 = nn.Linear(self.level_2_dim, 1)
        
        # Dropout
        self.dropout_1 = nn.Dropout(Dropout_Rate_1)
        self.dropout_2 = nn.Dropout(Dropout_Rate_2)

    def forward(self, latent_features, c1, c2, c3, c4, s_dropout=False):
        if s_dropout:
            latent_features = self.dropout_1(latent_features)
        latent_features = self.bn_input(latent_features)
        clinical_layer = torch.cat((latent_features, c1, c2, c3, c4), 1)
        hidden_layer = self.tanh(self.fc1(clinical_layer))
        if s_dropout:
            hidden_layer = self.dropout_2(hidden_layer)
        hidden_layer = self.bn2(hidden_layer)
        y_pred = torch.sigmoid(self.fc2(hidden_layer))
        
        return y_pred

def train_binary_classifier(train_x1, train_age, train_stage_i, train_stage_ii, train_race_white, train_yevent,
                            eval_x1, eval_age, eval_stage_i, eval_stage_ii, eval_race_white, eval_yevent,
                            input_n, level_2_dim, Dropout_Rate_1, Dropout_Rate_2, Learning_Rate, L2, epoch_num, patience, dtype,
                            path="saved_model/binary_classifier_checkpoint.pt"):
    net = BinaryClassifier(input_n, level_2_dim, Dropout_Rate_1, Dropout_Rate_2)

    early_stopping = EarlyStopping(patience=patience, verbose=False, path=path)

    if torch.cuda.is_available():
        net.cuda()
    opt = optim.Adam(net.parameters(), lr=Learning_Rate, weight_decay=L2)

    start_time = time.time()
    for epoch in range(epoch_num):
        net.train()
        opt.zero_grad()

        y_pred = net(train_x1, train_age, train_stage_i, train_stage_ii, train_race_white, s_dropout=True)
        loss = F.binary_cross_entropy(y_pred.squeeze(), train_yevent.squeeze())

        loss.backward()
        opt.step()

        net.eval()
        eval_y_pred = net(eval_x1, eval_age, eval_stage_i, eval_stage_ii, eval_race_white, s_dropout=False)
        eval_accuracy = accuracy_score(eval_yevent.detach().cpu().numpy(), eval_y_pred.detach().cpu().numpy().round())

        early_stopping(eval_accuracy, net)
        if early_stopping.early_stop:
            print("Early stopping, number of epochs: ", epoch)
            print('Save model of Epoch {:d}'.format(early_stopping.best_epoch_num))
            break
        if (epoch+1) % 100 == 0:
            net.eval()
            train_y_pred = net(train_x1, train_age, train_stage_i, train_stage_ii, train_race_white, s_dropout=False)
            train_accuracy = accuracy_score(train_yevent.detach().cpu().numpy(), train_y_pred.detach().cpu().numpy().round())
            print("Training Accuracy: %s," % train_accuracy, "validation Accuracy: %s." % eval_accuracy)

    print("Loading model, best epoch: %s." % early_stopping.best_epoch_num)
    net.load_state_dict(torch.load(path, map_location=torch.device('cpu')))

    net.eval()
    train_y_pred = net(train_x1, train_age, train_stage_i, train_stage_ii, train_race_white, s_dropout=False)
    train_accuracy = accuracy_score(train_yevent.detach().cpu().numpy(), train_y_pred.detach().cpu().numpy().round())

    net.eval()
    eval_y_pred = net(eval_x1, eval_age, eval_stage_i, eval_stage_ii, eval_race_white, s_dropout=False)
    eval_accuracy = accuracy_score(eval_yevent.detach().cpu().numpy(), eval_y_pred.detach().cpu().numpy().round())

    print("Final training Accuracy: %s," % train_accuracy, "final validation Accuracy: %s." % eval_accuracy)
    time_elapse = np.array(time.time() - start_time).round(2)
    print("Total time elapse: %s." % time_elapse)

    return (train_y_pred, eval_y_pred, train_accuracy, eval_accuracy, early_stopping.best_epoch_num)

# %%
start_time = time.time()

# Example of calling the function with your data (assuming the data loading and preprocessing steps are similar)
input_n = 16
level_2_dim = [8, 16, 32]
epoch_num = 500
patience = 200
Initial_Learning_Rate = [0.05, 0.01, 0.0075, 0.005, 0.0025]
L2_Lambda = [0.001, 0.00075, 0.0005, 0.00025, 0.0001]
Dropout_rate_1 = [0.1, 0.3, 0.5]
Dropout_rate_2 = [0.1, 0.3, 0.5]

best_epoch_num = 0

patient_id_train, x_train, ytime_train, yevent_train, age_train, stage_i_train, stage_ii_train, race_white_train = load_data("tune_tr_z_2omics.csv", dtype)
patient_id_valid, x_valid, ytime_valid, yevent_valid, age_valid, stage_i_valid, stage_ii_valid, race_white_valid = load_data("tune_val_z_2omics.csv", dtype)

patient_id_train_overall, x_train_overall, ytime_train_overall, yevent_train_overall, age_train_overall, stage_i_train_overall, stage_ii_train_overall, race_white_train_overall = load_data("tr_z_2omics.csv", dtype)
patient_id_test_overall, x_test_overall, ytime_test_overall, yevent_test_overall, age_test_overall, stage_i_test_overall, stage_ii_test_overall, race_white_test_overall = load_data("tes_z_2omics.csv", dtype)
opt_l2 = 0
opt_lr = 0
opt_dim = 0
opt_dr1 = 0
opt_dr2 = 0

opt_accuracy_va = float(0)
opt_accuracy_tr = float(0)
for l2 in L2_Lambda:
    for lr in Initial_Learning_Rate:
        for dim in level_2_dim:
            for dr1 in Dropout_rate_1:
                for dr2 in Dropout_rate_2:
                    _, _, accuracy_train, accuracy_valid, best_epoch_num_tune = train_binary_classifier(x_train, age_train, stage_i_train, stage_ii_train, race_white_train, yevent_train,
                                                                                                        x_valid, age_valid, stage_i_valid, stage_ii_valid, race_white_valid, yevent_valid,
                                                                                                        input_n, dim, dr1, dr2, lr, l2, epoch_num, patience, dtype,
                                                                                                        path="saved_models/binary_classifier_checkpoint_tune.pt")

                    if accuracy_valid > opt_accuracy_va:
                        opt_l2 = l2
                        opt_lr = lr
                        opt_dim = dim
                        opt_dr1 = dr1
                        opt_dr2 = dr2
                        opt_accuracy_tr = accuracy_train
                        opt_accuracy_va = accuracy_valid
                        best_epoch_num = best_epoch_num_tune
                    print("L2: %s," % l2, "LR: %s." % lr, "dim: %s," % dim, "dr1: %s," % dr1, "dr2: %s." % dr2)
                    print("Training Accuracy: %s," % accuracy_train, "validation Accuracy: %s." % accuracy_valid)

train_y_pred, test_y_pred, accuracy_train, accuracy_test, best_epoch_num_overall = train_binary_classifier(x_train_overall, age_train_overall, stage_i_train_overall, stage_ii_train_overall, race_white_train_overall, yevent_train_overall,
                                                                                                           x_test_overall, age_test_overall, stage_i_test_overall, stage_ii_test_overall, race_white_test_overall, yevent_test_overall,
                                                                                                           input_n, opt_dim, opt_dr1, opt_dr2, opt_lr, opt_l2, epoch_num, patience, dtype,
                                                                                                           path="saved_models/binary_classifier_checkpoint_overall.pt")
print("Optimal L2: %s," % opt_l2, "optimal LR: %s," % opt_lr, "optimal dim: %s," % opt_dim, "optimal dr1: %s," % opt_dr1, "optimal dr2: %s," % opt_dr2, "best epoch number in tuning: %s." % best_epoch_num)
print("Optimal training Accuracy: %s," % opt_accuracy_tr, "optimal validation Accuracy: %s." % opt_accuracy_va)
print("Testing phase: training Accuracy: %s," % accuracy_train, "testing Accuracy: %s." % accuracy_test)
end_time = time.time()
print("--- %s seconds ---" % (end_time - start_time))
# Out:
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# Training Accuracy: 0.8295964125560538, validation Accuracy: 0.7712765957446809.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# Training Accuracy: 0.8684603886397608, validation Accuracy: 0.8191489361702128.
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training Accuracy: 0.8699551569506726, validation Accuracy: 0.8191489361702128.
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training Accuracy: 0.866965620328849, validation Accuracy: 0.8138297872340425.
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# Training Accuracy: 0.8654708520179372, validation Accuracy: 0.8085106382978723.
# Loading model, best epoch: 342.
# Final training Accuracy: 0.8654708520179372, final validation Accuracy: 0.8351063829787234.
# Total time elapse: 1.75.
# L2: 0.001, LR: 0.05. dim: 8, dr1: 0.1, dr2: 0.1.
# Training Accuracy: 0.8654708520179372, validation Accuracy: 0.8351063829787234.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  226
# Save model of Epoch 27
# Loading model, best epoch: 27.
# Final training Accuracy: 0.8550074738415545, final validation Accuracy: 0.824468085106383.
# Total time elapse: 1.34.
# L2: 0.001, LR: 0.05. dim: 8, dr1: 0.1, dr2: 0.3.
# Training Accuracy: 0.8550074738415545, validation Accuracy: 0.824468085106383.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Loading model, best epoch: 500.
# Final training Accuracy: 0.8505231689088192, final validation Accuracy: 0.8191489361702128.
# Total time elapse: 17.67.
# L2: 0.001, LR: 0.05. dim: 8, dr1: 0.1, dr2: 0.5.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# Training Accuracy: 0.8535127055306427, validation Accuracy: 0.8138297872340425.
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  290
# Save model of Epoch 91
# Loading model, best epoch: 91.
# Final training Accuracy: 0.8624813153961136, final validation Accuracy: 0.8297872340425532.
# Total time elapse: 1.56.
# L2: 0.001, LR: 0.05. dim: 8, dr1: 0.3, dr2: 0.1.
# Training Accuracy: 0.8624813153961136, validation Accuracy: 0.8297872340425532.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Loading model, best epoch: 500.
# Final training Accuracy: 0.8505231689088192, final validation Accuracy: 0.8191489361702128.
# Total time elapse: 17.52.
# L2: 0.001, LR: 0.05. dim: 8, dr1: 0.3, dr2: 0.3.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Loading model, best epoch: 500.
# Final training Accuracy: 0.8505231689088192, final validation Accuracy: 0.8191489361702128.
# Total time elapse: 17.52.
# L2: 0.001, LR: 0.05. dim: 8, dr1: 0.3, dr2: 0.5.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training Accuracy: 0.8475336322869955, validation Accuracy: 0.8191489361702128.
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8138297872340425.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training Accuracy: 0.852017937219731, validation Accuracy: 0.8191489361702128.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Loading model, best epoch: 404.
# Final training Accuracy: 0.8490284005979073, final validation Accuracy: 0.824468085106383.
# Total time elapse: 2.44.
# L2: 0.001, LR: 0.05. dim: 8, dr1: 0.5, dr2: 0.1.
# Training Accuracy: 0.8490284005979073, validation Accuracy: 0.824468085106383.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Loading model, best epoch: 500.
# Final training Accuracy: 0.8505231689088192, final validation Accuracy: 0.8191489361702128.
# Total time elapse: 17.55.
# L2: 0.001, LR: 0.05. dim: 8, dr1: 0.5, dr2: 0.3.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Loading model, best epoch: 500.
# Final training Accuracy: 0.8505231689088192, final validation Accuracy: 0.8191489361702128.
# Total time elapse: 17.78.
# L2: 0.001, LR: 0.05. dim: 8, dr1: 0.5, dr2: 0.5.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# Training Accuracy: 0.8639760837070254, validation Accuracy: 0.8138297872340425.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training Accuracy: 0.8535127055306427, validation Accuracy: 0.7872340425531915.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# Training Accuracy: 0.8729446935724963, validation Accuracy: 0.7978723404255319.
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training Accuracy: 0.8699551569506726, validation Accuracy: 0.8031914893617021.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training Accuracy: 0.8579970104633782, validation Accuracy: 0.8085106382978723.
# Loading model, best epoch: 414.
# Final training Accuracy: 0.8550074738415545, final validation Accuracy: 0.8297872340425532.
# Total time elapse: 2.18.
# L2: 0.001, LR: 0.05. dim: 16, dr1: 0.1, dr2: 0.1.
# Training Accuracy: 0.8550074738415545, validation Accuracy: 0.8297872340425532.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training Accuracy: 0.8490284005979073, validation Accuracy: 0.8138297872340425.
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 20 out of 200
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Loading model, best epoch: 471.
# Final training Accuracy: 0.852017937219731, final validation Accuracy: 0.824468085106383.
# Total time elapse: 8.93.
# L2: 0.001, LR: 0.05. dim: 16, dr1: 0.1, dr2: 0.3.
# Training Accuracy: 0.852017937219731, validation Accuracy: 0.824468085106383.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Loading model, best epoch: 500.
# Final training Accuracy: 0.8505231689088192, final validation Accuracy: 0.8191489361702128.
# Total time elapse: 17.25.
# L2: 0.001, LR: 0.05. dim: 16, dr1: 0.1, dr2: 0.5.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# Training Accuracy: 0.8490284005979073, validation Accuracy: 0.8138297872340425.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training Accuracy: 0.85949177877429, validation Accuracy: 0.8085106382978723.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training Accuracy: 0.8624813153961136, validation Accuracy: 0.8191489361702128.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Loading model, best epoch: 421.
# Final training Accuracy: 0.8579970104633782, final validation Accuracy: 0.8297872340425532.
# Total time elapse: 3.24.
# L2: 0.001, LR: 0.05. dim: 16, dr1: 0.3, dr2: 0.1.
# Training Accuracy: 0.8579970104633782, validation Accuracy: 0.8297872340425532.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Loading model, best epoch: 500.
# Final training Accuracy: 0.8505231689088192, final validation Accuracy: 0.8191489361702128.
# Total time elapse: 17.5.
# L2: 0.001, LR: 0.05. dim: 16, dr1: 0.3, dr2: 0.3.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Loading model, best epoch: 500.
# Final training Accuracy: 0.8505231689088192, final validation Accuracy: 0.8191489361702128.
# Total time elapse: 17.22.
# L2: 0.001, LR: 0.05. dim: 16, dr1: 0.3, dr2: 0.5.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8071748878923767, validation Accuracy: 0.7712765957446809.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  286
# Save model of Epoch 87
# Loading model, best epoch: 87.
# Final training Accuracy: 0.8565022421524664, final validation Accuracy: 0.8297872340425532.
# Total time elapse: 3.17.
# L2: 0.001, LR: 0.05. dim: 16, dr1: 0.5, dr2: 0.1.
# Training Accuracy: 0.8565022421524664, validation Accuracy: 0.8297872340425532.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Loading model, best epoch: 500.
# Final training Accuracy: 0.8505231689088192, final validation Accuracy: 0.8191489361702128.
# Total time elapse: 17.48.
# L2: 0.001, LR: 0.05. dim: 16, dr1: 0.5, dr2: 0.3.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Loading model, best epoch: 500.
# Final training Accuracy: 0.8505231689088192, final validation Accuracy: 0.8191489361702128.
# Total time elapse: 17.86.
# L2: 0.001, LR: 0.05. dim: 16, dr1: 0.5, dr2: 0.5.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# EarlyStopping counter: 20 out of 200
# Training Accuracy: 0.8565022421524664, validation Accuracy: 0.8031914893617021.
# EarlyStopping counter: 20 out of 200
# Training Accuracy: 0.8654708520179372, validation Accuracy: 0.8085106382978723.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# Training Accuracy: 0.8759342301943199, validation Accuracy: 0.8085106382978723.
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 20 out of 200
# Training Accuracy: 0.8654708520179372, validation Accuracy: 0.7819148936170213.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# Training Accuracy: 0.8849028400597907, validation Accuracy: 0.8085106382978723.
# Loading model, best epoch: 391.
# Final training Accuracy: 0.8789237668161435, final validation Accuracy: 0.8404255319148937.
# Total time elapse: 2.91.
# L2: 0.001, LR: 0.05. dim: 32, dr1: 0.1, dr2: 0.1.
# Training Accuracy: 0.8789237668161435, validation Accuracy: 0.8404255319148937.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training Accuracy: 0.8535127055306427, validation Accuracy: 0.8191489361702128.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training Accuracy: 0.8550074738415545, validation Accuracy: 0.8031914893617021.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training Accuracy: 0.8609865470852018, validation Accuracy: 0.8085106382978723.
# Loading model, best epoch: 331.
# Final training Accuracy: 0.8639760837070254, final validation Accuracy: 0.824468085106383.
# Total time elapse: 2.46.
# L2: 0.001, LR: 0.05. dim: 32, dr1: 0.1, dr2: 0.3.
# Training Accuracy: 0.8639760837070254, validation Accuracy: 0.824468085106383.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Loading model, best epoch: 500.
# Final training Accuracy: 0.8505231689088192, final validation Accuracy: 0.8191489361702128.
# Total time elapse: 17.66.
# L2: 0.001, LR: 0.05. dim: 32, dr1: 0.1, dr2: 0.5.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training Accuracy: 0.8460388639760837, validation Accuracy: 0.8031914893617021.
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 20 out of 200
# Training Accuracy: 0.8579970104633782, validation Accuracy: 0.8191489361702128.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# Training Accuracy: 0.85949177877429, validation Accuracy: 0.8191489361702128.
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# Training Accuracy: 0.8550074738415545, validation Accuracy: 0.8085106382978723.
# Loading model, best epoch: 485.
# Final training Accuracy: 0.85949177877429, final validation Accuracy: 0.8297872340425532.
# Total time elapse: 2.54.
# L2: 0.001, LR: 0.05. dim: 32, dr1: 0.3, dr2: 0.1.
# Training Accuracy: 0.85949177877429, validation Accuracy: 0.8297872340425532.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Loading model, best epoch: 500.
# Final training Accuracy: 0.8505231689088192, final validation Accuracy: 0.8191489361702128.
# Total time elapse: 17.55.
# L2: 0.001, LR: 0.05. dim: 32, dr1: 0.3, dr2: 0.3.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Loading model, best epoch: 500.
# Final training Accuracy: 0.8505231689088192, final validation Accuracy: 0.8191489361702128.
# Total time elapse: 17.79.
# L2: 0.001, LR: 0.05. dim: 32, dr1: 0.3, dr2: 0.5.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Loading model, best epoch: 500.
# Final training Accuracy: 0.8505231689088192, final validation Accuracy: 0.8191489361702128.
# Total time elapse: 19.92.
# L2: 0.001, LR: 0.05. dim: 32, dr1: 0.5, dr2: 0.1.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Loading model, best epoch: 500.
# Final training Accuracy: 0.8505231689088192, final validation Accuracy: 0.8191489361702128.
# Total time elapse: 17.46.
# L2: 0.001, LR: 0.05. dim: 32, dr1: 0.5, dr2: 0.3.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Loading model, best epoch: 500.
# Final training Accuracy: 0.8505231689088192, final validation Accuracy: 0.8191489361702128.
# Total time elapse: 17.71.
# L2: 0.001, LR: 0.05. dim: 32, dr1: 0.5, dr2: 0.5.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training Accuracy: 0.8639760837070254, validation Accuracy: 0.8085106382978723.
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training Accuracy: 0.8684603886397608, validation Accuracy: 0.8138297872340425.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# Training Accuracy: 0.8774289985052317, validation Accuracy: 0.8297872340425532.
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  395
# Save model of Epoch 196
# Loading model, best epoch: 196.
# Final training Accuracy: 0.8729446935724963, final validation Accuracy: 0.8351063829787234.
# Total time elapse: 1.53.
# L2: 0.001, LR: 0.01. dim: 8, dr1: 0.1, dr2: 0.1.
# Training Accuracy: 0.8729446935724963, validation Accuracy: 0.8351063829787234.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# Training Accuracy: 0.852017937219731, validation Accuracy: 0.8138297872340425.
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# Training Accuracy: 0.8624813153961136, validation Accuracy: 0.824468085106383.
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training Accuracy: 0.8609865470852018, validation Accuracy: 0.8085106382978723.
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training Accuracy: 0.8654708520179372, validation Accuracy: 0.8138297872340425.
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training Accuracy: 0.866965620328849, validation Accuracy: 0.8138297872340425.
# Loading model, best epoch: 436.
# Final training Accuracy: 0.8654708520179372, final validation Accuracy: 0.8297872340425532.
# Total time elapse: 2.07.
# L2: 0.001, LR: 0.01. dim: 8, dr1: 0.1, dr2: 0.3.
# Training Accuracy: 0.8654708520179372, validation Accuracy: 0.8297872340425532.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8138297872340425.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  215
# Save model of Epoch 16
# Loading model, best epoch: 16.
# Final training Accuracy: 0.8385650224215246, final validation Accuracy: 0.824468085106383.
# Total time elapse: 0.64.
# L2: 0.001, LR: 0.01. dim: 8, dr1: 0.1, dr2: 0.5.
# Training Accuracy: 0.8385650224215246, validation Accuracy: 0.824468085106383.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training Accuracy: 0.852017937219731, validation Accuracy: 0.8085106382978723.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 20 out of 200
# Training Accuracy: 0.8550074738415545, validation Accuracy: 0.8085106382978723.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 20 out of 200
# Training Accuracy: 0.8654708520179372, validation Accuracy: 0.8138297872340425.
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training Accuracy: 0.866965620328849, validation Accuracy: 0.8191489361702128.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training Accuracy: 0.8639760837070254, validation Accuracy: 0.8191489361702128.
# Loading model, best epoch: 456.
# Final training Accuracy: 0.8714499252615845, final validation Accuracy: 0.8351063829787234.
# Total time elapse: 2.52.
# L2: 0.001, LR: 0.01. dim: 8, dr1: 0.3, dr2: 0.1.
# Training Accuracy: 0.8714499252615845, validation Accuracy: 0.8351063829787234.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8138297872340425.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8138297872340425.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 20 out of 200
# Training Accuracy: 0.85949177877429, validation Accuracy: 0.8138297872340425.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8138297872340425.
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  498
# Save model of Epoch 299
# Loading model, best epoch: 299.
# Final training Accuracy: 0.85949177877429, final validation Accuracy: 0.824468085106383.
# Total time elapse: 3.09.
# L2: 0.001, LR: 0.01. dim: 8, dr1: 0.3, dr2: 0.3.
# Training Accuracy: 0.85949177877429, validation Accuracy: 0.824468085106383.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Loading model, best epoch: 500.
# Final training Accuracy: 0.8505231689088192, final validation Accuracy: 0.8191489361702128.
# Total time elapse: 16.61.
# L2: 0.001, LR: 0.01. dim: 8, dr1: 0.3, dr2: 0.5.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# EarlyStopping counter: 20 out of 200
# Training Accuracy: 0.852017937219731, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.852017937219731, validation Accuracy: 0.8191489361702128.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training Accuracy: 0.8550074738415545, validation Accuracy: 0.8191489361702128.
# Loading model, best epoch: 407.
# Final training Accuracy: 0.8565022421524664, final validation Accuracy: 0.8297872340425532.
# Total time elapse: 7.62.
# L2: 0.001, LR: 0.01. dim: 8, dr1: 0.5, dr2: 0.1.
# Training Accuracy: 0.8565022421524664, validation Accuracy: 0.8297872340425532.
# Training Accuracy: 0.852017937219731, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.852017937219731, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8138297872340425.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Loading model, best epoch: 500.
# Final training Accuracy: 0.8505231689088192, final validation Accuracy: 0.8191489361702128.
# Total time elapse: 16.24.
# L2: 0.001, LR: 0.01. dim: 8, dr1: 0.5, dr2: 0.3.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# EarlyStopping counter: 20 out of 200
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Loading model, best epoch: 500.
# Final training Accuracy: 0.8505231689088192, final validation Accuracy: 0.8191489361702128.
# Total time elapse: 16.39.
# L2: 0.001, LR: 0.01. dim: 8, dr1: 0.5, dr2: 0.5.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# EarlyStopping counter: 20 out of 200
# Training Accuracy: 0.8609865470852018, validation Accuracy: 0.8085106382978723.
# Training Accuracy: 0.8878923766816144, validation Accuracy: 0.824468085106383.
# EarlyStopping counter: 20 out of 200
# Training Accuracy: 0.9133034379671151, validation Accuracy: 0.8191489361702128.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# Training Accuracy: 0.922272047832586, validation Accuracy: 0.8031914893617021.
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  488
# Save model of Epoch 289
# Loading model, best epoch: 289.
# Final training Accuracy: 0.8923766816143498, final validation Accuracy: 0.8404255319148937.
# Total time elapse: 3.18.
# L2: 0.001, LR: 0.01. dim: 16, dr1: 0.1, dr2: 0.1.
# Training Accuracy: 0.8923766816143498, validation Accuracy: 0.8404255319148937.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training Accuracy: 0.8624813153961136, validation Accuracy: 0.8085106382978723.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training Accuracy: 0.8565022421524664, validation Accuracy: 0.8031914893617021.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training Accuracy: 0.8624813153961136, validation Accuracy: 0.8031914893617021.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 20 out of 200
# Training Accuracy: 0.866965620328849, validation Accuracy: 0.8297872340425532.
# EarlyStopping counter: 20 out of 200
# Training Accuracy: 0.8639760837070254, validation Accuracy: 0.824468085106383.
# Loading model, best epoch: 482.
# Final training Accuracy: 0.8759342301943199, final validation Accuracy: 0.8351063829787234.
# Total time elapse: 3.14.
# L2: 0.001, LR: 0.01. dim: 16, dr1: 0.1, dr2: 0.3.
# Training Accuracy: 0.8759342301943199, validation Accuracy: 0.8351063829787234.
# EarlyStopping counter: 20 out of 200
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8138297872340425.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training Accuracy: 0.8475336322869955, validation Accuracy: 0.8138297872340425.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 20 out of 200
# Training Accuracy: 0.8490284005979073, validation Accuracy: 0.8138297872340425.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training Accuracy: 0.852017937219731, validation Accuracy: 0.8138297872340425.
# Loading model, best epoch: 489.
# Final training Accuracy: 0.8505231689088192, final validation Accuracy: 0.8191489361702128.
# Total time elapse: 4.18.
# L2: 0.001, LR: 0.01. dim: 16, dr1: 0.1, dr2: 0.5.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# Training Accuracy: 0.8535127055306427, validation Accuracy: 0.8138297872340425.
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  259
# Save model of Epoch 60
# Loading model, best epoch: 60.
# Final training Accuracy: 0.85949177877429, final validation Accuracy: 0.8297872340425532.
# Total time elapse: 1.63.
# L2: 0.001, LR: 0.01. dim: 16, dr1: 0.3, dr2: 0.1.
# Training Accuracy: 0.85949177877429, validation Accuracy: 0.8297872340425532.
# EarlyStopping counter: 20 out of 200
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8138297872340425.
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  264
# Save model of Epoch 65
# Loading model, best epoch: 65.
# Final training Accuracy: 0.8579970104633782, final validation Accuracy: 0.824468085106383.
# Total time elapse: 1.76.
# L2: 0.001, LR: 0.01. dim: 16, dr1: 0.3, dr2: 0.3.
# Training Accuracy: 0.8579970104633782, validation Accuracy: 0.824468085106383.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  217
# Save model of Epoch 18
# Loading model, best epoch: 18.
# Final training Accuracy: 0.8535127055306427, final validation Accuracy: 0.824468085106383.
# Total time elapse: 0.83.
# L2: 0.001, LR: 0.01. dim: 16, dr1: 0.3, dr2: 0.5.
# Training Accuracy: 0.8535127055306427, validation Accuracy: 0.824468085106383.
# Training Accuracy: 0.8535127055306427, validation Accuracy: 0.8085106382978723.
# Training Accuracy: 0.852017937219731, validation Accuracy: 0.8138297872340425.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.852017937219731, validation Accuracy: 0.8138297872340425.
# Loading model, best epoch: 499.
# Final training Accuracy: 0.8535127055306427, final validation Accuracy: 0.8191489361702128.
# Total time elapse: 12.88.
# L2: 0.001, LR: 0.01. dim: 16, dr1: 0.5, dr2: 0.1.
# Training Accuracy: 0.8535127055306427, validation Accuracy: 0.8191489361702128.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training Accuracy: 0.852017937219731, validation Accuracy: 0.8191489361702128.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  223
# Save model of Epoch 24
# Loading model, best epoch: 24.
# Final training Accuracy: 0.8400597907324364, final validation Accuracy: 0.824468085106383.
# Total time elapse: 0.99.
# L2: 0.001, LR: 0.01. dim: 16, dr1: 0.5, dr2: 0.3.
# Training Accuracy: 0.8400597907324364, validation Accuracy: 0.824468085106383.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Loading model, best epoch: 500.
# Final training Accuracy: 0.8505231689088192, final validation Accuracy: 0.8191489361702128.
# Total time elapse: 17.68.
# L2: 0.001, LR: 0.01. dim: 16, dr1: 0.5, dr2: 0.5.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# EarlyStopping counter: 20 out of 200
# Training Accuracy: 0.866965620328849, validation Accuracy: 0.8138297872340425.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training Accuracy: 0.905829596412556, validation Accuracy: 0.824468085106383.
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# Training Accuracy: 0.9252615844544095, validation Accuracy: 0.8191489361702128.
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  344
# Save model of Epoch 145
# Loading model, best epoch: 145.
# Final training Accuracy: 0.898355754857997, final validation Accuracy: 0.8297872340425532.
# Total time elapse: 2.26.
# L2: 0.001, LR: 0.01. dim: 32, dr1: 0.1, dr2: 0.1.
# Training Accuracy: 0.898355754857997, validation Accuracy: 0.8297872340425532.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 20 out of 200
# Training Accuracy: 0.85949177877429, validation Accuracy: 0.8085106382978723.
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# Training Accuracy: 0.8609865470852018, validation Accuracy: 0.8085106382978723.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training Accuracy: 0.8639760837070254, validation Accuracy: 0.8138297872340425.
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# Training Accuracy: 0.866965620328849, validation Accuracy: 0.8191489361702128.
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  453
# Save model of Epoch 254
# Loading model, best epoch: 254.
# Final training Accuracy: 0.866965620328849, final validation Accuracy: 0.8297872340425532.
# Total time elapse: 2.15.
# L2: 0.001, LR: 0.01. dim: 32, dr1: 0.1, dr2: 0.3.
# Training Accuracy: 0.866965620328849, validation Accuracy: 0.8297872340425532.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training Accuracy: 0.8535127055306427, validation Accuracy: 0.8085106382978723.
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# Training Accuracy: 0.8490284005979073, validation Accuracy: 0.8138297872340425.
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  240
# Save model of Epoch 41
# Loading model, best epoch: 41.
# Final training Accuracy: 0.8505231689088192, final validation Accuracy: 0.8191489361702128.
# Total time elapse: 1.01.
# L2: 0.001, LR: 0.01. dim: 32, dr1: 0.1, dr2: 0.5.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training Accuracy: 0.8699551569506726, validation Accuracy: 0.8297872340425532.
# EarlyStopping counter: 20 out of 200
# Training Accuracy: 0.8699551569506726, validation Accuracy: 0.8404255319148937.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training Accuracy: 0.8774289985052317, validation Accuracy: 0.8191489361702128.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training Accuracy: 0.866965620328849, validation Accuracy: 0.8191489361702128.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  400
# Save model of Epoch 201
# Loading model, best epoch: 201.
# Final training Accuracy: 0.8714499252615845, final validation Accuracy: 0.8404255319148937.
# Total time elapse: 2.76.
# L2: 0.001, LR: 0.01. dim: 32, dr1: 0.3, dr2: 0.1.
# Training Accuracy: 0.8714499252615845, validation Accuracy: 0.8404255319148937.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8085106382978723.
# EarlyStopping counter: 20 out of 200
# Training Accuracy: 0.8565022421524664, validation Accuracy: 0.8085106382978723.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 20 out of 200
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8138297872340425.
# Loading model, best epoch: 473.
# Final training Accuracy: 0.8505231689088192, final validation Accuracy: 0.8191489361702128.
# Total time elapse: 4.59.
# L2: 0.001, LR: 0.01. dim: 32, dr1: 0.3, dr2: 0.3.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8138297872340425.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8490284005979073, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8138297872340425.
# Loading model, best epoch: 495.
# Final training Accuracy: 0.8505231689088192, final validation Accuracy: 0.8191489361702128.
# Total time elapse: 13.69.
# L2: 0.001, LR: 0.01. dim: 32, dr1: 0.3, dr2: 0.5.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# ...
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# Training Accuracy: 0.8565022421524664, validation Accuracy: 0.8031914893617021.
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  243
# Save model of Epoch 44
# Loading model, best epoch: 44.
# Final training Accuracy: 0.8490284005979073, final validation Accuracy: 0.8351063829787234.
# Total time elapse: 1.7.
# L2: 0.0001, LR: 0.0025. dim: 16, dr1: 0.3, dr2: 0.3.
# Training Accuracy: 0.8490284005979073, validation Accuracy: 0.8351063829787234.
# EarlyStopping counter: 20 out of 200
# Training Accuracy: 0.8550074738415545, validation Accuracy: 0.8085106382978723.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# Training Accuracy: 0.852017937219731, validation Accuracy: 0.8138297872340425.
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training Accuracy: 0.852017937219731, validation Accuracy: 0.8138297872340425.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 20 out of 200
# Training Accuracy: 0.8550074738415545, validation Accuracy: 0.8085106382978723.
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 20 out of 200
# Training Accuracy: 0.8535127055306427, validation Accuracy: 0.8138297872340425.
# Loading model, best epoch: 471.
# Final training Accuracy: 0.852017937219731, final validation Accuracy: 0.8191489361702128.
# Total time elapse: 4.32.
# L2: 0.0001, LR: 0.0025. dim: 16, dr1: 0.3, dr2: 0.5.
# Training Accuracy: 0.852017937219731, validation Accuracy: 0.8191489361702128.
# EarlyStopping counter: 20 out of 200
# Training Accuracy: 0.85949177877429, validation Accuracy: 0.8138297872340425.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 20 out of 200
# Training Accuracy: 0.8535127055306427, validation Accuracy: 0.8085106382978723.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training Accuracy: 0.8535127055306427, validation Accuracy: 0.8085106382978723.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training Accuracy: 0.85949177877429, validation Accuracy: 0.8085106382978723.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  410
# Save model of Epoch 211
# Loading model, best epoch: 211.
# Final training Accuracy: 0.8535127055306427, final validation Accuracy: 0.8191489361702128.
# Total time elapse: 2.69.
# L2: 0.0001, LR: 0.0025. dim: 16, dr1: 0.5, dr2: 0.1.
# Training Accuracy: 0.8535127055306427, validation Accuracy: 0.8191489361702128.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8085106382978723.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  218
# Save model of Epoch 19
# Loading model, best epoch: 19.
# Final training Accuracy: 0.8550074738415545, final validation Accuracy: 0.8297872340425532.
# Total time elapse: 0.99.
# L2: 0.0001, LR: 0.0025. dim: 16, dr1: 0.5, dr2: 0.3.
# Training Accuracy: 0.8550074738415545, validation Accuracy: 0.8297872340425532.
# EarlyStopping counter: 20 out of 200
# Training Accuracy: 0.8490284005979073, validation Accuracy: 0.8085106382978723.
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# Training Accuracy: 0.8490284005979073, validation Accuracy: 0.8138297872340425.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training Accuracy: 0.8490284005979073, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# Loading model, best epoch: 500.
# Final training Accuracy: 0.8505231689088192, final validation Accuracy: 0.8191489361702128.
# Total time elapse: 9.64.
# L2: 0.0001, LR: 0.0025. dim: 16, dr1: 0.5, dr2: 0.5.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training Accuracy: 0.8729446935724963, validation Accuracy: 0.824468085106383.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training Accuracy: 0.8774289985052317, validation Accuracy: 0.824468085106383.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training Accuracy: 0.9147982062780269, validation Accuracy: 0.8031914893617021.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training Accuracy: 0.9312406576980568, validation Accuracy: 0.7978723404255319.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  422
# Save model of Epoch 223
# Loading model, best epoch: 223.
# Final training Accuracy: 0.8938714499252616, final validation Accuracy: 0.8297872340425532.
# Total time elapse: 1.55.
# L2: 0.0001, LR: 0.0025. dim: 32, dr1: 0.1, dr2: 0.1.
# Training Accuracy: 0.8938714499252616, validation Accuracy: 0.8297872340425532.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training Accuracy: 0.8624813153961136, validation Accuracy: 0.8085106382978723.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training Accuracy: 0.866965620328849, validation Accuracy: 0.824468085106383.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 20 out of 200
# Training Accuracy: 0.8774289985052317, validation Accuracy: 0.824468085106383.
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 20 out of 200
# Training Accuracy: 0.874439461883408, validation Accuracy: 0.8297872340425532.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# Training Accuracy: 0.8819133034379671, validation Accuracy: 0.8191489361702128.
# Loading model, best epoch: 400.
# Final training Accuracy: 0.874439461883408, final validation Accuracy: 0.8297872340425532.
# Total time elapse: 3.21.
# L2: 0.0001, LR: 0.0025. dim: 32, dr1: 0.1, dr2: 0.3.
# Training Accuracy: 0.874439461883408, validation Accuracy: 0.8297872340425532.
# EarlyStopping counter: 20 out of 200
# Training Accuracy: 0.8535127055306427, validation Accuracy: 0.8085106382978723.
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# Training Accuracy: 0.8579970104633782, validation Accuracy: 0.8031914893617021.
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  263
# Save model of Epoch 64
# Loading model, best epoch: 64.
# Final training Accuracy: 0.8430493273542601, final validation Accuracy: 0.8297872340425532.
# Total time elapse: 1.63.
# L2: 0.0001, LR: 0.0025. dim: 32, dr1: 0.1, dr2: 0.5.
# Training Accuracy: 0.8430493273542601, validation Accuracy: 0.8297872340425532.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# Training Accuracy: 0.8639760837070254, validation Accuracy: 0.8138297872340425.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# Training Accuracy: 0.8714499252615845, validation Accuracy: 0.8191489361702128.
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# Training Accuracy: 0.8684603886397608, validation Accuracy: 0.8138297872340425.
# EarlyStopping counter: 20 out of 200
# Training Accuracy: 0.8834080717488789, validation Accuracy: 0.824468085106383.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# Training Accuracy: 0.8938714499252616, validation Accuracy: 0.8138297872340425.
# Loading model, best epoch: 399.
# Final training Accuracy: 0.8849028400597907, final validation Accuracy: 0.8297872340425532.
# Total time elapse: 3.1.
# L2: 0.0001, LR: 0.0025. dim: 32, dr1: 0.3, dr2: 0.1.
# Training Accuracy: 0.8849028400597907, validation Accuracy: 0.8297872340425532.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training Accuracy: 0.8565022421524664, validation Accuracy: 0.8031914893617021.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training Accuracy: 0.8639760837070254, validation Accuracy: 0.8085106382978723.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  224
# Save model of Epoch 25
# Loading model, best epoch: 25.
# Final training Accuracy: 0.8355754857997011, final validation Accuracy: 0.8404255319148937.
# Total time elapse: 1.35.
# L2: 0.0001, LR: 0.0025. dim: 32, dr1: 0.3, dr2: 0.3.
# Training Accuracy: 0.8355754857997011, validation Accuracy: 0.8404255319148937.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training Accuracy: 0.8579970104633782, validation Accuracy: 0.8085106382978723.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# Training Accuracy: 0.8535127055306427, validation Accuracy: 0.8085106382978723.
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  281
# Save model of Epoch 82
# Loading model, best epoch: 82.
# Final training Accuracy: 0.85949177877429, final validation Accuracy: 0.8191489361702128.
# Total time elapse: 1.19.
# L2: 0.0001, LR: 0.0025. dim: 32, dr1: 0.3, dr2: 0.5.
# Training Accuracy: 0.85949177877429, validation Accuracy: 0.8191489361702128.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training Accuracy: 0.8579970104633782, validation Accuracy: 0.8138297872340425.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training Accuracy: 0.8624813153961136, validation Accuracy: 0.824468085106383.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training Accuracy: 0.8579970104633782, validation Accuracy: 0.8191489361702128.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 20 out of 200
# Training Accuracy: 0.8684603886397608, validation Accuracy: 0.8191489361702128.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 20 out of 200
# Training Accuracy: 0.8624813153961136, validation Accuracy: 0.8138297872340425.
# Loading model, best epoch: 464.
# Final training Accuracy: 0.8624813153961136, final validation Accuracy: 0.824468085106383.
# Total time elapse: 3.23.
# L2: 0.0001, LR: 0.0025. dim: 32, dr1: 0.5, dr2: 0.1.
# Training Accuracy: 0.8624813153961136, validation Accuracy: 0.824468085106383.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training Accuracy: 0.85949177877429, validation Accuracy: 0.8085106382978723.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training Accuracy: 0.8535127055306427, validation Accuracy: 0.8191489361702128.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  219
# Save model of Epoch 20
# Loading model, best epoch: 20.
# Final training Accuracy: 0.8505231689088192, final validation Accuracy: 0.8351063829787234.
# Total time elapse: 1.15.
# L2: 0.0001, LR: 0.0025. dim: 32, dr1: 0.5, dr2: 0.3.
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8351063829787234.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# Training Accuracy: 0.8505231689088192, validation Accuracy: 0.8191489361702128.
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# Training Accuracy: 0.8490284005979073, validation Accuracy: 0.8138297872340425.
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  261
# Save model of Epoch 62
# Loading model, best epoch: 62.
# Final training Accuracy: 0.8624813153961136, final validation Accuracy: 0.8297872340425532.
# Total time elapse: 0.88.
# L2: 0.0001, LR: 0.0025. dim: 32, dr1: 0.5, dr2: 0.5.
# Training Accuracy: 0.8624813153961136, validation Accuracy: 0.8297872340425532.
# EarlyStopping counter: 20 out of 200
# Training Accuracy: 0.851808634772462, validation Accuracy: 0.7960199004975125.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training Accuracy: 0.8459743290548425, validation Accuracy: 0.7910447761194029.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training Accuracy: 0.8448074679113186, validation Accuracy: 0.7910447761194029.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  338
# Save model of Epoch 139
# Loading model, best epoch: 139.
# Final training Accuracy: 0.8506417736289381, final validation Accuracy: 0.8109452736318408.
# Total time elapse: 2.6.
# Optimal L2: 0.0001, optimal LR: 0.0025, optimal dim: 8, optimal dr1: 0.5, optimal dr2: 0.1, best epoch number in tuning: 27.
# Optimal training Accuracy: 0.8236173393124065, optimal validation Accuracy: 0.8563829787234043.
# Testing phase: training Accuracy: 0.8506417736289381, testing Accuracy: 0.8109452736318408.

# %%
print("--- %s seconds ---" % (end_time - start_time))

# %%
#25-30 mins
