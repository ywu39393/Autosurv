# %%
import math
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import time
from utils import load_data
import lifelines
from lifelines.utils import concordance_index
from LFSurv import BinaryClassifier
from utils import R_set, neg_par_log_likelihood, c_index, EarlyStopping

from sklearn.metrics import accuracy_score
dtype = torch.FloatTensor
os.chdir('/cloud-home/U1039935/Autosurv/autobin')
# Define the new model for binary classification
class BinaryClassifier(nn.Module):
    def __init__(self, input_n, level_2_dim, Dropout_Rate_1, Dropout_Rate_2):
        super(BinaryClassifier, self).__init__()
        self.input_n = input_n
        self.level_2_dim = level_2_dim
        self.tanh = nn.Tanh()

        # Binary classification fc layers
        self.bn_input = nn.BatchNorm1d(self.input_n)
        self.fc1 = nn.Linear(self.input_n + 4, self.level_2_dim)
        self.bn2 = nn.BatchNorm1d(self.level_2_dim)
        self.fc2 = nn.Linear(self.level_2_dim, 1)
        
        # Dropout
        self.dropout_1 = nn.Dropout(Dropout_Rate_1)
        self.dropout_2 = nn.Dropout(Dropout_Rate_2)

    def forward(self, latent_features, c1, c2, c3, c4, s_dropout=False):
        if s_dropout:
            latent_features = self.dropout_1(latent_features)
        latent_features = self.bn_input(latent_features)
        clinical_layer = torch.cat((latent_features, c1, c2, c3, c4), 1)
        hidden_layer = self.tanh(self.fc1(clinical_layer))
        if s_dropout:
            hidden_layer = self.dropout_2(hidden_layer)
        hidden_layer = self.bn2(hidden_layer)
        y_pred = torch.sigmoid(self.fc2(hidden_layer))
        
        return y_pred

# def train_binary_classifier(train_x1, train_age, train_stage_i, train_stage_ii, train_race_white, train_yevent,
#                             eval_x1, eval_age, eval_stage_i, eval_stage_ii, eval_race_white, eval_yevent,
#                             input_n, level_2_dim, Dropout_Rate_1, Dropout_Rate_2, Learning_Rate, L2, epoch_num, patience, dtype,
#                             path="saved_model/binary_classifier_checkpoint.pt"):
#     net = BinaryClassifier(input_n, level_2_dim, Dropout_Rate_1, Dropout_Rate_2)

#     early_stopping = EarlyStopping(patience=patience, verbose=False, path=path)

#     if torch.cuda.is_available():
#         net.cuda()
#     opt = optim.Adam(net.parameters(), lr=Learning_Rate, weight_decay=L2)

#     start_time = time.time()
#     for epoch in range(epoch_num):
#         net.train()
#         opt.zero_grad()

#         y_pred = net(train_x1, train_age, train_stage_i, train_stage_ii, train_race_white, s_dropout=True)
#         loss = F.binary_cross_entropy(y_pred.squeeze(), train_yevent.squeeze())

#         loss.backward()
#         opt.step()

#         net.eval()
#         eval_y_pred = net(eval_x1, eval_age, eval_stage_i, eval_stage_ii, eval_race_white, s_dropout=False)
#         eval_accuracy = accuracy_score(eval_yevent.detach().cpu().numpy(), eval_y_pred.detach().cpu().numpy().round())
#         eval_auc = roc_auc_score(eval_yevent.detach().cpu().numpy(), eval_y_pred.detach().cpu().numpy())
#         eval_f1 = f1_score(eval_yevent.detach().cpu().numpy(), eval_y_pred.detach().cpu().numpy().round())

#         early_stopping(eval_accuracy, net)
#         if early_stopping.early_stop:
#             print("Early stopping, number of epochs: ", epoch)
#             print('Save model of Epoch {:d}'.format(early_stopping.best_epoch_num))
#             break
#         if (epoch+1) % 100 == 0:
#             net.eval()
#             train_y_pred = net(train_x1, train_age, train_stage_i, train_stage_ii, train_race_white, s_dropout=False)
#             train_accuracy = accuracy_score(train_yevent.detach().cpu().numpy(), train_y_pred.detach().cpu().numpy().round())
#             print("Training Accuracy: %s," % train_accuracy, "validation Accuracy: %s." % eval_accuracy)

#     print("Loading model, best epoch: %s." % early_stopping.best_epoch_num)
#     net.load_state_dict(torch.load(path, map_location=torch.device('cpu')))

#     net.eval()
#     train_y_pred = net(train_x1, train_age, train_stage_i, train_stage_ii, train_race_white, s_dropout=False)
#     train_accuracy = accuracy_score(train_yevent.detach().cpu().numpy(), train_y_pred.detach().cpu().numpy().round())

#     net.eval()
#     eval_y_pred = net(eval_x1, eval_age, eval_stage_i, eval_stage_ii, eval_race_white, s_dropout=False)
#     eval_accuracy = accuracy_score(eval_yevent.detach().cpu().numpy(), eval_y_pred.detach().cpu().numpy().round())

#     print("Final training Accuracy: %s," % train_accuracy, "final validation Accuracy: %s." % eval_accuracy)
#     time_elapse = np.array(time.time() - start_time).round(2)
#     print("Total time elapse: %s." % time_elapse)

#     return (train_y_pred, eval_y_pred, train_accuracy, eval_accuracy, early_stopping.best_epoch_num)

# %%
import time
import torch
import torch.optim as optim
import torch.nn.functional as F
from sklearn.metrics import accuracy_score, roc_auc_score, f1_score, confusion_matrix, roc_curve, auc
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

def train_binary_classifier(train_x1, train_age, train_stage_i, train_stage_ii, train_race_white, train_yevent,
                            eval_x1, eval_age, eval_stage_i, eval_stage_ii, eval_race_white, eval_yevent,
                            input_n, level_2_dim, Dropout_Rate_1, Dropout_Rate_2, Learning_Rate, L2, epoch_num, patience, dtype,
                            path="saved_model/binary_classifier_checkpoint.pt", plot = True):
    net = BinaryClassifier(input_n, level_2_dim, Dropout_Rate_1, Dropout_Rate_2)

    early_stopping = EarlyStopping(patience=patience, verbose=False, path=path)

    if torch.cuda.is_available():
        net.cuda()
    opt = optim.Adam(net.parameters(), lr=Learning_Rate, weight_decay=L2)
    
    # Calculate the class weights
    num_pos = train_yevent.sum()
    num_neg = train_yevent.shape[0] - num_pos
    pos_weight = num_neg / (num_pos + num_neg)
    neg_weight = num_pos / (num_pos + num_neg)
    ###
 

    start_time = time.time()
    train_losses = []
    val_accuracies = []
    val_aucs = []
    val_f1s = []
    
    for epoch in range(epoch_num):
        net.train()
        opt.zero_grad()

        y_pred = net(train_x1, train_age, train_stage_i, train_stage_ii, train_race_white, s_dropout=True)
        # Calculate balanced cross-entropy loss
        loss_pos = -pos_weight * (train_yevent * torch.log(torch.sigmoid(y_pred)).squeeze())
        loss_neg = -neg_weight * ((1 - train_yevent) * torch.log(1 - torch.sigmoid(y_pred)).squeeze())
        loss = (loss_pos + loss_neg).mean()
        ##
        
        loss.backward()
        opt.step()

        train_losses.append(loss.item())

        net.eval()
        eval_y_pred = net(eval_x1, eval_age, eval_stage_i, eval_stage_ii, eval_race_white, s_dropout=False)
        eval_accuracy = accuracy_score(eval_yevent.detach().cpu().numpy(), eval_y_pred.detach().cpu().numpy().round())
        eval_auc = roc_auc_score(eval_yevent.detach().cpu().numpy(), eval_y_pred.detach().cpu().numpy())
        eval_f1 = f1_score(eval_yevent.detach().cpu().numpy(), eval_y_pred.detach().cpu().numpy().round())
        
        val_accuracies.append(eval_accuracy)
        val_aucs.append(eval_auc)
        val_f1s.append(eval_f1)

        early_stopping(eval_f1, net)
        if early_stopping.early_stop:
            print("Early stopping, number of epochs: ", epoch)
            print('Save model of Epoch {:d}'.format(early_stopping.best_epoch_num))
            break
        if (epoch+1) % 100 == 0:
            net.eval()
            train_y_pred = net(train_x1, train_age, train_stage_i, train_stage_ii, train_race_white, s_dropout=False)
            train_f1 = f1_score(train_yevent.detach().cpu().numpy(), train_y_pred.detach().cpu().numpy().round())
            print("Training F1: %s," % train_f1, "validation F1: %s." % eval_f1)

    print("Loading model, best epoch: %s." % early_stopping.best_epoch_num)
    net.load_state_dict(torch.load(path, map_location=torch.device('cpu')))

    net.eval()
    train_y_pred = net(train_x1, train_age, train_stage_i, train_stage_ii, train_race_white, s_dropout=False)
    train_accuracy = accuracy_score(train_yevent.detach().cpu().numpy(), train_y_pred.detach().cpu().numpy().round())
    train_auc = roc_auc_score(train_yevent.detach().cpu().numpy(), train_y_pred.detach().cpu().numpy())
    train_f1 = f1_score(train_yevent.detach().cpu().numpy(), train_y_pred.detach().cpu().numpy().round())
    
    net.eval()
    eval_y_pred = net(eval_x1, eval_age, eval_stage_i, eval_stage_ii, eval_race_white, s_dropout=False)
    eval_accuracy = accuracy_score(eval_yevent.detach().cpu().numpy(), eval_y_pred.detach().cpu().numpy().round())
    eval_auc = roc_auc_score(eval_yevent.detach().cpu().numpy(), eval_y_pred.detach().cpu().numpy())
    eval_f1 = f1_score(eval_yevent.detach().cpu().numpy(), eval_y_pred.detach().cpu().numpy().round())

    print("Final training Accuracy: %s," % train_accuracy, "final validation Accuracy: %s." % eval_accuracy)
    print("Final training AUC: %s," % train_auc, "final validation AUC: %s." % eval_auc)    
    print("Final training F1: %s," % train_f1, "final validation F1: %s." % eval_f1)
    time_elapse = np.array(time.time() - start_time).round(2)
    print("Total time elapse: %s." % time_elapse)
    if plot == True: 
        # Plotting the metrics
        epochs = range(1, len(train_losses) + 1)
        plt.figure(figsize=(18, 6))

        plt.subplot(1, 4, 1)
        plt.plot(epochs, train_losses, 'b', label='Training loss')
        plt.title('Training loss')
        plt.xlabel('Epochs')
        plt.ylabel('Loss')
        plt.legend()

        plt.subplot(1, 4, 2)
        plt.plot(epochs, val_accuracies, 'r', label='Validation Accuracy')
        plt.title('Validation Accuracy')
        plt.xlabel('Epochs')
        plt.ylabel('Accuracy')
        plt.legend()

        plt.subplot(1, 4, 3)
        plt.plot(epochs, val_aucs, 'g', label='Validation AUC')
        plt.plot(epochs, val_f1s, 'm', label='Validation F1')
        plt.title('Validation AUC and F1')
        plt.xlabel('Epochs')
        plt.ylabel('Score')
        plt.legend()
        
        plt.subplot(1, 4, 4)
        conf_matrix = confusion_matrix(eval_yevent.detach().cpu().numpy(), eval_y_pred.detach().cpu().numpy().round())
        sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
        plt.title('Confusion Matrix')
        plt.xlabel('Predicted label')
        plt.ylabel('True Label')

        plt.tight_layout()
        plt.show()
        
            # ROC Curve
        fpr, tpr, _ = roc_curve(eval_yevent.detach().cpu().numpy(), torch.sigmoid(eval_y_pred).detach().cpu().numpy())
        roc_auc = auc(fpr, tpr)

        plt.figure()
        plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
        plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
        plt.xlim([0.0, 1.0])
        plt.ylim([0.0, 1.05])
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.title('Receiver Operating Characteristic')
        plt.legend(loc="lower right")
        plt.show()
    

    return (train_y_pred, eval_y_pred, train_accuracy, eval_accuracy, train_auc, eval_auc, train_f1, eval_f1, early_stopping.best_epoch_num)

# %%
start_time = time.time()

# Example of calling the function with your data (assuming the data loading and preprocessing steps are similar)
input_n = 16
level_2_dim = [8, 16, 32]
epoch_num = 500
patience = 200
Initial_Learning_Rate = [0.05, 0.01, 0.0075, 0.005, 0.0025]
L2_Lambda = [0.001, 0.00075, 0.0005, 0.00025, 0.0001]
Dropout_rate_1 = [0.1, 0.3, 0.5]
Dropout_rate_2 = [0.1, 0.3, 0.5]

best_epoch_num = 0

patient_id_train, x_train, ytime_train, yevent_train, age_train, stage_i_train, stage_ii_train, race_white_train = load_data("tune_tr_z_2omics.csv", dtype)
patient_id_valid, x_valid, ytime_valid, yevent_valid, age_valid, stage_i_valid, stage_ii_valid, race_white_valid = load_data("tune_val_z_2omics.csv", dtype)

patient_id_train_overall, x_train_overall, ytime_train_overall, yevent_train_overall, age_train_overall, stage_i_train_overall, stage_ii_train_overall, race_white_train_overall = load_data("tr_z_2omics.csv", dtype)
patient_id_test_overall, x_test_overall, ytime_test_overall, yevent_test_overall, age_test_overall, stage_i_test_overall, stage_ii_test_overall, race_white_test_overall = load_data("tes_z_2omics.csv", dtype)
opt_l2 = 0
opt_lr = 0
opt_dim = 0
opt_dr1 = 0
opt_dr2 = 0

opt_va = float(0)
opt_tr = float(0)
for l2 in L2_Lambda:
    for lr in Initial_Learning_Rate:
        for dim in level_2_dim:
            for dr1 in Dropout_rate_1:
                for dr2 in Dropout_rate_2:
                    _, _, accuracy_train, accuracy_valid, train_auc, eval_auc, train_f1, eval_f1, best_epoch_num_tune = train_binary_classifier(x_train, age_train, stage_i_train, stage_ii_train, race_white_train, yevent_train,
                                                                                                        x_valid, age_valid, stage_i_valid, stage_ii_valid, race_white_valid, yevent_valid,
                                                                                                        input_n, dim, dr1, dr2, lr, l2, epoch_num, patience, dtype,
                                                                                                        path="saved_models/binary_classifier_checkpoint_tune.pt", plot = False)

                    if eval_f1 > opt_va:
                        opt_l2 = l2
                        opt_lr = lr
                        opt_dim = dim
                        opt_dr1 = dr1
                        opt_dr2 = dr2
                        opt_tr = train_f1
                        opt_va = eval_f1
                        best_epoch_num = best_epoch_num_tune
                    print("L2: %s," % l2, "LR: %s." % lr, "dim: %s," % dim, "dr1: %s," % dr1, "dr2: %s." % dr2)
                    print("Training F1: %s," % train_f1, "validation F1: %s." % eval_f1)

train_y_pred, test_y_pred, accuracy_train, accuracy_test, train_auc, test_auc, train_f1, test_f1, best_epoch_num_overall = train_binary_classifier(x_train_overall, age_train_overall, stage_i_train_overall, stage_ii_train_overall, race_white_train_overall, yevent_train_overall,
                                                                                                           x_test_overall, age_test_overall, stage_i_test_overall, stage_ii_test_overall, race_white_test_overall, yevent_test_overall,
                                                                                                           input_n, opt_dim, opt_dr1, opt_dr2, opt_lr, opt_l2, epoch_num, patience, dtype,
                                                                                                           path="saved_models/binary_classifier_checkpoint_overall.pt")
print("Optimal L2: %s," % opt_l2, "optimal LR: %s," % opt_lr, "optimal dim: %s," % opt_dim, "optimal dr1: %s," % opt_dr1, "optimal dr2: %s," % opt_dr2, "best epoch number in tuning: %s." % best_epoch_num)
print("Optimal training f1: %s," % opt_va, "optimal validation F1: %s." % opt_tr)
print("Testing phase: training Accuracy: %s," % accuracy_train, "testing Accuracy: %s." % accuracy_test)
print("Testing phase: training AUC: %s," % train_auc, "testing AUC: %s." % test_auc)
print("Testing phase: training F1: %s," % train_f1, "testing F1: %s." % test_f1)
end_time = time.time()
print("--- %s seconds ---" % (end_time - start_time))
# Out:
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  203
# Save model of Epoch 4
# Loading model, best epoch: 4.
# Final training Accuracy: 0.1898355754857997, final validation Accuracy: 0.19680851063829788.
# Final training AUC: 0.5608435852372583, final validation AUC: 0.5777310924369747.
# Final training F1: 0.25753424657534246, final validation F1: 0.29107981220657275.
# Total time elapse: 3.8.
# L2: 0.001, LR: 0.05. dim: 8, dr1: 0.1, dr2: 0.1.
# Training F1: 0.25753424657534246, validation F1: 0.29107981220657275.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Loading model, best epoch: 500.
# Final training Accuracy: 0.8505231689088192, final validation Accuracy: 0.8191489361702128.
# Final training AUC: 0.5, final validation AUC: 0.5.
# Final training F1: 0.0, final validation F1: 0.0.
# Total time elapse: 19.07.
# L2: 0.001, LR: 0.05. dim: 8, dr1: 0.1, dr2: 0.3.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Loading model, best epoch: 500.
# Final training Accuracy: 0.8505231689088192, final validation Accuracy: 0.8191489361702128.
# Final training AUC: 0.5, final validation AUC: 0.5.
# Final training F1: 0.0, final validation F1: 0.0.
# Total time elapse: 18.79.
# L2: 0.001, LR: 0.05. dim: 8, dr1: 0.1, dr2: 0.5.
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  200
# Save model of Epoch 1
# Loading model, best epoch: 1.
# Final training Accuracy: 0.5261584454409567, final validation Accuracy: 0.5691489361702128.
# Final training AUC: 0.44442882249560633, final validation AUC: 0.5265469824293354.
# Final training F1: 0.18508997429305912, final validation F1: 0.2702702702702703.
# Total time elapse: 1.05.
# L2: 0.001, LR: 0.05. dim: 8, dr1: 0.3, dr2: 0.1.
# Training F1: 0.18508997429305912, validation F1: 0.2702702702702703.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Loading model, best epoch: 500.
# Final training Accuracy: 0.8505231689088192, final validation Accuracy: 0.8191489361702128.
# Final training AUC: 0.5, final validation AUC: 0.5.
# Final training F1: 0.0, final validation F1: 0.0.
# Total time elapse: 18.36.
# L2: 0.001, LR: 0.05. dim: 8, dr1: 0.3, dr2: 0.3.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Loading model, best epoch: 500.
# Final training Accuracy: 0.8505231689088192, final validation Accuracy: 0.8191489361702128.
# Final training AUC: 0.5, final validation AUC: 0.5.
# Final training F1: 0.0, final validation F1: 0.0.
# Total time elapse: 18.48.
# L2: 0.001, LR: 0.05. dim: 8, dr1: 0.3, dr2: 0.5.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Loading model, best epoch: 500.
# Final training Accuracy: 0.8505231689088192, final validation Accuracy: 0.8191489361702128.
# Final training AUC: 0.5, final validation AUC: 0.5.
# Final training F1: 0.0, final validation F1: 0.0.
# Total time elapse: 18.81.
# L2: 0.001, LR: 0.05. dim: 8, dr1: 0.5, dr2: 0.1.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Loading model, best epoch: 500.
# Final training Accuracy: 0.8505231689088192, final validation Accuracy: 0.8191489361702128.
# Final training AUC: 0.5, final validation AUC: 0.5.
# Final training F1: 0.0, final validation F1: 0.0.
# Total time elapse: 18.46.
# L2: 0.001, LR: 0.05. dim: 8, dr1: 0.5, dr2: 0.3.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Loading model, best epoch: 500.
# Final training Accuracy: 0.8505231689088192, final validation Accuracy: 0.8191489361702128.
# Final training AUC: 0.5, final validation AUC: 0.5.
# Final training F1: 0.0, final validation F1: 0.0.
# Total time elapse: 18.74.
# L2: 0.001, LR: 0.05. dim: 8, dr1: 0.5, dr2: 0.5.
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  200
# Save model of Epoch 1
# Loading model, best epoch: 1.
# Final training Accuracy: 0.336322869955157, final validation Accuracy: 0.3882978723404255.
# Final training AUC: 0.5278734622144112, final validation AUC: 0.4931245225362872.
# Final training F1: 0.26973684210526316, final validation F1: 0.2857142857142857.
# Total time elapse: 1.05.
# L2: 0.001, LR: 0.05. dim: 16, dr1: 0.1, dr2: 0.1.
# Training F1: 0.26973684210526316, validation F1: 0.2857142857142857.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  200
# Save model of Epoch 1
# Loading model, best epoch: 1.
# Final training Accuracy: 0.14947683109118087, final validation Accuracy: 0.18085106382978725.
# Final training AUC: 0.4770474516695958, final validation AUC: 0.5248281130634072.
# Final training F1: 0.26007802340702213, final validation F1: 0.3063063063063063.
# Total time elapse: 1.08.
# L2: 0.001, LR: 0.05. dim: 16, dr1: 0.1, dr2: 0.3.
# Training F1: 0.26007802340702213, validation F1: 0.3063063063063063.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Loading model, best epoch: 500.
# Final training Accuracy: 0.8505231689088192, final validation Accuracy: 0.8191489361702128.
# Final training AUC: 0.5, final validation AUC: 0.5.
# Final training F1: 0.0, final validation F1: 0.0.
# Total time elapse: 18.75.
# L2: 0.001, LR: 0.05. dim: 16, dr1: 0.1, dr2: 0.5.
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  200
# Save model of Epoch 1
# Loading model, best epoch: 1.
# Final training Accuracy: 0.14947683109118087, final validation Accuracy: 0.18085106382978725.
# Final training AUC: 0.4705096660808436, final validation AUC: 0.4264705882352942.
# Final training F1: 0.26007802340702213, final validation F1: 0.3063063063063063.
# Total time elapse: 1.04.
# L2: 0.001, LR: 0.05. dim: 16, dr1: 0.3, dr2: 0.1.
# Training F1: 0.26007802340702213, validation F1: 0.3063063063063063.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Loading model, best epoch: 500.
# Final training Accuracy: 0.8505231689088192, final validation Accuracy: 0.8191489361702128.
# Final training AUC: 0.5, final validation AUC: 0.5.
# Final training F1: 0.0, final validation F1: 0.0.
# Total time elapse: 18.6.
# L2: 0.001, LR: 0.05. dim: 16, dr1: 0.3, dr2: 0.3.
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  202
# Save model of Epoch 3
# Loading model, best epoch: 3.
# Final training Accuracy: 0.14947683109118087, final validation Accuracy: 0.18085106382978725.
# Final training AUC: 0.623128295254833, final validation AUC: 0.6035141329258976.
# Final training F1: 0.26007802340702213, final validation F1: 0.3063063063063063.
# Total time elapse: 1.07.
# L2: 0.001, LR: 0.05. dim: 16, dr1: 0.3, dr2: 0.5.
# Training F1: 0.26007802340702213, validation F1: 0.3063063063063063.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Loading model, best epoch: 500.
# Final training Accuracy: 0.8505231689088192, final validation Accuracy: 0.8191489361702128.
# Final training AUC: 0.5, final validation AUC: 0.5.
# Final training F1: 0.0, final validation F1: 0.0.
# Total time elapse: 18.56.
# L2: 0.001, LR: 0.05. dim: 16, dr1: 0.5, dr2: 0.1.
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  201
# Save model of Epoch 2
# Loading model, best epoch: 2.
# Final training Accuracy: 0.15396113602391628, final validation Accuracy: 0.18617021276595744.
# Final training AUC: 0.5419683655536027, final validation AUC: 0.5268334606569901.
# Final training F1: 0.26109660574412535, final validation F1: 0.3076923076923077.
# Total time elapse: 1.06.
# L2: 0.001, LR: 0.05. dim: 16, dr1: 0.5, dr2: 0.3.
# Training F1: 0.26109660574412535, validation F1: 0.3076923076923077.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  200
# Save model of Epoch 1
# Loading model, best epoch: 1.
# Final training Accuracy: 0.20926756352765322, final validation Accuracy: 0.26063829787234044.
# Final training AUC: 0.491493848857645, final validation AUC: 0.5702826585179526.
# Final training F1: 0.22773722627737225, final validation F1: 0.3015075376884422.
# Total time elapse: 1.07.
# L2: 0.001, LR: 0.05. dim: 16, dr1: 0.5, dr2: 0.5.
# Training F1: 0.22773722627737225, validation F1: 0.3015075376884422.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  200
# Save model of Epoch 1
# Loading model, best epoch: 1.
# Final training Accuracy: 0.6442451420029895, final validation Accuracy: 0.6808510638297872.
# Final training AUC: 0.4068892794376098, final validation AUC: 0.48262032085561496.
# Final training F1: 0.11194029850746269, final validation F1: 0.25.
# Total time elapse: 1.03.
# L2: 0.001, LR: 0.05. dim: 32, dr1: 0.1, dr2: 0.1.
# Training F1: 0.11194029850746269, validation F1: 0.25.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  200
# Save model of Epoch 1
# Loading model, best epoch: 1.
# Final training Accuracy: 0.14947683109118087, final validation Accuracy: 0.18085106382978725.
# Final training AUC: 0.46081722319859403, final validation AUC: 0.43869365928189463.
# Final training F1: 0.26007802340702213, final validation F1: 0.3063063063063063.
# Total time elapse: 1.05.
# L2: 0.001, LR: 0.05. dim: 32, dr1: 0.1, dr2: 0.3.
# Training F1: 0.26007802340702213, validation F1: 0.3063063063063063.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Loading model, best epoch: 500.
# Final training Accuracy: 0.8505231689088192, final validation Accuracy: 0.8191489361702128.
# Final training AUC: 0.5, final validation AUC: 0.5.
# Final training F1: 0.0, final validation F1: 0.0.
# Total time elapse: 19.05.
# L2: 0.001, LR: 0.05. dim: 32, dr1: 0.1, dr2: 0.5.
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  204
# Save model of Epoch 5
# Loading model, best epoch: 5.
# Final training Accuracy: 0.8116591928251121, final validation Accuracy: 0.7925531914893617.
# Final training AUC: 0.5850966608084358, final validation AUC: 0.5530939648586708.
# Final training F1: 0.25, final validation F1: 0.2909090909090909.
# Total time elapse: 1.16.
# L2: 0.001, LR: 0.05. dim: 32, dr1: 0.3, dr2: 0.1.
# Training F1: 0.25, validation F1: 0.2909090909090909.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Loading model, best epoch: 500.
# Final training Accuracy: 0.8505231689088192, final validation Accuracy: 0.8191489361702128.
# Final training AUC: 0.5, final validation AUC: 0.5.
# Final training F1: 0.0, final validation F1: 0.0.
# Total time elapse: 18.72.
# L2: 0.001, LR: 0.05. dim: 32, dr1: 0.3, dr2: 0.3.
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  200
# Save model of Epoch 1
# Loading model, best epoch: 1.
# Final training Accuracy: 0.14947683109118087, final validation Accuracy: 0.18085106382978725.
# Final training AUC: 0.5388224956063268, final validation AUC: 0.5826967150496563.
# Final training F1: 0.26007802340702213, final validation F1: 0.3063063063063063.
# Total time elapse: 1.03.
# L2: 0.001, LR: 0.05. dim: 32, dr1: 0.3, dr2: 0.5.
# Training F1: 0.26007802340702213, validation F1: 0.3063063063063063.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Loading model, best epoch: 500.
# Final training Accuracy: 0.8505231689088192, final validation Accuracy: 0.8191489361702128.
# Final training AUC: 0.5, final validation AUC: 0.5.
# Final training F1: 0.0, final validation F1: 0.0.
# Total time elapse: 18.82.
# L2: 0.001, LR: 0.05. dim: 32, dr1: 0.5, dr2: 0.1.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Loading model, best epoch: 500.
# Final training Accuracy: 0.8505231689088192, final validation Accuracy: 0.8191489361702128.
# Final training AUC: 0.5, final validation AUC: 0.5.
# Final training F1: 0.0, final validation F1: 0.0.
# Total time elapse: 19.03.
# L2: 0.001, LR: 0.05. dim: 32, dr1: 0.5, dr2: 0.3.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Loading model, best epoch: 500.
# Final training Accuracy: 0.8505231689088192, final validation Accuracy: 0.8191489361702128.
# Final training AUC: 0.5, final validation AUC: 0.5.
# Final training F1: 0.0, final validation F1: 0.0.
# Total time elapse: 18.83.
# L2: 0.001, LR: 0.05. dim: 32, dr1: 0.5, dr2: 0.5.
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  209
# Save model of Epoch 10
# Loading model, best epoch: 10.
# Final training Accuracy: 0.15097159940209268, final validation Accuracy: 0.18617021276595744.
# Final training AUC: 0.49218804920913883, final validation AUC: 0.5387700534759358.
# Final training F1: 0.2584856396866841, final validation F1: 0.3076923076923077.
# Total time elapse: 1.39.
# L2: 0.001, LR: 0.01. dim: 8, dr1: 0.1, dr2: 0.1.
# Training F1: 0.2584856396866841, validation F1: 0.3076923076923077.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  218
# Save model of Epoch 19
# Loading model, best epoch: 19.
# Final training Accuracy: 0.5724962630792227, final validation Accuracy: 0.574468085106383.
# Final training AUC: 0.5456590509666082, final validation AUC: 0.6176470588235293.
# Final training F1: 0.2513089005235602, final validation F1: 0.3333333333333333.
# Total time elapse: 1.74.
# L2: 0.001, LR: 0.01. dim: 8, dr1: 0.1, dr2: 0.3.
# Training F1: 0.2513089005235602, validation F1: 0.3333333333333333.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  205
# Save model of Epoch 6
# Loading model, best epoch: 6.
# Final training Accuracy: 0.17189835575485798, final validation Accuracy: 0.19148936170212766.
# Final training AUC: 0.5092970123022847, final validation AUC: 0.44404125286478224.
# Final training F1: 0.2632978723404255, final validation F1: 0.3090909090909091.
# Total time elapse: 1.07.
# L2: 0.001, LR: 0.01. dim: 8, dr1: 0.1, dr2: 0.5.
# Training F1: 0.2632978723404255, validation F1: 0.3090909090909091.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  225
# Save model of Epoch 26
# Loading model, best epoch: 26.
# Final training Accuracy: 0.7982062780269058, final validation Accuracy: 0.8138297872340425.
# Final training AUC: 0.584165202108963, final validation AUC: 0.5731474407944996.
# Final training F1: 0.21965317919075145, final validation F1: 0.4067796610169492.
# Total time elapse: 1.97.
# L2: 0.001, LR: 0.01. dim: 8, dr1: 0.3, dr2: 0.1.
# Training F1: 0.21965317919075145, validation F1: 0.4067796610169492.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  213
# Save model of Epoch 14
# Loading model, best epoch: 14.
# Final training Accuracy: 0.15844544095665172, final validation Accuracy: 0.19148936170212766.
# Final training AUC: 0.5346748681898067, final validation AUC: 0.5286478227654698.
# Final training F1: 0.2621231979030144, final validation F1: 0.3090909090909091.
# Total time elapse: 1.35.
# L2: 0.001, LR: 0.01. dim: 8, dr1: 0.3, dr2: 0.3.
# Training F1: 0.2621231979030144, validation F1: 0.3090909090909091.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  226
# Save model of Epoch 27
# Loading model, best epoch: 27.
# Final training Accuracy: 0.7428998505231689, final validation Accuracy: 0.7340425531914894.
# Final training AUC: 0.5601933216168717, final validation AUC: 0.549274255156608.
# Final training F1: 0.3008130081300813, final validation F1: 0.358974358974359.
# Total time elapse: 1.41.
# L2: 0.001, LR: 0.01. dim: 8, dr1: 0.3, dr2: 0.5.
# Training F1: 0.3008130081300813, validation F1: 0.358974358974359.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Loading model, best epoch: 500.
# Final training Accuracy: 0.8505231689088192, final validation Accuracy: 0.8191489361702128.
# Final training AUC: 0.5702548330404218, final validation AUC: 0.5944423223834989.
# Final training F1: 0.0, final validation F1: 0.0.
# Total time elapse: 19.08.
# L2: 0.001, LR: 0.01. dim: 8, dr1: 0.5, dr2: 0.1.
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  238
# Save model of Epoch 39
# Loading model, best epoch: 39.
# Final training Accuracy: 0.7757847533632287, final validation Accuracy: 0.75.
# Final training AUC: 0.5897275922671353, final validation AUC: 0.5846065699006876.
# Final training F1: 0.27184466019417475, final validation F1: 0.3380281690140845.
# Total time elapse: 1.73.
# L2: 0.001, LR: 0.01. dim: 8, dr1: 0.5, dr2: 0.3.
# Training F1: 0.27184466019417475, validation F1: 0.3380281690140845.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  204
# Save model of Epoch 5
# Loading model, best epoch: 5.
# Final training Accuracy: 0.4588938714499253, final validation Accuracy: 0.4946808510638298.
# Final training AUC: 0.5254305799648507, final validation AUC: 0.6038961038961038.
# Final training F1: 0.23628691983122363, final validation F1: 0.3356643356643357.
# Total time elapse: 1.19.
# L2: 0.001, LR: 0.01. dim: 8, dr1: 0.5, dr2: 0.5.
# Training F1: 0.23628691983122363, validation F1: 0.3356643356643357.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  220
# Save model of Epoch 21
# Loading model, best epoch: 21.
# Final training Accuracy: 0.8430493273542601, final validation Accuracy: 0.8297872340425532.
# Final training AUC: 0.5646397188049209, final validation AUC: 0.5557677616501145.
# Final training F1: 0.08695652173913043, final validation F1: 0.15789473684210525.
# Total time elapse: 1.8.
# L2: 0.001, LR: 0.01. dim: 16, dr1: 0.1, dr2: 0.1.
# Training F1: 0.08695652173913043, validation F1: 0.15789473684210525.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  203
# Save model of Epoch 4
# Loading model, best epoch: 4.
# Final training Accuracy: 0.16143497757847533, final validation Accuracy: 0.19148936170212766.
# Final training AUC: 0.541511423550088, final validation AUC: 0.5372421695951107.
# Final training F1: 0.2608695652173913, final validation F1: 0.3090909090909091.
# Total time elapse: 1.14.
# L2: 0.001, LR: 0.01. dim: 16, dr1: 0.1, dr2: 0.3.
# Training F1: 0.2608695652173913, validation F1: 0.3090909090909091.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Loading model, best epoch: 500.
# Final training Accuracy: 0.8505231689088192, final validation Accuracy: 0.8191489361702128.
# Final training AUC: 0.5, final validation AUC: 0.5.
# Final training F1: 0.0, final validation F1: 0.0.
# Total time elapse: 18.61.
# L2: 0.001, LR: 0.01. dim: 16, dr1: 0.1, dr2: 0.5.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Loading model, best epoch: 500.
# Final training Accuracy: 0.8505231689088192, final validation Accuracy: 0.8191489361702128.
# Final training AUC: 0.5248681898066784, final validation AUC: 0.4652406417112299.
# Final training F1: 0.0, final validation F1: 0.0.
# Total time elapse: 18.37.
# L2: 0.001, LR: 0.01. dim: 16, dr1: 0.3, dr2: 0.1.
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  200
# Save model of Epoch 1
# Loading model, best epoch: 1.
# Final training Accuracy: 0.17638266068759342, final validation Accuracy: 0.22340425531914893.
# Final training AUC: 0.5789806678383129, final validation AUC: 0.4967532467532468.
# Final training F1: 0.26238286479250333, final validation F1: 0.2980769230769231.
# Total time elapse: 1.04.
# L2: 0.001, LR: 0.01. dim: 16, dr1: 0.3, dr2: 0.3.
# Training F1: 0.26238286479250333, validation F1: 0.2980769230769231.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  207
# Save model of Epoch 8
# Loading model, best epoch: 8.
# Final training Accuracy: 0.14947683109118087, final validation Accuracy: 0.18085106382978725.
# Final training AUC: 0.3673286467486819, final validation AUC: 0.41386554621848737.
# Final training F1: 0.26007802340702213, final validation F1: 0.3063063063063063.
# Total time elapse: 1.4.
# L2: 0.001, LR: 0.01. dim: 16, dr1: 0.3, dr2: 0.5.
# Training F1: 0.26007802340702213, validation F1: 0.3063063063063063.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  204
# Save model of Epoch 5
# Loading model, best epoch: 5.
# Final training Accuracy: 0.14947683109118087, final validation Accuracy: 0.18085106382978725.
# Final training AUC: 0.5088927943760985, final validation AUC: 0.5550038197097019.
# Final training F1: 0.26007802340702213, final validation F1: 0.3063063063063063.
# Total time elapse: 1.18.
# L2: 0.001, LR: 0.01. dim: 16, dr1: 0.5, dr2: 0.1.
# Training F1: 0.26007802340702213, validation F1: 0.3063063063063063.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  221
# Save model of Epoch 22
# Loading model, best epoch: 22.
# Final training Accuracy: 0.5590433482810164, final validation Accuracy: 0.48936170212765956.
# Final training AUC: 0.5753075571177505, final validation AUC: 0.5548128342245989.
# Final training F1: 0.2751842751842752, final validation F1: 0.2835820895522388.
# Total time elapse: 1.83.
# L2: 0.001, LR: 0.01. dim: 16, dr1: 0.5, dr2: 0.3.
# Training F1: 0.2751842751842752, validation F1: 0.2835820895522388.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Loading model, best epoch: 500.
# Final training Accuracy: 0.8505231689088192, final validation Accuracy: 0.8191489361702128.
# Final training AUC: 0.5, final validation AUC: 0.5.
# Final training F1: 0.0, final validation F1: 0.0.
# Total time elapse: 18.63.
# L2: 0.001, LR: 0.01. dim: 16, dr1: 0.5, dr2: 0.5.
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  206
# Save model of Epoch 7
# Loading model, best epoch: 7.
# Final training Accuracy: 0.8131539611360239, final validation Accuracy: 0.8457446808510638.
# Final training AUC: 0.5928646748681898, final validation AUC: 0.6124904507257448.
# Final training F1: 0.1830065359477124, final validation F1: 0.35555555555555557.
# Total time elapse: 1.16.
# L2: 0.001, LR: 0.01. dim: 32, dr1: 0.1, dr2: 0.1.
# Training F1: 0.1830065359477124, validation F1: 0.35555555555555557.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  201
# Save model of Epoch 2
# Loading model, best epoch: 2.
# Final training Accuracy: 0.25112107623318386, final validation Accuracy: 0.26595744680851063.
# Final training AUC: 0.5203866432337434, final validation AUC: 0.5068754774637128.
# Final training F1: 0.25112107623318386, final validation F1: 0.31683168316831684.
# Total time elapse: 1.1.
# L2: 0.001, LR: 0.01. dim: 32, dr1: 0.1, dr2: 0.3.
# Training F1: 0.25112107623318386, validation F1: 0.31683168316831684.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  206
# Save model of Epoch 7
# Loading model, best epoch: 7.
# Final training Accuracy: 0.47832585949177875, final validation Accuracy: 0.5212765957446809.
# Final training AUC: 0.5649912126537786, final validation AUC: 0.549083269671505.
# Final training F1: 0.26215644820295986, final validation F1: 0.3076923076923077.
# Total time elapse: 1.29.
# L2: 0.001, LR: 0.01. dim: 32, dr1: 0.1, dr2: 0.5.
# Training F1: 0.26215644820295986, validation F1: 0.3076923076923077.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  220
# Save model of Epoch 21
# Loading model, best epoch: 21.
# Final training Accuracy: 0.8191330343796711, final validation Accuracy: 0.8085106382978723.
# Final training AUC: 0.5665026362038665, final validation AUC: 0.5763941940412529.
# Final training F1: 0.20915032679738563, final validation F1: 0.28.
# Total time elapse: 1.47.
# L2: 0.001, LR: 0.01. dim: 32, dr1: 0.3, dr2: 0.1.
# Training F1: 0.20915032679738563, validation F1: 0.28.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  204
# Save model of Epoch 5
# Loading model, best epoch: 5.
# Final training Accuracy: 0.6278026905829597, final validation Accuracy: 0.6542553191489362.
# Final training AUC: 0.5941036906854129, final validation AUC: 0.6262414056531703.
# Final training F1: 0.27405247813411077, final validation F1: 0.36893203883495146.
# Total time elapse: 1.16.
# L2: 0.001, LR: 0.01. dim: 32, dr1: 0.3, dr2: 0.3.
# Training F1: 0.27405247813411077, validation F1: 0.36893203883495146.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Loading model, best epoch: 500.
# Final training Accuracy: 0.8505231689088192, final validation Accuracy: 0.8191489361702128.
# Final training AUC: 0.5, final validation AUC: 0.5.
# Final training F1: 0.0, final validation F1: 0.0.
# Total time elapse: 18.96.
# L2: 0.001, LR: 0.01. dim: 32, dr1: 0.3, dr2: 0.5.
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  200
# Save model of Epoch 1
# Loading model, best epoch: 1.
# Final training Accuracy: 0.14947683109118087, final validation Accuracy: 0.18085106382978725.
# Final training AUC: 0.510755711775044, final validation AUC: 0.4270435446906035.
# Final training F1: 0.26007802340702213, final validation F1: 0.3063063063063063.
# Total time elapse: 1.08.
# L2: 0.001, LR: 0.01. dim: 32, dr1: 0.5, dr2: 0.1.
# Training F1: 0.26007802340702213, validation F1: 0.3063063063063063.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  200
# Save model of Epoch 1
# Loading model, best epoch: 1.
# Final training Accuracy: 0.47533632286995514, final validation Accuracy: 0.5106382978723404.
# Final training AUC: 0.5442355008787346, final validation AUC: 0.5557677616501145.
# Final training F1: 0.267223382045929, final validation F1: 0.30303030303030304.
# Total time elapse: 1.07.
# L2: 0.001, LR: 0.01. dim: 32, dr1: 0.5, dr2: 0.3.
# Training F1: 0.267223382045929, validation F1: 0.30303030303030304.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  214
# Save model of Epoch 15
# Loading model, best epoch: 15.
# Final training Accuracy: 0.6128550074738416, final validation Accuracy: 0.601063829787234.
# Final training AUC: 0.5374165202108963, final validation AUC: 0.5756302521008404.
# Final training F1: 0.25360230547550433, final validation F1: 0.3119266055045872.
# Total time elapse: 1.57.
# L2: 0.001, LR: 0.01. dim: 32, dr1: 0.5, dr2: 0.5.
# Training F1: 0.25360230547550433, validation F1: 0.3119266055045872.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Loading model, best epoch: 500.
# Final training Accuracy: 0.8505231689088192, final validation Accuracy: 0.8191489361702128.
# Final training AUC: 0.4222407732864674, final validation AUC: 0.4122421695951108.
# Final training F1: 0.0, final validation F1: 0.0.
# Total time elapse: 18.59.
# L2: 0.001, LR: 0.0075. dim: 8, dr1: 0.1, dr2: 0.1.
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  213
# Save model of Epoch 14
# Loading model, best epoch: 14.
# Final training Accuracy: 0.2750373692077728, final validation Accuracy: 0.35106382978723405.
# Final training AUC: 0.5319420035149385, final validation AUC: 0.5786860198624905.
# Final training F1: 0.2617960426179604, final validation F1: 0.33695652173913043.
# Total time elapse: 1.28.
# L2: 0.001, LR: 0.0075. dim: 8, dr1: 0.1, dr2: 0.3.
# Training F1: 0.2617960426179604, validation F1: 0.33695652173913043.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  207
# Save model of Epoch 8
# Loading model, best epoch: 8.
# Final training Accuracy: 0.8475336322869955, final validation Accuracy: 0.824468085106383.
# Final training AUC: 0.4436555360281195, final validation AUC: 0.4155844155844156.
# Final training F1: 0.0, final validation F1: 0.05714285714285714.
# Total time elapse: 1.28.
# L2: 0.001, LR: 0.0075. dim: 8, dr1: 0.1, dr2: 0.5.
# Training F1: 0.0, validation F1: 0.05714285714285714.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Loading model, best epoch: 500.
# Final training Accuracy: 0.8505231689088192, final validation Accuracy: 0.8191489361702128.
# Final training AUC: 0.4232776801405976, final validation AUC: 0.4322956455309397.
# Final training F1: 0.0, final validation F1: 0.0.
# Total time elapse: 18.48.
# L2: 0.001, LR: 0.0075. dim: 8, dr1: 0.3, dr2: 0.1.
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  200
# Save model of Epoch 1
# Loading model, best epoch: 1.
# Final training Accuracy: 0.14947683109118087, final validation Accuracy: 0.18085106382978725.
# Final training AUC: 0.4118365553602812, final validation AUC: 0.44270435446906037.
# Final training F1: 0.26007802340702213, final validation F1: 0.3063063063063063.
# Total time elapse: 1.04.
# L2: 0.001, LR: 0.0075. dim: 8, dr1: 0.3, dr2: 0.3.
# Training F1: 0.26007802340702213, validation F1: 0.3063063063063063.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  202
# Save model of Epoch 3
# Loading model, best epoch: 3.
# Final training Accuracy: 0.15097159940209268, final validation Accuracy: 0.18617021276595744.
# Final training AUC: 0.522688927943761, final validation AUC: 0.48433919022154315.
# Final training F1: 0.2604166666666667, final validation F1: 0.3076923076923077.
# Total time elapse: 1.1.
# L2: 0.001, LR: 0.0075. dim: 8, dr1: 0.3, dr2: 0.5.
# Training F1: 0.2604166666666667, validation F1: 0.3076923076923077.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 200 out of 200
# ...
# Final training AUC: 0.6278910369068542, final validation AUC: 0.5423987776928954.
# Final training F1: 0.2805755395683453, final validation F1: 0.22784810126582278.
# Total time elapse: 1.48.
# L2: 0.0001, LR: 0.0025. dim: 16, dr1: 0.1, dr2: 0.1.
# Training F1: 0.2805755395683453, validation F1: 0.22784810126582278.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Loading model, best epoch: 500.
# Final training Accuracy: 0.8505231689088192, final validation Accuracy: 0.8191489361702128.
# Final training AUC: 0.546256590509666, final validation AUC: 0.39343009931245226.
# Final training F1: 0.0, final validation F1: 0.0.
# Total time elapse: 18.98.
# L2: 0.0001, LR: 0.0025. dim: 16, dr1: 0.1, dr2: 0.3.
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  211
# Save model of Epoch 12
# Loading model, best epoch: 12.
# Final training Accuracy: 0.7219730941704036, final validation Accuracy: 0.7446808510638298.
# Final training AUC: 0.4835149384885764, final validation AUC: 0.5255920550038198.
# Final training F1: 0.16964285714285715, final validation F1: 0.35135135135135137.
# Total time elapse: 1.24.
# L2: 0.0001, LR: 0.0025. dim: 16, dr1: 0.1, dr2: 0.5.
# Training F1: 0.16964285714285715, validation F1: 0.35135135135135137.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  213
# Save model of Epoch 14
# Loading model, best epoch: 14.
# Final training Accuracy: 0.15844544095665172, final validation Accuracy: 0.18617021276595744.
# Final training AUC: 0.5422144112478032, final validation AUC: 0.5177616501145913.
# Final training F1: 0.2621231979030144, final validation F1: 0.3076923076923077.
# Total time elapse: 1.49.
# L2: 0.0001, LR: 0.0025. dim: 16, dr1: 0.3, dr2: 0.1.
# Training F1: 0.2621231979030144, validation F1: 0.3076923076923077.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Loading model, best epoch: 500.
# Final training Accuracy: 0.8505231689088192, final validation Accuracy: 0.8191489361702128.
# Final training AUC: 0.5858172231985941, final validation AUC: 0.5584415584415584.
# Final training F1: 0.0, final validation F1: 0.0.
# Total time elapse: 18.62.
# L2: 0.0001, LR: 0.0025. dim: 16, dr1: 0.3, dr2: 0.3.
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  203
# Save model of Epoch 4
# Loading model, best epoch: 4.
# Final training Accuracy: 0.19133034379671152, final validation Accuracy: 0.24468085106382978.
# Final training AUC: 0.5333216168717048, final validation AUC: 0.534568372803667.
# Final training F1: 0.2578875171467764, final validation F1: 0.3173076923076923.
# Total time elapse: 1.14.
# L2: 0.0001, LR: 0.0025. dim: 16, dr1: 0.3, dr2: 0.5.
# Training F1: 0.2578875171467764, validation F1: 0.3173076923076923.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Loading model, best epoch: 500.
# Final training Accuracy: 0.8505231689088192, final validation Accuracy: 0.8191489361702128.
# Final training AUC: 0.4928822495606327, final validation AUC: 0.516042780748663.
# Final training F1: 0.0, final validation F1: 0.0.
# Total time elapse: 19.12.
# L2: 0.0001, LR: 0.0025. dim: 16, dr1: 0.5, dr2: 0.1.
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  201
# Save model of Epoch 2
# Loading model, best epoch: 2.
# Final training Accuracy: 0.8460388639760837, final validation Accuracy: 0.8085106382978723.
# Final training AUC: 0.6046748681898066, final validation AUC: 0.6113445378151261.
# Final training F1: 0.16260162601626016, final validation F1: 0.18181818181818182.
# Total time elapse: 1.06.
# L2: 0.0001, LR: 0.0025. dim: 16, dr1: 0.5, dr2: 0.3.
# Training F1: 0.16260162601626016, validation F1: 0.18181818181818182.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Loading model, best epoch: 500.
# Final training Accuracy: 0.8505231689088192, final validation Accuracy: 0.8191489361702128.
# Final training AUC: 0.402609841827768, final validation AUC: 0.30194805194805197.
# Final training F1: 0.0, final validation F1: 0.0.
# Total time elapse: 18.91.
# L2: 0.0001, LR: 0.0025. dim: 16, dr1: 0.5, dr2: 0.5.
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  245
# Save model of Epoch 46
# Loading model, best epoch: 46.
# Final training Accuracy: 0.7862481315396114, final validation Accuracy: 0.7925531914893617.
# Final training AUC: 0.5621265377855887, final validation AUC: 0.6071428571428572.
# Final training F1: 0.23529411764705882, final validation F1: 0.36065573770491804.
# Total time elapse: 1.96.
# L2: 0.0001, LR: 0.0025. dim: 32, dr1: 0.1, dr2: 0.1.
# Training F1: 0.23529411764705882, validation F1: 0.36065573770491804.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  200
# Save model of Epoch 1
# Loading model, best epoch: 1.
# Final training Accuracy: 0.23168908819133036, final validation Accuracy: 0.2872340425531915.
# Final training AUC: 0.37806678383128295, final validation AUC: 0.40985485103132163.
# Final training F1: 0.21406727828746178, final validation F1: 0.2717391304347826.
# Total time elapse: 1.07.
# L2: 0.0001, LR: 0.0025. dim: 32, dr1: 0.1, dr2: 0.3.
# Training F1: 0.21406727828746178, validation F1: 0.2717391304347826.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  205
# Save model of Epoch 6
# Loading model, best epoch: 6.
# Final training Accuracy: 0.18535127055306427, final validation Accuracy: 0.21808510638297873.
# Final training AUC: 0.4389894551845343, final validation AUC: 0.5026737967914439.
# Final training F1: 0.2625169147496617, final validation F1: 0.30985915492957744.
# Total time elapse: 1.25.
# L2: 0.0001, LR: 0.0025. dim: 32, dr1: 0.1, dr2: 0.5.
# Training F1: 0.2625169147496617, validation F1: 0.30985915492957744.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  221
# Save model of Epoch 22
# Loading model, best epoch: 22.
# Final training Accuracy: 0.5426008968609866, final validation Accuracy: 0.574468085106383.
# Final training AUC: 0.49161687170474516, final validation AUC: 0.5059205500381971.
# Final training F1: 0.2193877551020408, final validation F1: 0.3103448275862069.
# Total time elapse: 1.62.
# L2: 0.0001, LR: 0.0025. dim: 32, dr1: 0.3, dr2: 0.1.
# Training F1: 0.2193877551020408, validation F1: 0.3103448275862069.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  200
# Save model of Epoch 1
# Loading model, best epoch: 1.
# Final training Accuracy: 0.15097159940209268, final validation Accuracy: 0.18617021276595744.
# Final training AUC: 0.396871704745167, final validation AUC: 0.4297173414820473.
# Final training F1: 0.23035230352303523, final validation F1: 0.28837209302325584.
# Total time elapse: 1.04.
# L2: 0.0001, LR: 0.0025. dim: 32, dr1: 0.3, dr2: 0.3.
# Training F1: 0.23035230352303523, validation F1: 0.28837209302325584.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Training F1: 0.0, validation F1: 0.0.
# Loading model, best epoch: 500.
# Final training Accuracy: 0.8505231689088192, final validation Accuracy: 0.8191489361702128.
# Final training AUC: 0.4186643233743409, final validation AUC: 0.4018334606569901.
# Final training F1: 0.0, final validation F1: 0.0.
# Total time elapse: 19.3.
# L2: 0.0001, LR: 0.0025. dim: 32, dr1: 0.3, dr2: 0.5.
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 20 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  261
# Save model of Epoch 62
# Loading model, best epoch: 62.
# Final training Accuracy: 0.8460388639760837, final validation Accuracy: 0.8351063829787234.
# Final training AUC: 0.6079789103690686, final validation AUC: 0.5958747135217722.
# Final training F1: 0.11965811965811966, final validation F1: 0.24390243902439024.
# Total time elapse: 1.81.
# L2: 0.0001, LR: 0.0025. dim: 32, dr1: 0.5, dr2: 0.1.
# Training F1: 0.11965811965811966, validation F1: 0.24390243902439024.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  200
# Save model of Epoch 1
# Loading model, best epoch: 1.
# Final training Accuracy: 0.7115097159940209, final validation Accuracy: 0.7180851063829787.
# Final training AUC: 0.5961159929701231, final validation AUC: 0.5844155844155844.
# Final training F1: 0.26053639846743293, final validation F1: 0.345679012345679.
# Total time elapse: 1.05.
# L2: 0.0001, LR: 0.0025. dim: 32, dr1: 0.5, dr2: 0.3.
# Training F1: 0.26053639846743293, validation F1: 0.345679012345679.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  213
# Save model of Epoch 14
# Loading model, best epoch: 14.
# Final training Accuracy: 0.7742899850523169, final validation Accuracy: 0.7872340425531915.
# Final training AUC: 0.530456942003515, final validation AUC: 0.5516615737203974.
# Final training F1: 0.17486338797814208, final validation F1: 0.16666666666666666.
# Total time elapse: 1.26.
# L2: 0.0001, LR: 0.0025. dim: 32, dr1: 0.5, dr2: 0.5.
# Training F1: 0.17486338797814208, validation F1: 0.16666666666666666.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 20 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# Training F1: 0.0, validation F1: 0.0.
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  271
# Save model of Epoch 72
# Loading model, best epoch: 72.
# Final training Accuracy: 0.5099183197199533, final validation Accuracy: 0.5621890547263682.
# Final training AUC: 0.5693007989100143, final validation AUC: 0.5721036585365853.
# Final training F1: 0.2682926829268293, final validation F1: 0.35294117647058826.
# Total time elapse: 1.78.
# Optimal L2: 0.001, optimal LR: 0.005, optimal dim: 8, optimal dr1: 0.3, optimal dr2: 0.1, best epoch number in tuning: 58.
# Optimal training f1: 0.4383561643835616, optimal validation F1: 0.29343629343629346.
# Testing phase: training Accuracy: 0.5099183197199533, testing Accuracy: 0.5621890547263682.
# Testing phase: training AUC: 0.5693007989100143, testing AUC: 0.5721036585365853.
# Testing phase: training F1: 0.2682926829268293, testing F1: 0.35294117647058826.
# --- 4400.010357379913 seconds ---

# %%
print("--- %s seconds ---" % (end_time - start_time))

# %%
#25-30 mins
