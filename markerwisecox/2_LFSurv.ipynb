# %%
import math
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.nn.init as init
import torch.optim as optim
import time
import lifelines
from lifelines.utils import concordance_index
from LFSurv import LFSurv
from utils import sort_data, load_data, R_set, neg_par_log_likelihood, c_index, EarlyStopping
from train_LFSurv import train_LFSurv

dtype = torch.FloatTensor
os.chdir('/cloud-home/U1039935/Autosurv/autostat')

# %%
data_tune_train = pd.read_csv("processed_data_example/TCGA_BRCA/tune/minmax_normalized/data_train_gene_minmax_tune.csv")
data_tune_valid = pd.read_csv("processed_data_example/TCGA_BRCA/tune/minmax_normalized/data_valid_gene_minmax_tune.csv")
data_train = pd.read_csv("processed_data_example/TCGA_BRCA/train_test_split/minmax_normalized/data_train_gene_minmax_overall.csv")
data_valid = pd.read_csv("processed_data_example/TCGA_BRCA/train_test_split/minmax_normalized/data_test_gene_minmax_overall.csv")

# %%
data_train.shape
# Out:
# (857, 2706)

# %%
select_gene =['patient_id', 'OS.time', 'OS', 'age', 'stage_i', 'stage_ii', 'race_white',
 'ENSG00000169764',
 'ENSG00000115380',
 'ENSG00000168216',
 'ENSG00000131080',
 'ENSG00000154734',
 'ENSG00000184005',
 'ENSG00000154727',
 'ENSG00000185010',
 'ENSG00000069431',
 'ENSG00000171056',
 'ENSG00000137693',
 'ENSG00000140285',
 'ENSG00000138686',
 'ENSG00000138640',
 'ENSG00000005020',
 'ENSG00000157557']

# %%
tune_tr = data_tune_train[select_gene]
tune_val = data_tune_valid[select_gene]
tr = data_train[select_gene]
val = data_valid[select_gene]
tune_tr = pd.DataFrame(tune_tr)
tune_val = pd.DataFrame(tune_val)
tr = pd.DataFrame(tr)
val = pd.DataFrame(val)
print(tune_tr.shape, tune_val.shape, tr.shape, val.shape)
# Out:
# (669, 23) (188, 23) (857, 23) (201, 23)

# %%
tune_tr.to_csv('tune_tr_z_2omics.csv', index = False)
tune_val.to_csv("tune_val_z_2omics.csv", index = False)
tr.to_csv('tr_z_2omics.csv', index = False)
val.to_csv('tes_z_2omics.csv', index = False)

# %%
# modify input_n based on optim model
input_n = 16
level_2_dim = [8, 16, 32]
epoch_num = 500
patience = 200
Initial_Learning_Rate = [0.05, 0.01, 0.0075, 0.005, 0.0025]
# Initial_Learning_Rate = [0.05, 0.0075, 0.0025]
L2_Lambda = [0.001, 0.00075, 0.0005, 0.00025, 0.0001]
# L2_Lambda = [0.001, 0.0005, 0.0001]
Dropout_rate_1 = [0.1, 0.3, 0.5]
Dropout_rate_2 = [0.1, 0.3, 0.5]

best_epoch_num = 0


patient_id_train, x_train, ytime_train, yevent_train, age_train, stage_i_train, stage_ii_train, race_white_train = load_data("tune_tr_z_2omics.csv", dtype)
patient_id_valid, x_valid, ytime_valid, yevent_valid, age_valid, stage_i_valid, stage_ii_valid, race_white_valid = load_data("tune_val_z_2omics.csv", dtype)

patient_id_train_overall, x_train_overall, ytime_train_overall, yevent_train_overall, age_train_overall, stage_i_train_overall, stage_ii_train_overall, race_white_train_overall = load_data("tr_z_2omics.csv", dtype)
patient_id_test_overall, x_test_overall, ytime_test_overall, yevent_test_overall, age_test_overall, stage_i_test_overall, stage_ii_test_overall, race_white_test_overall = load_data("tes_z_2omics.csv", dtype)

# %%
x_train.shape
# Out:
# torch.Size([669, 16])

# %%
import time

# %%
start_time = time.time()
opt_l2 = 0
opt_lr = 0
opt_dim = 0
opt_dr1 = 0
opt_dr2 = 0

opt_cindex_va = float(0)
opt_cindex_tr = float(0)
for l2 in L2_Lambda:
    for lr in Initial_Learning_Rate:
        for dim in level_2_dim:
            for dr1 in Dropout_rate_1:
                for dr2 in Dropout_rate_2:
                    _, _, cindex_train, cindex_valid, best_epoch_num_tune = train_LFSurv(x_train, age_train, stage_i_train, stage_ii_train, race_white_train, ytime_train, yevent_train,
                                                                                         x_valid, age_valid, stage_i_valid, stage_ii_valid, race_white_valid, ytime_valid, yevent_valid,
                                                                                         input_n, dim, dr1, dr2, lr, l2, epoch_num, patience, dtype,
                                                                                         path = "sup_checkpoint_tune.pt")
                    
                    if cindex_valid > opt_cindex_va:
                        opt_l2 = l2
                        opt_lr = lr
                        opt_dim = dim
                        opt_dr1 = dr1
                        opt_dr2 = dr2
                        opt_cindex_tr = cindex_train
                        opt_cindex_va = cindex_valid
                        best_epoch_num = best_epoch_num_tune
                    print("L2: %s," %l2, "LR: %s." %lr, "dim: %s," %dim, "dr1: %s," %dr1, "dr2: %s." %dr2)
                    print("Training C-index: %s," %cindex_train.round(4), "validation C-index: %s." %cindex_valid.round(4))
end_time = time.time()
print("--- %s seconds ---" % (end_time - start_time))
# Out:
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7568, validation C-index: 0.7159.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.7606, validation C-index: 0.6844.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  226
# Save model of Epoch 27
# Loading model, best epoch: 27.
# Final training C-index: 0.7633, final validation C-index: 0.7517.
# Total time elapse: 3.89.
# L2: 0.001, LR: 0.05. dim: 8, dr1: 0.1, dr2: 0.1.
# Training C-index: 0.7633, validation C-index: 0.7517.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.765, validation C-index: 0.7296.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.7604, validation C-index: 0.7002.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  231
# Save model of Epoch 32
# Loading model, best epoch: 32.
# Final training C-index: 0.7453, final validation C-index: 0.7538.
# Total time elapse: 1.22.
# L2: 0.001, LR: 0.05. dim: 8, dr1: 0.1, dr2: 0.3.
# Training C-index: 0.7453, validation C-index: 0.7538.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7691, validation C-index: 0.7142.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.7642, validation C-index: 0.7342.
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# Training C-index: 0.7635, validation C-index: 0.7287.
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7587, validation C-index: 0.727.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.7626, validation C-index: 0.7244.
# Loading model, best epoch: 328.
# Final training C-index: 0.7556, final validation C-index: 0.7632.
# Total time elapse: 2.57.
# L2: 0.001, LR: 0.05. dim: 8, dr1: 0.1, dr2: 0.5.
# Training C-index: 0.7556, validation C-index: 0.7632.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7484, validation C-index: 0.733.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training C-index: 0.7518, validation C-index: 0.7006.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  213
# Save model of Epoch 14
# Loading model, best epoch: 14.
# Final training C-index: 0.728, final validation C-index: 0.7645.
# Total time elapse: 1.14.
# L2: 0.001, LR: 0.05. dim: 8, dr1: 0.3, dr2: 0.1.
# Training C-index: 0.728, validation C-index: 0.7645.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7607, validation C-index: 0.7321.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.7624, validation C-index: 0.7164.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  237
# Save model of Epoch 38
# Loading model, best epoch: 38.
# Final training C-index: 0.7522, final validation C-index: 0.7491.
# Total time elapse: 1.15.
# L2: 0.001, LR: 0.05. dim: 8, dr1: 0.3, dr2: 0.3.
# Training C-index: 0.7522, validation C-index: 0.7491.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.7576, validation C-index: 0.7376.
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.745, validation C-index: 0.7296.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7578, validation C-index: 0.7372.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training C-index: 0.7552, validation C-index: 0.7368.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  409
# Save model of Epoch 210
# Loading model, best epoch: 210.
# Final training C-index: 0.7492, final validation C-index: 0.7534.
# Total time elapse: 2.04.
# L2: 0.001, LR: 0.05. dim: 8, dr1: 0.3, dr2: 0.5.
# Training C-index: 0.7492, validation C-index: 0.7534.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.753, validation C-index: 0.7351.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training C-index: 0.7603, validation C-index: 0.7291.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  215
# Save model of Epoch 16
# Loading model, best epoch: 16.
# Final training C-index: 0.7357, final validation C-index: 0.7713.
# Total time elapse: 1.37.
# L2: 0.001, LR: 0.05. dim: 8, dr1: 0.5, dr2: 0.1.
# Training C-index: 0.7357, validation C-index: 0.7713.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7621, validation C-index: 0.7232.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training C-index: 0.7622, validation C-index: 0.7342.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  204
# Save model of Epoch 5
# Loading model, best epoch: 5.
# Final training C-index: 0.6891, final validation C-index: 0.7581.
# Total time elapse: 1.01.
# L2: 0.001, LR: 0.05. dim: 8, dr1: 0.5, dr2: 0.3.
# Training C-index: 0.6891, validation C-index: 0.7581.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7565, validation C-index: 0.744.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# Training C-index: 0.7556, validation C-index: 0.727.
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  290
# Save model of Epoch 91
# Loading model, best epoch: 91.
# Final training C-index: 0.744, final validation C-index: 0.7581.
# Total time elapse: 1.48.
# L2: 0.001, LR: 0.05. dim: 8, dr1: 0.5, dr2: 0.5.
# Training C-index: 0.744, validation C-index: 0.7581.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7681, validation C-index: 0.7411.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training C-index: 0.7643, validation C-index: 0.744.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  219
# Save model of Epoch 20
# Loading model, best epoch: 20.
# Final training C-index: 0.7446, final validation C-index: 0.7636.
# Total time elapse: 1.26.
# L2: 0.001, LR: 0.05. dim: 16, dr1: 0.1, dr2: 0.1.
# Training C-index: 0.7446, validation C-index: 0.7636.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.7699, validation C-index: 0.7428.
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.7645, validation C-index: 0.7364.
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# Training C-index: 0.7713, validation C-index: 0.7342.
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  370
# Save model of Epoch 171
# Loading model, best epoch: 171.
# Final training C-index: 0.7493, final validation C-index: 0.7662.
# Total time elapse: 2.02.
# L2: 0.001, LR: 0.05. dim: 16, dr1: 0.1, dr2: 0.3.
# Training C-index: 0.7493, validation C-index: 0.7662.
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.7437, validation C-index: 0.7249.
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# Training C-index: 0.7596, validation C-index: 0.7394.
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  260
# Save model of Epoch 61
# Loading model, best epoch: 61.
# Final training C-index: 0.7497, final validation C-index: 0.7747.
# Total time elapse: 1.92.
# L2: 0.001, LR: 0.05. dim: 16, dr1: 0.1, dr2: 0.5.
# Training C-index: 0.7497, validation C-index: 0.7747.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7651, validation C-index: 0.7266.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training C-index: 0.7613, validation C-index: 0.71.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  217
# Save model of Epoch 18
# Loading model, best epoch: 18.
# Final training C-index: 0.7471, final validation C-index: 0.7594.
# Total time elapse: 1.09.
# L2: 0.001, LR: 0.05. dim: 16, dr1: 0.3, dr2: 0.1.
# Training C-index: 0.7471, validation C-index: 0.7594.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7605, validation C-index: 0.7296.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training C-index: 0.7569, validation C-index: 0.7402.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  219
# Save model of Epoch 20
# Loading model, best epoch: 20.
# Final training C-index: 0.7404, final validation C-index: 0.7666.
# Total time elapse: 1.27.
# L2: 0.001, LR: 0.05. dim: 16, dr1: 0.3, dr2: 0.3.
# Training C-index: 0.7404, validation C-index: 0.7666.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7558, validation C-index: 0.7342.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training C-index: 0.7609, validation C-index: 0.7236.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  218
# Save model of Epoch 19
# Loading model, best epoch: 19.
# Final training C-index: 0.7412, final validation C-index: 0.7628.
# Total time elapse: 1.06.
# L2: 0.001, LR: 0.05. dim: 16, dr1: 0.3, dr2: 0.5.
# Training C-index: 0.7412, validation C-index: 0.7628.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7573, validation C-index: 0.7347.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training C-index: 0.7603, validation C-index: 0.7291.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  217
# Save model of Epoch 18
# Loading model, best epoch: 18.
# Final training C-index: 0.7404, final validation C-index: 0.7666.
# Total time elapse: 1.27.
# L2: 0.001, LR: 0.05. dim: 16, dr1: 0.5, dr2: 0.1.
# Training C-index: 0.7404, validation C-index: 0.7666.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7512, validation C-index: 0.7325.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.7556, validation C-index: 0.7347.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  237
# Save model of Epoch 38
# Loading model, best epoch: 38.
# Final training C-index: 0.7403, final validation C-index: 0.7615.
# Total time elapse: 1.57.
# L2: 0.001, LR: 0.05. dim: 16, dr1: 0.5, dr2: 0.3.
# Training C-index: 0.7403, validation C-index: 0.7615.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7465, validation C-index: 0.756.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# Training C-index: 0.7601, validation C-index: 0.7151.
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  299
# Save model of Epoch 100
# Loading model, best epoch: 100.
# Final training C-index: 0.7465, final validation C-index: 0.756.
# Total time elapse: 1.58.
# L2: 0.001, LR: 0.05. dim: 16, dr1: 0.5, dr2: 0.5.
# Training C-index: 0.7465, validation C-index: 0.756.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7734, validation C-index: 0.7049.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training C-index: 0.7766, validation C-index: 0.6955.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  212
# Save model of Epoch 13
# Loading model, best epoch: 13.
# Final training C-index: 0.7441, final validation C-index: 0.756.
# Total time elapse: 1.11.
# L2: 0.001, LR: 0.05. dim: 32, dr1: 0.1, dr2: 0.1.
# Training C-index: 0.7441, validation C-index: 0.756.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7647, validation C-index: 0.7308.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training C-index: 0.7509, validation C-index: 0.7091.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  210
# Save model of Epoch 11
# Loading model, best epoch: 11.
# Final training C-index: 0.7532, final validation C-index: 0.756.
# Total time elapse: 1.02.
# L2: 0.001, LR: 0.05. dim: 32, dr1: 0.1, dr2: 0.3.
# Training C-index: 0.7532, validation C-index: 0.756.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7575, validation C-index: 0.7419.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.7639, validation C-index: 0.7261.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  236
# Save model of Epoch 37
# Loading model, best epoch: 37.
# Final training C-index: 0.7485, final validation C-index: 0.7658.
# Total time elapse: 1.24.
# L2: 0.001, LR: 0.05. dim: 32, dr1: 0.1, dr2: 0.5.
# Training C-index: 0.7485, validation C-index: 0.7658.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7646, validation C-index: 0.7227.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training C-index: 0.7614, validation C-index: 0.7206.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  204
# Save model of Epoch 5
# Loading model, best epoch: 5.
# Final training C-index: 0.733, final validation C-index: 0.7726.
# Total time elapse: 1.0.
# L2: 0.001, LR: 0.05. dim: 32, dr1: 0.3, dr2: 0.1.
# Training C-index: 0.733, validation C-index: 0.7726.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7582, validation C-index: 0.7283.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training C-index: 0.7653, validation C-index: 0.7151.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  214
# Save model of Epoch 15
# Loading model, best epoch: 15.
# Final training C-index: 0.7425, final validation C-index: 0.7594.
# Total time elapse: 1.06.
# L2: 0.001, LR: 0.05. dim: 32, dr1: 0.3, dr2: 0.3.
# Training C-index: 0.7425, validation C-index: 0.7594.
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.7632, validation C-index: 0.7296.
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# Training C-index: 0.7587, validation C-index: 0.7376.
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.754, validation C-index: 0.7249.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training C-index: 0.7577, validation C-index: 0.7436.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  410
# Save model of Epoch 211
# Loading model, best epoch: 211.
# Final training C-index: 0.7479, final validation C-index: 0.7551.
# Total time elapse: 2.29.
# L2: 0.001, LR: 0.05. dim: 32, dr1: 0.3, dr2: 0.5.
# Training C-index: 0.7479, validation C-index: 0.7551.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7629, validation C-index: 0.7155.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training C-index: 0.76, validation C-index: 0.7304.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  213
# Save model of Epoch 14
# Loading model, best epoch: 14.
# Final training C-index: 0.7344, final validation C-index: 0.7636.
# Total time elapse: 1.13.
# L2: 0.001, LR: 0.05. dim: 32, dr1: 0.5, dr2: 0.1.
# Training C-index: 0.7344, validation C-index: 0.7636.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7553, validation C-index: 0.7138.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training C-index: 0.7617, validation C-index: 0.73.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  207
# Save model of Epoch 8
# Loading model, best epoch: 8.
# Final training C-index: 0.7208, final validation C-index: 0.7589.
# Total time elapse: 1.0.
# L2: 0.001, LR: 0.05. dim: 32, dr1: 0.5, dr2: 0.3.
# Training C-index: 0.7208, validation C-index: 0.7589.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7621, validation C-index: 0.7334.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.7615, validation C-index: 0.7338.
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# Training C-index: 0.7594, validation C-index: 0.7385.
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  364
# Save model of Epoch 165
# Loading model, best epoch: 165.
# Final training C-index: 0.7419, final validation C-index: 0.7547.
# Total time elapse: 1.87.
# L2: 0.001, LR: 0.05. dim: 32, dr1: 0.5, dr2: 0.5.
# Training C-index: 0.7419, validation C-index: 0.7547.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.77, validation C-index: 0.7253.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.7716, validation C-index: 0.7368.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# Training C-index: 0.7827, validation C-index: 0.7296.
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  390
# Save model of Epoch 191
# Loading model, best epoch: 191.
# Final training C-index: 0.7747, final validation C-index: 0.7538.
# Total time elapse: 2.14.
# L2: 0.001, LR: 0.01. dim: 8, dr1: 0.1, dr2: 0.1.
# Training C-index: 0.7747, validation C-index: 0.7538.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.7686, validation C-index: 0.7308.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# Training C-index: 0.7644, validation C-index: 0.7164.
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  297
# Save model of Epoch 98
# Loading model, best epoch: 98.
# Final training C-index: 0.7681, final validation C-index: 0.7342.
# Total time elapse: 1.68.
# L2: 0.001, LR: 0.01. dim: 8, dr1: 0.1, dr2: 0.3.
# Training C-index: 0.7681, validation C-index: 0.7342.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.7649, validation C-index: 0.7151.
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# Training C-index: 0.7667, validation C-index: 0.7227.
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  279
# Save model of Epoch 80
# Loading model, best epoch: 80.
# Final training C-index: 0.7688, final validation C-index: 0.7368.
# Total time elapse: 1.69.
# L2: 0.001, LR: 0.01. dim: 8, dr1: 0.1, dr2: 0.5.
# Training C-index: 0.7688, validation C-index: 0.7368.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7624, validation C-index: 0.7364.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.7613, validation C-index: 0.7317.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  235
# Save model of Epoch 36
# Loading model, best epoch: 36.
# Final training C-index: 0.736, final validation C-index: 0.7721.
# Total time elapse: 1.92.
# L2: 0.001, LR: 0.01. dim: 8, dr1: 0.3, dr2: 0.1.
# Training C-index: 0.736, validation C-index: 0.7721.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7608, validation C-index: 0.7074.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7628, validation C-index: 0.7313.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.7641, validation C-index: 0.7219.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  326
# Save model of Epoch 127
# Loading model, best epoch: 127.
# Final training C-index: 0.7612, final validation C-index: 0.7432.
# Total time elapse: 1.7.
# L2: 0.001, LR: 0.01. dim: 8, dr1: 0.3, dr2: 0.3.
# Training C-index: 0.7612, validation C-index: 0.7432.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.7568, validation C-index: 0.7244.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.762, validation C-index: 0.7334.
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# Training C-index: 0.7632, validation C-index: 0.7249.
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  377
# Save model of Epoch 178
# Loading model, best epoch: 178.
# Final training C-index: 0.7628, final validation C-index: 0.7423.
# Total time elapse: 2.21.
# L2: 0.001, LR: 0.01. dim: 8, dr1: 0.3, dr2: 0.5.
# Training C-index: 0.7628, validation C-index: 0.7423.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7613, validation C-index: 0.7317.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.7623, validation C-index: 0.721.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  235
# Save model of Epoch 36
# Loading model, best epoch: 36.
# Final training C-index: 0.7409, final validation C-index: 0.7606.
# Total time elapse: 1.29.
# L2: 0.001, LR: 0.01. dim: 8, dr1: 0.5, dr2: 0.1.
# Training C-index: 0.7409, validation C-index: 0.7606.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7575, validation C-index: 0.7108.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training C-index: 0.7614, validation C-index: 0.7347.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  200
# Save model of Epoch 1
# Loading model, best epoch: 1.
# Final training C-index: 0.6629, final validation C-index: 0.7679.
# Total time elapse: 0.95.
# L2: 0.001, LR: 0.01. dim: 8, dr1: 0.5, dr2: 0.3.
# Training C-index: 0.6629, validation C-index: 0.7679.
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.7543, validation C-index: 0.7112.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.7605, validation C-index: 0.7257.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.7604, validation C-index: 0.7338.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# Training C-index: 0.7605, validation C-index: 0.7227.
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  496
# Save model of Epoch 297
# Loading model, best epoch: 297.
# Final training C-index: 0.7596, final validation C-index: 0.7385.
# Total time elapse: 3.35.
# L2: 0.001, LR: 0.01. dim: 8, dr1: 0.5, dr2: 0.5.
# Training C-index: 0.7596, validation C-index: 0.7385.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7747, validation C-index: 0.7325.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.7861, validation C-index: 0.7364.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  223
# Save model of Epoch 24
# Loading model, best epoch: 24.
# Final training C-index: 0.7487, final validation C-index: 0.7594.
# Total time elapse: 1.31.
# L2: 0.001, LR: 0.01. dim: 16, dr1: 0.1, dr2: 0.1.
# Training C-index: 0.7487, validation C-index: 0.7594.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7689, validation C-index: 0.7266.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.7743, validation C-index: 0.7219.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  230
# Save model of Epoch 31
# Loading model, best epoch: 31.
# Final training C-index: 0.7545, final validation C-index: 0.7547.
# Total time elapse: 1.51.
# L2: 0.001, LR: 0.01. dim: 16, dr1: 0.1, dr2: 0.3.
# Training C-index: 0.7545, validation C-index: 0.7547.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7612, validation C-index: 0.7078.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# Training C-index: 0.7633, validation C-index: 0.7266.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# Training C-index: 0.7687, validation C-index: 0.7193.
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  382
# Save model of Epoch 183
# Loading model, best epoch: 183.
# Final training C-index: 0.7682, final validation C-index: 0.7406.
# Total time elapse: 2.04.
# L2: 0.001, LR: 0.01. dim: 16, dr1: 0.1, dr2: 0.5.
# Training C-index: 0.7682, validation C-index: 0.7406.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.7627, validation C-index: 0.7168.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# Training C-index: 0.7666, validation C-index: 0.7308.
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.7681, validation C-index: 0.7372.
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# Training C-index: 0.7804, validation C-index: 0.7138.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# Training C-index: 0.7865, validation C-index: 0.7138.
# Loading model, best epoch: 394.
# Final training C-index: 0.7684, final validation C-index: 0.7509.
# Total time elapse: 3.01.
# L2: 0.001, LR: 0.01. dim: 16, dr1: 0.3, dr2: 0.1.
# Training C-index: 0.7684, validation C-index: 0.7509.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.7604, validation C-index: 0.7279.
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# Training C-index: 0.76, validation C-index: 0.7279.
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  268
# Save model of Epoch 69
# Loading model, best epoch: 69.
# Final training C-index: 0.7561, final validation C-index: 0.7462.
# Total time elapse: 1.55.
# L2: 0.001, LR: 0.01. dim: 16, dr1: 0.3, dr2: 0.3.
# Training C-index: 0.7561, validation C-index: 0.7462.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.7596, validation C-index: 0.7223.
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.76, validation C-index: 0.7334.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7633, validation C-index: 0.7321.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# Training C-index: 0.7629, validation C-index: 0.7274.
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  487
# Save model of Epoch 288
# Loading model, best epoch: 288.
# Final training C-index: 0.7613, final validation C-index: 0.7432.
# Total time elapse: 2.53.
# L2: 0.001, LR: 0.01. dim: 16, dr1: 0.3, dr2: 0.5.
# Training C-index: 0.7613, validation C-index: 0.7432.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7588, validation C-index: 0.7351.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.7613, validation C-index: 0.7321.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  230
# Save model of Epoch 31
# Loading model, best epoch: 31.
# Final training C-index: 0.7342, final validation C-index: 0.7666.
# Total time elapse: 1.24.
# L2: 0.001, LR: 0.01. dim: 16, dr1: 0.5, dr2: 0.1.
# Training C-index: 0.7342, validation C-index: 0.7666.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7577, validation C-index: 0.7019.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training C-index: 0.7602, validation C-index: 0.7347.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  205
# Save model of Epoch 6
# Loading model, best epoch: 6.
# Final training C-index: 0.6883, final validation C-index: 0.7568.
# Total time elapse: 0.97.
# L2: 0.001, LR: 0.01. dim: 16, dr1: 0.5, dr2: 0.3.
# Training C-index: 0.6883, validation C-index: 0.7568.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.7569, validation C-index: 0.7266.
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# Training C-index: 0.7619, validation C-index: 0.7227.
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  259
# Save model of Epoch 60
# Loading model, best epoch: 60.
# Final training C-index: 0.7514, final validation C-index: 0.7513.
# Total time elapse: 1.76.
# L2: 0.001, LR: 0.01. dim: 16, dr1: 0.5, dr2: 0.5.
# Training C-index: 0.7514, validation C-index: 0.7513.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7845, validation C-index: 0.7338.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.8113, validation C-index: 0.721.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.8174, validation C-index: 0.747.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.8373, validation C-index: 0.7385.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.8546, validation C-index: 0.7074.
# Loading model, best epoch: 321.
# Final training C-index: 0.8194, final validation C-index: 0.7598.
# Total time elapse: 2.73.
# L2: 0.001, LR: 0.01. dim: 32, dr1: 0.1, dr2: 0.1.
# Training C-index: 0.8194, validation C-index: 0.7598.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7692, validation C-index: 0.7266.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.7748, validation C-index: 0.7249.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  228
# Save model of Epoch 29
# Loading model, best epoch: 29.
# Final training C-index: 0.7532, final validation C-index: 0.7547.
# Total time elapse: 1.31.
# L2: 0.001, LR: 0.01. dim: 32, dr1: 0.1, dr2: 0.3.
# Training C-index: 0.7532, validation C-index: 0.7547.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7715, validation C-index: 0.7296.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training C-index: 0.7698, validation C-index: 0.7202.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  201
# Save model of Epoch 2
# Loading model, best epoch: 2.
# Final training C-index: 0.6459, final validation C-index: 0.7547.
# Total time elapse: 0.9.
# L2: 0.001, LR: 0.01. dim: 32, dr1: 0.1, dr2: 0.5.
# Training C-index: 0.6459, validation C-index: 0.7547.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7574, validation C-index: 0.6912.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.7646, validation C-index: 0.7423.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  227
# Save model of Epoch 28
# Loading model, best epoch: 28.
# Final training C-index: 0.7537, final validation C-index: 0.7555.
# Total time elapse: 1.3.
# L2: 0.001, LR: 0.01. dim: 32, dr1: 0.3, dr2: 0.1.
# Training C-index: 0.7537, validation C-index: 0.7555.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.7582, validation C-index: 0.7415.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# Training C-index: 0.764, validation C-index: 0.7266.
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  289
# Save model of Epoch 90
# Loading model, best epoch: 90.
# Final training C-index: 0.7599, final validation C-index: 0.7466.
# Total time elapse: 1.67.
# L2: 0.001, LR: 0.01. dim: 32, dr1: 0.3, dr2: 0.3.
# Training C-index: 0.7599, validation C-index: 0.7466.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.7582, validation C-index: 0.7223.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7628, validation C-index: 0.7244.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.76, validation C-index: 0.7347.
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# Training C-index: 0.7601, validation C-index: 0.7342.
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  461
# Save model of Epoch 262
# Loading model, best epoch: 262.
# Final training C-index: 0.7615, final validation C-index: 0.7398.
# Total time elapse: 2.79.
# L2: 0.001, LR: 0.01. dim: 32, dr1: 0.3, dr2: 0.5.
# Training C-index: 0.7615, validation C-index: 0.7398.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7618, validation C-index: 0.7066.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.7628, validation C-index: 0.7244.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  236
# Save model of Epoch 37
# Loading model, best epoch: 37.
# Final training C-index: 0.757, final validation C-index: 0.7491.
# Total time elapse: 1.23.
# L2: 0.001, LR: 0.01. dim: 32, dr1: 0.5, dr2: 0.1.
# Training C-index: 0.757, validation C-index: 0.7491.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.762, validation C-index: 0.7202.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training C-index: 0.7624, validation C-index: 0.7189.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  208
# Save model of Epoch 9
# Loading model, best epoch: 9.
# Final training C-index: 0.7008, final validation C-index: 0.7589.
# Total time elapse: 0.99.
# L2: 0.001, LR: 0.01. dim: 32, dr1: 0.5, dr2: 0.3.
# Training C-index: 0.7008, validation C-index: 0.7589.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.7607, validation C-index: 0.7172.
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# Training C-index: 0.761, validation C-index: 0.7168.
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  241
# Save model of Epoch 42
# Loading model, best epoch: 42.
# Final training C-index: 0.7442, final validation C-index: 0.7602.
# Total time elapse: 1.45.
# L2: 0.001, LR: 0.01. dim: 32, dr1: 0.5, dr2: 0.5.
# Training C-index: 0.7442, validation C-index: 0.7602.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7733, validation C-index: 0.7193.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.7787, validation C-index: 0.7223.
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# ...
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# Training C-index: 0.7713, validation C-index: 0.721.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.771, validation C-index: 0.7227.
# Loading model, best epoch: 409.
# Final training C-index: 0.7716, final validation C-index: 0.7321.
# Total time elapse: 4.19.
# L2: 0.0001, LR: 0.0025. dim: 16, dr1: 0.1, dr2: 0.5.
# Training C-index: 0.7716, validation C-index: 0.7321.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.7612, validation C-index: 0.7351.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7627, validation C-index: 0.7095.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7684, validation C-index: 0.7428.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7687, validation C-index: 0.7445.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.7685, validation C-index: 0.7411.
# Loading model, best epoch: 444.
# Final training C-index: 0.7674, final validation C-index: 0.7594.
# Total time elapse: 3.73.
# L2: 0.0001, LR: 0.0025. dim: 16, dr1: 0.3, dr2: 0.1.
# Training C-index: 0.7674, validation C-index: 0.7594.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.752, validation C-index: 0.7394.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.7637, validation C-index: 0.7155.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  223
# Save model of Epoch 24
# Loading model, best epoch: 24.
# Final training C-index: 0.7034, final validation C-index: 0.7457.
# Total time elapse: 1.2.
# L2: 0.0001, LR: 0.0025. dim: 16, dr1: 0.3, dr2: 0.3.
# Training C-index: 0.7034, validation C-index: 0.7457.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7458, validation C-index: 0.7129.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7609, validation C-index: 0.7095.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.7621, validation C-index: 0.7249.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  328
# Save model of Epoch 129
# Loading model, best epoch: 129.
# Final training C-index: 0.7587, final validation C-index: 0.7321.
# Total time elapse: 2.56.
# L2: 0.0001, LR: 0.0025. dim: 16, dr1: 0.3, dr2: 0.5.
# Training C-index: 0.7587, validation C-index: 0.7321.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.757, validation C-index: 0.7053.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training C-index: 0.7618, validation C-index: 0.7257.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  205
# Save model of Epoch 6
# Loading model, best epoch: 6.
# Final training C-index: 0.6991, final validation C-index: 0.7572.
# Total time elapse: 1.11.
# L2: 0.0001, LR: 0.0025. dim: 16, dr1: 0.5, dr2: 0.1.
# Training C-index: 0.6991, validation C-index: 0.7572.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7441, validation C-index: 0.7334.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7617, validation C-index: 0.7206.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training C-index: 0.7631, validation C-index: 0.7236.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  311
# Save model of Epoch 112
# Loading model, best epoch: 112.
# Final training C-index: 0.7535, final validation C-index: 0.7466.
# Total time elapse: 2.06.
# L2: 0.0001, LR: 0.0025. dim: 16, dr1: 0.5, dr2: 0.3.
# Training C-index: 0.7535, validation C-index: 0.7466.
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.7479, validation C-index: 0.7087.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7598, validation C-index: 0.7193.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.7613, validation C-index: 0.7236.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  337
# Save model of Epoch 138
# Loading model, best epoch: 138.
# Final training C-index: 0.7567, final validation C-index: 0.7321.
# Total time elapse: 3.12.
# L2: 0.0001, LR: 0.0025. dim: 16, dr1: 0.5, dr2: 0.5.
# Training C-index: 0.7567, validation C-index: 0.7321.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.7707, validation C-index: 0.7428.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7848, validation C-index: 0.7402.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.807, validation C-index: 0.7479.
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.8223, validation C-index: 0.7521.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.8376, validation C-index: 0.7436.
# Loading model, best epoch: 470.
# Final training C-index: 0.8312, final validation C-index: 0.7611.
# Total time elapse: 3.73.
# L2: 0.0001, LR: 0.0025. dim: 32, dr1: 0.1, dr2: 0.1.
# Training C-index: 0.8312, validation C-index: 0.7611.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7609, validation C-index: 0.7134.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7755, validation C-index: 0.7193.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.7744, validation C-index: 0.7296.
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.7793, validation C-index: 0.7164.
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# Training C-index: 0.7826, validation C-index: 0.7283.
# Loading model, best epoch: 379.
# Final training C-index: 0.7779, final validation C-index: 0.7449.
# Total time elapse: 2.6.
# L2: 0.0001, LR: 0.0025. dim: 32, dr1: 0.1, dr2: 0.3.
# Training C-index: 0.7779, validation C-index: 0.7449.
# Training C-index: 0.7479, validation C-index: 0.7181.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7725, validation C-index: 0.7304.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.7667, validation C-index: 0.7078.
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# Training C-index: 0.7716, validation C-index: 0.7147.
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  446
# Save model of Epoch 247
# Loading model, best epoch: 247.
# Final training C-index: 0.7707, final validation C-index: 0.7347.
# Total time elapse: 5.24.
# L2: 0.0001, LR: 0.0025. dim: 32, dr1: 0.1, dr2: 0.5.
# Training C-index: 0.7707, validation C-index: 0.7347.
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.7664, validation C-index: 0.7291.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.7676, validation C-index: 0.7334.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.7733, validation C-index: 0.7351.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.7797, validation C-index: 0.7411.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# Training C-index: 0.7866, validation C-index: 0.7445.
# Loading model, best epoch: 381.
# Final training C-index: 0.7773, final validation C-index: 0.7606.
# Total time elapse: 4.16.
# L2: 0.0001, LR: 0.0025. dim: 32, dr1: 0.3, dr2: 0.1.
# Training C-index: 0.7773, validation C-index: 0.7606.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.7557, validation C-index: 0.7206.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# Training C-index: 0.7644, validation C-index: 0.7355.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.7663, validation C-index: 0.7142.
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.767, validation C-index: 0.7368.
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.7687, validation C-index: 0.7364.
# Loading model, best epoch: 478.
# Final training C-index: 0.7674, final validation C-index: 0.7462.
# Total time elapse: 3.65.
# L2: 0.0001, LR: 0.0025. dim: 32, dr1: 0.3, dr2: 0.3.
# Training C-index: 0.7674, validation C-index: 0.7462.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.75, validation C-index: 0.7266.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.756, validation C-index: 0.701.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training C-index: 0.7644, validation C-index: 0.7283.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.7632, validation C-index: 0.7296.
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7665, validation C-index: 0.7313.
# Loading model, best epoch: 435.
# Final training C-index: 0.7656, final validation C-index: 0.7372.
# Total time elapse: 3.18.
# L2: 0.0001, LR: 0.0025. dim: 32, dr1: 0.3, dr2: 0.5.
# Training C-index: 0.7656, validation C-index: 0.7372.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7589, validation C-index: 0.7462.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# Training C-index: 0.7613, validation C-index: 0.7406.
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  299
# Save model of Epoch 100
# Loading model, best epoch: 100.
# Final training C-index: 0.7589, final validation C-index: 0.7462.
# Total time elapse: 1.62.
# L2: 0.0001, LR: 0.0025. dim: 32, dr1: 0.5, dr2: 0.1.
# Training C-index: 0.7589, validation C-index: 0.7462.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7547, validation C-index: 0.7321.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# Training C-index: 0.7606, validation C-index: 0.7274.
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  292
# Save model of Epoch 93
# Loading model, best epoch: 93.
# Final training C-index: 0.7474, final validation C-index: 0.7483.
# Total time elapse: 2.01.
# L2: 0.0001, LR: 0.0025. dim: 32, dr1: 0.5, dr2: 0.3.
# Training C-index: 0.7474, validation C-index: 0.7483.
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.7468, validation C-index: 0.7215.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7603, validation C-index: 0.7134.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training C-index: 0.7612, validation C-index: 0.7206.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  316
# Save model of Epoch 117
# Loading model, best epoch: 117.
# Final training C-index: 0.7565, final validation C-index: 0.7449.
# Total time elapse: 3.48.
# L2: 0.0001, LR: 0.0025. dim: 32, dr1: 0.5, dr2: 0.5.
# Training C-index: 0.7565, validation C-index: 0.7449.
# --- 1375.6601901054382 seconds ---

# %%
print("--- %s seconds ---" % (end_time - start_time))
# Out:
# --- 1375.6601901054382 seconds ---

# %%
train_y_pred, test_y_pred, cindex_train, cindex_test, best_epoch_num_overall = train_LFSurv(x_train_overall, age_train_overall, stage_i_train_overall, stage_ii_train_overall, race_white_train_overall, ytime_train_overall, yevent_train_overall,
                                                                                            x_test_overall, age_test_overall, stage_i_test_overall, stage_ii_test_overall, race_white_test_overall, ytime_test_overall, yevent_test_overall,
                                                                                            input_n, opt_dim, opt_dr1, opt_dr2, opt_lr, opt_l2, epoch_num, patience, dtype,
                                                                                            path = "sup_checkpoint_overall.pt")
print("Optimal L2: %s," %opt_l2, "optimal LR: %s," %opt_lr, "optimal dim: %s," %opt_dim, "optimal dr1: %s," %opt_dr1, "optimal dr2: %s," %opt_dr2, "best epoch number in tuning: %s." %best_epoch_num)
print("Optimal training C-index: %s," %opt_cindex_tr.round(4), "optimal validation C-index: %s." %opt_cindex_va.round(4))
print("Testing phase: training C-index: %s," %cindex_train.round(4), "testing C-index: %s." %cindex_test.round(4))
# Out:
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.7494, validation C-index: 0.6628.
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.7513, validation C-index: 0.6655.
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.7567, validation C-index: 0.6652.
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.7635, validation C-index: 0.6754.
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# Training C-index: 0.7664, validation C-index: 0.6745.
# Loading model, best epoch: 362.
# Final training C-index: 0.7643, final validation C-index: 0.6865.
# Total time elapse: 4.32.
# Optimal L2: 0.0005, optimal LR: 0.0075, optimal dim: 32, optimal dr1: 0.1, optimal dr2: 0.5, best epoch number in tuning: 2.
# Optimal training C-index: 0.712, optimal validation C-index: 0.7973.
# Testing phase: training C-index: 0.7643, testing C-index: 0.6865.
