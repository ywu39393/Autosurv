# %%
import math
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.nn.init as init
import torch.optim as optim
import time
import lifelines
from lifelines.utils import concordance_index
from LFSurv import LFSurv
from utils import sort_data, load_data, R_set, neg_par_log_likelihood, c_index, EarlyStopping
from train_LFSurv import train_LFSurv

dtype = torch.FloatTensor
os.chdir('/cloud-home/U1039935/Autosurv/autostat')

# %%
data_tune_train = pd.read_csv("processed_data_example/TCGA_BRCA/tune/minmax_normalized/data_train_gene_minmax_tune.csv")
data_tune_valid = pd.read_csv("processed_data_example/TCGA_BRCA/tune/minmax_normalized/data_valid_gene_minmax_tune.csv")
data_train = pd.read_csv("processed_data_example/TCGA_BRCA/train_test_split/minmax_normalized/data_train_gene_minmax_overall.csv")
data_valid = pd.read_csv("processed_data_example/TCGA_BRCA/train_test_split/minmax_normalized/data_test_gene_minmax_overall.csv")

# %%
data_train.shape
# Out:
# (857, 2706)

# %%
select_gene =['patient_id', 'OS.time', 'OS', 'age', 'stage_i', 'stage_ii', 'race_white',
 'ENSG00000169764',
 'ENSG00000115380',
 'ENSG00000168216',
 'ENSG00000131080',
 'ENSG00000154734',
 'ENSG00000184005',
 'ENSG00000154727',
 'ENSG00000185010',
 'ENSG00000069431',
 'ENSG00000171056',
 'ENSG00000137693',
 'ENSG00000140285',
 'ENSG00000138686',
 'ENSG00000138640',
 'ENSG00000005020',
 'ENSG00000157557']

# %%
tune_tr = data_tune_train[select_gene]
tune_val = data_tune_valid[select_gene]
tr = data_train[select_gene]
val = data_valid[select_gene]
tune_tr = pd.DataFrame(tune_tr)
tune_val = pd.DataFrame(tune_val)
tr = pd.DataFrame(tr)
val = pd.DataFrame(val)
print(tune_tr.shape, tune_val.shape, tr.shape, val.shape)
# Out:
# (669, 23) (188, 23) (857, 23) (201, 23)

# %%
tune_tr.to_csv('tune_tr_z_2omics.csv', index = False)
tune_val.to_csv("tune_val_z_2omics.csv", index = False)
tr.to_csv('tr_z_2omics.csv', index = False)
val.to_csv('tes_z_2omics.csv', index = False)

# %%
# modify input_n based on optim model
input_n = 16
level_2_dim = [8, 16, 32]
epoch_num = 500
patience = 200
Initial_Learning_Rate = [0.05, 0.01, 0.0075, 0.005, 0.0025]
# Initial_Learning_Rate = [0.05, 0.0075, 0.0025]
L2_Lambda = [0.001, 0.00075, 0.0005, 0.00025, 0.0001]
# L2_Lambda = [0.001, 0.0005, 0.0001]
Dropout_rate_1 = [0.1, 0.3, 0.5]
Dropout_rate_2 = [0.1, 0.3, 0.5]

best_epoch_num = 0


patient_id_train, x_train, ytime_train, yevent_train, age_train, stage_i_train, stage_ii_train, race_white_train = load_data("tune_tr_z_2omics.csv", dtype)
patient_id_valid, x_valid, ytime_valid, yevent_valid, age_valid, stage_i_valid, stage_ii_valid, race_white_valid = load_data("tune_val_z_2omics.csv", dtype)

patient_id_train_overall, x_train_overall, ytime_train_overall, yevent_train_overall, age_train_overall, stage_i_train_overall, stage_ii_train_overall, race_white_train_overall = load_data("tr_z_2omics.csv", dtype)
patient_id_test_overall, x_test_overall, ytime_test_overall, yevent_test_overall, age_test_overall, stage_i_test_overall, stage_ii_test_overall, race_white_test_overall = load_data("tes_z_2omics.csv", dtype)

# %%
x_train.shape
# Out:
# torch.Size([669, 16])

# %%
import time

# %%
start_time = time.time()
opt_l2 = 0
opt_lr = 0
opt_dim = 0
opt_dr1 = 0
opt_dr2 = 0

opt_cindex_va = float(0)
opt_cindex_tr = float(0)
for l2 in L2_Lambda:
    for lr in Initial_Learning_Rate:
        for dim in level_2_dim:
            for dr1 in Dropout_rate_1:
                for dr2 in Dropout_rate_2:
                    _, _, cindex_train, cindex_valid, best_epoch_num_tune = train_LFSurv(x_train, age_train, stage_i_train, stage_ii_train, race_white_train, ytime_train, yevent_train,
                                                                                         x_valid, age_valid, stage_i_valid, stage_ii_valid, race_white_valid, ytime_valid, yevent_valid,
                                                                                         input_n, dim, dr1, dr2, lr, l2, epoch_num, patience, dtype,
                                                                                         path = "sup_checkpoint_tune.pt")
                    
                    if cindex_valid > opt_cindex_va:
                        opt_l2 = l2
                        opt_lr = lr
                        opt_dim = dim
                        opt_dr1 = dr1
                        opt_dr2 = dr2
                        opt_cindex_tr = cindex_train
                        opt_cindex_va = cindex_valid
                        best_epoch_num = best_epoch_num_tune
                    print("L2: %s," %l2, "LR: %s." %lr, "dim: %s," %dim, "dr1: %s," %dr1, "dr2: %s." %dr2)
                    print("Training C-index: %s," %cindex_train.round(4), "validation C-index: %s." %cindex_valid.round(4))
end_time = time.time()
print("--- %s seconds ---" % (end_time - start_time))
# Out:
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7704, validation C-index: 0.73.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training C-index: 0.7776, validation C-index: 0.7261.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  211
# Save model of Epoch 12
# Loading model, best epoch: 12.
# Final training C-index: 0.7221, final validation C-index: 0.776.
# Total time elapse: 1.11.
# L2: 0.001, LR: 0.05. dim: 8, dr1: 0.1, dr2: 0.1.
# Training C-index: 0.7221, validation C-index: 0.776.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.763, validation C-index: 0.7261.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.7728, validation C-index: 0.7338.
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# Training C-index: 0.769, validation C-index: 0.7334.
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.7698, validation C-index: 0.7164.
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# Training C-index: 0.7612, validation C-index: 0.7428.
# Loading model, best epoch: 351.
# Final training C-index: 0.7518, final validation C-index: 0.7709.
# Total time elapse: 2.68.
# L2: 0.001, LR: 0.05. dim: 8, dr1: 0.1, dr2: 0.3.
# Training C-index: 0.7518, validation C-index: 0.7709.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7547, validation C-index: 0.7432.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.7521, validation C-index: 0.7313.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  231
# Save model of Epoch 32
# Loading model, best epoch: 32.
# Final training C-index: 0.7408, final validation C-index: 0.7572.
# Total time elapse: 1.17.
# L2: 0.001, LR: 0.05. dim: 8, dr1: 0.1, dr2: 0.5.
# Training C-index: 0.7408, validation C-index: 0.7572.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7629, validation C-index: 0.7176.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.7593, validation C-index: 0.7176.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  221
# Save model of Epoch 22
# Loading model, best epoch: 22.
# Final training C-index: 0.7407, final validation C-index: 0.7589.
# Total time elapse: 1.16.
# L2: 0.001, LR: 0.05. dim: 8, dr1: 0.3, dr2: 0.1.
# Training C-index: 0.7407, validation C-index: 0.7589.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7601, validation C-index: 0.7266.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.7604, validation C-index: 0.7334.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  221
# Save model of Epoch 22
# Loading model, best epoch: 22.
# Final training C-index: 0.744, final validation C-index: 0.7636.
# Total time elapse: 1.25.
# L2: 0.001, LR: 0.05. dim: 8, dr1: 0.3, dr2: 0.3.
# Training C-index: 0.744, validation C-index: 0.7636.
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.7483, validation C-index: 0.7368.
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# Training C-index: 0.7572, validation C-index: 0.7415.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7585, validation C-index: 0.7432.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.7619, validation C-index: 0.7368.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  427
# Save model of Epoch 228
# Loading model, best epoch: 228.
# Final training C-index: 0.7608, final validation C-index: 0.75.
# Total time elapse: 2.59.
# L2: 0.001, LR: 0.05. dim: 8, dr1: 0.3, dr2: 0.5.
# Training C-index: 0.7608, validation C-index: 0.75.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7621, validation C-index: 0.7376.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training C-index: 0.7593, validation C-index: 0.7368.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  211
# Save model of Epoch 12
# Loading model, best epoch: 12.
# Final training C-index: 0.7344, final validation C-index: 0.7785.
# Total time elapse: 1.18.
# L2: 0.001, LR: 0.05. dim: 8, dr1: 0.5, dr2: 0.1.
# Training C-index: 0.7344, validation C-index: 0.7785.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7608, validation C-index: 0.7372.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.7555, validation C-index: 0.7351.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  232
# Save model of Epoch 33
# Loading model, best epoch: 33.
# Final training C-index: 0.7515, final validation C-index: 0.7479.
# Total time elapse: 1.18.
# L2: 0.001, LR: 0.05. dim: 8, dr1: 0.5, dr2: 0.3.
# Training C-index: 0.7515, validation C-index: 0.7479.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.596, validation C-index: 0.6416.
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# Training C-index: 0.6297, validation C-index: 0.7208.
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.6401, validation C-index: 0.7362.
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# Training C-index: 0.3626, validation C-index: 0.2715.
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  451
# Save model of Epoch 252
# Loading model, best epoch: 252.
# Final training C-index: 0.6955, final validation C-index: 0.7711.
# Total time elapse: 2.07.
# L2: 0.001, LR: 0.05. dim: 8, dr1: 0.5, dr2: 0.5.
# Training C-index: 0.6955, validation C-index: 0.7711.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7681, validation C-index: 0.7142.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training C-index: 0.7712, validation C-index: 0.7189.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  215
# Save model of Epoch 16
# Loading model, best epoch: 16.
# Final training C-index: 0.7469, final validation C-index: 0.7658.
# Total time elapse: 1.06.
# L2: 0.001, LR: 0.05. dim: 16, dr1: 0.1, dr2: 0.1.
# Training C-index: 0.7469, validation C-index: 0.7658.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7743, validation C-index: 0.7261.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.7669, validation C-index: 0.7244.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  222
# Save model of Epoch 23
# Loading model, best epoch: 23.
# Final training C-index: 0.7491, final validation C-index: 0.7645.
# Total time elapse: 1.26.
# L2: 0.001, LR: 0.05. dim: 16, dr1: 0.1, dr2: 0.3.
# Training C-index: 0.7491, validation C-index: 0.7645.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7674, validation C-index: 0.73.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training C-index: 0.7656, validation C-index: 0.7219.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  200
# Save model of Epoch 1
# Loading model, best epoch: 1.
# Final training C-index: 0.6232, final validation C-index: 0.7619.
# Total time elapse: 0.87.
# L2: 0.001, LR: 0.05. dim: 16, dr1: 0.1, dr2: 0.5.
# Training C-index: 0.6232, validation C-index: 0.7619.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.763, validation C-index: 0.7176.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training C-index: 0.7632, validation C-index: 0.7313.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  212
# Save model of Epoch 13
# Loading model, best epoch: 13.
# Final training C-index: 0.7438, final validation C-index: 0.7653.
# Total time elapse: 1.1.
# L2: 0.001, LR: 0.05. dim: 16, dr1: 0.3, dr2: 0.1.
# Training C-index: 0.7438, validation C-index: 0.7653.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.7513, validation C-index: 0.724.
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# Training C-index: 0.7489, validation C-index: 0.7445.
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  278
# Save model of Epoch 79
# Loading model, best epoch: 79.
# Final training C-index: 0.7497, final validation C-index: 0.7624.
# Total time elapse: 1.54.
# L2: 0.001, LR: 0.05. dim: 16, dr1: 0.3, dr2: 0.3.
# Training C-index: 0.7497, validation C-index: 0.7624.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.758, validation C-index: 0.7325.
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7572, validation C-index: 0.7389.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.7573, validation C-index: 0.7385.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  338
# Save model of Epoch 139
# Loading model, best epoch: 139.
# Final training C-index: 0.7513, final validation C-index: 0.7636.
# Total time elapse: 1.89.
# L2: 0.001, LR: 0.05. dim: 16, dr1: 0.3, dr2: 0.5.
# Training C-index: 0.7513, validation C-index: 0.7636.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.7622, validation C-index: 0.7244.
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# Training C-index: 0.7592, validation C-index: 0.73.
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  248
# Save model of Epoch 49
# Loading model, best epoch: 49.
# Final training C-index: 0.7498, final validation C-index: 0.7602.
# Total time elapse: 1.31.
# L2: 0.001, LR: 0.05. dim: 16, dr1: 0.5, dr2: 0.1.
# Training C-index: 0.7498, validation C-index: 0.7602.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7593, validation C-index: 0.7321.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training C-index: 0.7488, validation C-index: 0.7436.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  201
# Save model of Epoch 2
# Loading model, best epoch: 2.
# Final training C-index: 0.6892, final validation C-index: 0.7666.
# Total time elapse: 0.94.
# L2: 0.001, LR: 0.05. dim: 16, dr1: 0.5, dr2: 0.3.
# Training C-index: 0.6892, validation C-index: 0.7666.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.7566, validation C-index: 0.7266.
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# Training C-index: 0.7632, validation C-index: 0.7236.
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  261
# Save model of Epoch 62
# Loading model, best epoch: 62.
# Final training C-index: 0.754, final validation C-index: 0.7521.
# Total time elapse: 1.29.
# L2: 0.001, LR: 0.05. dim: 16, dr1: 0.5, dr2: 0.5.
# Training C-index: 0.754, validation C-index: 0.7521.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.7735, validation C-index: 0.7385.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# Training C-index: 0.7765, validation C-index: 0.7253.
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  282
# Save model of Epoch 83
# Loading model, best epoch: 83.
# Final training C-index: 0.7734, final validation C-index: 0.7581.
# Total time elapse: 1.57.
# L2: 0.001, LR: 0.05. dim: 32, dr1: 0.1, dr2: 0.1.
# Training C-index: 0.7734, validation C-index: 0.7581.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.768, validation C-index: 0.7266.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training C-index: 0.7643, validation C-index: 0.7266.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  211
# Save model of Epoch 12
# Loading model, best epoch: 12.
# Final training C-index: 0.7379, final validation C-index: 0.7585.
# Total time elapse: 1.08.
# L2: 0.001, LR: 0.05. dim: 32, dr1: 0.1, dr2: 0.3.
# Training C-index: 0.7379, validation C-index: 0.7585.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7378, validation C-index: 0.7151.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7629, validation C-index: 0.727.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training C-index: 0.7677, validation C-index: 0.7359.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  310
# Save model of Epoch 111
# Loading model, best epoch: 111.
# Final training C-index: 0.7561, final validation C-index: 0.7594.
# Total time elapse: 1.47.
# L2: 0.001, LR: 0.05. dim: 32, dr1: 0.1, dr2: 0.5.
# Training C-index: 0.7561, validation C-index: 0.7594.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7631, validation C-index: 0.7244.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training C-index: 0.7603, validation C-index: 0.7095.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  212
# Save model of Epoch 13
# Loading model, best epoch: 13.
# Final training C-index: 0.7409, final validation C-index: 0.7649.
# Total time elapse: 1.02.
# L2: 0.001, LR: 0.05. dim: 32, dr1: 0.3, dr2: 0.1.
# Training C-index: 0.7409, validation C-index: 0.7649.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7513, validation C-index: 0.7317.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.7538, validation C-index: 0.7432.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  235
# Save model of Epoch 36
# Loading model, best epoch: 36.
# Final training C-index: 0.746, final validation C-index: 0.773.
# Total time elapse: 1.21.
# L2: 0.001, LR: 0.05. dim: 32, dr1: 0.3, dr2: 0.3.
# Training C-index: 0.746, validation C-index: 0.773.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.7629, validation C-index: 0.7381.
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7609, validation C-index: 0.7227.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.7553, validation C-index: 0.733.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  330
# Save model of Epoch 131
# Loading model, best epoch: 131.
# Final training C-index: 0.7488, final validation C-index: 0.7551.
# Total time elapse: 1.81.
# L2: 0.001, LR: 0.05. dim: 32, dr1: 0.3, dr2: 0.5.
# Training C-index: 0.7488, validation C-index: 0.7551.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7608, validation C-index: 0.7249.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training C-index: 0.7567, validation C-index: 0.7236.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  206
# Save model of Epoch 7
# Loading model, best epoch: 7.
# Final training C-index: 0.7256, final validation C-index: 0.7615.
# Total time elapse: 1.02.
# L2: 0.001, LR: 0.05. dim: 32, dr1: 0.5, dr2: 0.1.
# Training C-index: 0.7256, validation C-index: 0.7615.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7568, validation C-index: 0.7355.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.7592, validation C-index: 0.7266.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  224
# Save model of Epoch 25
# Loading model, best epoch: 25.
# Final training C-index: 0.7548, final validation C-index: 0.7547.
# Total time elapse: 1.32.
# L2: 0.001, LR: 0.05. dim: 32, dr1: 0.5, dr2: 0.3.
# Training C-index: 0.7548, validation C-index: 0.7547.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.752, validation C-index: 0.7308.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.7577, validation C-index: 0.7351.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  229
# Save model of Epoch 30
# Loading model, best epoch: 30.
# Final training C-index: 0.7413, final validation C-index: 0.7572.
# Total time elapse: 1.47.
# L2: 0.001, LR: 0.05. dim: 32, dr1: 0.5, dr2: 0.5.
# Training C-index: 0.7413, validation C-index: 0.7572.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.7692, validation C-index: 0.7325.
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.7738, validation C-index: 0.7411.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7795, validation C-index: 0.7219.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training C-index: 0.7787, validation C-index: 0.7249.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  418
# Save model of Epoch 219
# Loading model, best epoch: 219.
# Final training C-index: 0.7749, final validation C-index: 0.7521.
# Total time elapse: 2.32.
# L2: 0.001, LR: 0.01. dim: 8, dr1: 0.1, dr2: 0.1.
# Training C-index: 0.7749, validation C-index: 0.7521.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7707, validation C-index: 0.7181.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training C-index: 0.7715, validation C-index: 0.724.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  200
# Save model of Epoch 1
# Loading model, best epoch: 1.
# Final training C-index: 0.6345, final validation C-index: 0.7381.
# Total time elapse: 0.9.
# L2: 0.001, LR: 0.01. dim: 8, dr1: 0.1, dr2: 0.3.
# Training C-index: 0.6345, validation C-index: 0.7381.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.7679, validation C-index: 0.7419.
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# Training C-index: 0.7694, validation C-index: 0.7168.
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  242
# Save model of Epoch 43
# Loading model, best epoch: 43.
# Final training C-index: 0.7603, final validation C-index: 0.7432.
# Total time elapse: 1.37.
# L2: 0.001, LR: 0.01. dim: 8, dr1: 0.1, dr2: 0.5.
# Training C-index: 0.7603, validation C-index: 0.7432.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7616, validation C-index: 0.7147.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.7652, validation C-index: 0.7419.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  224
# Save model of Epoch 25
# Loading model, best epoch: 25.
# Final training C-index: 0.7508, final validation C-index: 0.7526.
# Total time elapse: 1.08.
# L2: 0.001, LR: 0.01. dim: 8, dr1: 0.3, dr2: 0.1.
# Training C-index: 0.7508, validation C-index: 0.7526.
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.7604, validation C-index: 0.7159.
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.7636, validation C-index: 0.7185.
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# Training C-index: 0.7635, validation C-index: 0.7253.
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  360
# Save model of Epoch 161
# Loading model, best epoch: 161.
# Final training C-index: 0.7609, final validation C-index: 0.7389.
# Total time elapse: 2.54.
# L2: 0.001, LR: 0.01. dim: 8, dr1: 0.3, dr2: 0.3.
# Training C-index: 0.7609, validation C-index: 0.7389.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.7599, validation C-index: 0.7223.
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.762, validation C-index: 0.7253.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.7639, validation C-index: 0.7313.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7624, validation C-index: 0.7304.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.7622, validation C-index: 0.727.
# Loading model, best epoch: 339.
# Final training C-index: 0.7615, final validation C-index: 0.7389.
# Total time elapse: 2.59.
# L2: 0.001, LR: 0.01. dim: 8, dr1: 0.3, dr2: 0.5.
# Training C-index: 0.7615, validation C-index: 0.7389.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7596, validation C-index: 0.7359.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.7601, validation C-index: 0.7334.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  238
# Save model of Epoch 39
# Loading model, best epoch: 39.
# Final training C-index: 0.7451, final validation C-index: 0.7551.
# Total time elapse: 1.52.
# L2: 0.001, LR: 0.01. dim: 8, dr1: 0.5, dr2: 0.1.
# Training C-index: 0.7451, validation C-index: 0.7551.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.7606, validation C-index: 0.7159.
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# Training C-index: 0.7616, validation C-index: 0.7236.
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  248
# Save model of Epoch 49
# Loading model, best epoch: 49.
# Final training C-index: 0.7552, final validation C-index: 0.7487.
# Total time elapse: 1.57.
# L2: 0.001, LR: 0.01. dim: 8, dr1: 0.5, dr2: 0.3.
# Training C-index: 0.7552, validation C-index: 0.7487.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7599, validation C-index: 0.7296.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training C-index: 0.7602, validation C-index: 0.7244.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  213
# Save model of Epoch 14
# Loading model, best epoch: 14.
# Final training C-index: 0.6913, final validation C-index: 0.7513.
# Total time elapse: 1.31.
# L2: 0.001, LR: 0.01. dim: 8, dr1: 0.5, dr2: 0.5.
# Training C-index: 0.6913, validation C-index: 0.7513.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.772, validation C-index: 0.7287.
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.8023, validation C-index: 0.7261.
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# Training C-index: 0.8277, validation C-index: 0.698.
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  376
# Save model of Epoch 177
# Loading model, best epoch: 177.
# Final training C-index: 0.8007, final validation C-index: 0.7496.
# Total time elapse: 1.93.
# L2: 0.001, LR: 0.01. dim: 16, dr1: 0.1, dr2: 0.1.
# Training C-index: 0.8007, validation C-index: 0.7496.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.766, validation C-index: 0.7274.
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7702, validation C-index: 0.7257.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7801, validation C-index: 0.7381.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.7832, validation C-index: 0.7432.
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.7824, validation C-index: 0.7291.
# Loading model, best epoch: 465.
# Final training C-index: 0.7788, final validation C-index: 0.7538.
# Total time elapse: 3.09.
# L2: 0.001, LR: 0.01. dim: 16, dr1: 0.1, dr2: 0.3.
# Training C-index: 0.7788, validation C-index: 0.7538.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.7698, validation C-index: 0.7189.
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# Training C-index: 0.7685, validation C-index: 0.7261.
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  276
# Save model of Epoch 77
# Loading model, best epoch: 77.
# Final training C-index: 0.7674, final validation C-index: 0.7347.
# Total time elapse: 1.88.
# L2: 0.001, LR: 0.01. dim: 16, dr1: 0.1, dr2: 0.5.
# Training C-index: 0.7674, validation C-index: 0.7347.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.764, validation C-index: 0.7219.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.7679, validation C-index: 0.7351.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  234
# Save model of Epoch 35
# Loading model, best epoch: 35.
# Final training C-index: 0.7546, final validation C-index: 0.7521.
# Total time elapse: 1.69.
# L2: 0.001, LR: 0.01. dim: 16, dr1: 0.3, dr2: 0.1.
# Training C-index: 0.7546, validation C-index: 0.7521.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.7615, validation C-index: 0.7244.
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# Training C-index: 0.7616, validation C-index: 0.7351.
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  245
# Save model of Epoch 46
# Loading model, best epoch: 46.
# Final training C-index: 0.754, final validation C-index: 0.7496.
# Total time elapse: 1.26.
# L2: 0.001, LR: 0.01. dim: 16, dr1: 0.3, dr2: 0.3.
# Training C-index: 0.754, validation C-index: 0.7496.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7467, validation C-index: 0.6904.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training C-index: 0.7627, validation C-index: 0.7236.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  200
# Save model of Epoch 1
# Loading model, best epoch: 1.
# Final training C-index: 0.6282, final validation C-index: 0.7491.
# Total time elapse: 0.84.
# L2: 0.001, LR: 0.01. dim: 16, dr1: 0.3, dr2: 0.5.
# Training C-index: 0.6282, validation C-index: 0.7491.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7605, validation C-index: 0.7287.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.7576, validation C-index: 0.7381.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  231
# Save model of Epoch 32
# Loading model, best epoch: 32.
# Final training C-index: 0.7501, final validation C-index: 0.7538.
# Total time elapse: 1.25.
# L2: 0.001, LR: 0.01. dim: 16, dr1: 0.5, dr2: 0.1.
# Training C-index: 0.7501, validation C-index: 0.7538.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.7616, validation C-index: 0.7291.
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# Training C-index: 0.7616, validation C-index: 0.7198.
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  243
# Save model of Epoch 44
# Loading model, best epoch: 44.
# Final training C-index: 0.7534, final validation C-index: 0.7474.
# Total time elapse: 1.21.
# L2: 0.001, LR: 0.01. dim: 16, dr1: 0.5, dr2: 0.3.
# Training C-index: 0.7534, validation C-index: 0.7474.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7604, validation C-index: 0.7342.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training C-index: 0.761, validation C-index: 0.7151.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  214
# Save model of Epoch 15
# Loading model, best epoch: 15.
# Final training C-index: 0.7136, final validation C-index: 0.7449.
# Total time elapse: 1.24.
# L2: 0.001, LR: 0.01. dim: 16, dr1: 0.5, dr2: 0.5.
# Training C-index: 0.7136, validation C-index: 0.7449.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.78, validation C-index: 0.7372.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.8108, validation C-index: 0.7398.
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# Training C-index: 0.8223, validation C-index: 0.7419.
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  353
# Save model of Epoch 154
# Loading model, best epoch: 154.
# Final training C-index: 0.795, final validation C-index: 0.7615.
# Total time elapse: 2.33.
# L2: 0.001, LR: 0.01. dim: 32, dr1: 0.1, dr2: 0.1.
# Training C-index: 0.795, validation C-index: 0.7615.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7767, validation C-index: 0.7368.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.7728, validation C-index: 0.7279.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  230
# Save model of Epoch 31
# Loading model, best epoch: 31.
# Final training C-index: 0.7616, final validation C-index: 0.7551.
# Total time elapse: 1.15.
# L2: 0.001, LR: 0.01. dim: 32, dr1: 0.1, dr2: 0.3.
# Training C-index: 0.7616, validation C-index: 0.7551.
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.7631, validation C-index: 0.7257.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.7626, validation C-index: 0.7181.
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# Training C-index: 0.7733, validation C-index: 0.7193.
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  340
# Save model of Epoch 141
# Loading model, best epoch: 141.
# Final training C-index: 0.7683, final validation C-index: 0.7372.
# Total time elapse: 2.12.
# L2: 0.001, LR: 0.01. dim: 32, dr1: 0.1, dr2: 0.5.
# Training C-index: 0.7683, validation C-index: 0.7372.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.7666, validation C-index: 0.7164.
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.7703, validation C-index: 0.7415.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.7679, validation C-index: 0.7483.
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# Training C-index: 0.7813, validation C-index: 0.7176.
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  471
# Save model of Epoch 272
# Loading model, best epoch: 272.
# Final training C-index: 0.7675, final validation C-index: 0.7581.
# Total time elapse: 2.81.
# L2: 0.001, LR: 0.01. dim: 32, dr1: 0.3, dr2: 0.1.
# Training C-index: 0.7675, validation C-index: 0.7581.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.7636, validation C-index: 0.727.
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# Training C-index: 0.7605, validation C-index: 0.7351.
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  246
# Save model of Epoch 47
# Loading model, best epoch: 47.
# Final training C-index: 0.7547, final validation C-index: 0.7543.
# Total time elapse: 1.67.
# L2: 0.001, LR: 0.01. dim: 32, dr1: 0.3, dr2: 0.3.
# Training C-index: 0.7547, validation C-index: 0.7543.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.759, validation C-index: 0.7185.
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# Training C-index: 0.7598, validation C-index: 0.7334.
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  246
# Save model of Epoch 47
# Loading model, best epoch: 47.
# Final training C-index: 0.7486, final validation C-index: 0.7398.
# Total time elapse: 1.58.
# L2: 0.001, LR: 0.01. dim: 32, dr1: 0.3, dr2: 0.5.
# Training C-index: 0.7486, validation C-index: 0.7398.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7627, validation C-index: 0.7291.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.7648, validation C-index: 0.7355.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  229
# Save model of Epoch 30
# Loading model, best epoch: 30.
# Final training C-index: 0.7419, final validation C-index: 0.756.
# Total time elapse: 1.43.
# L2: 0.001, LR: 0.01. dim: 32, dr1: 0.5, dr2: 0.1.
# Training C-index: 0.7419, validation C-index: 0.756.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7604, validation C-index: 0.7351.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.7621, validation C-index: 0.7257.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  236
# Save model of Epoch 37
# Loading model, best epoch: 37.
# Final training C-index: 0.7528, final validation C-index: 0.7543.
# Total time elapse: 1.1.
# L2: 0.001, LR: 0.01. dim: 32, dr1: 0.5, dr2: 0.3.
# Training C-index: 0.7528, validation C-index: 0.7543.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.7617, validation C-index: 0.7236.
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# Training C-index: 0.76, validation C-index: 0.7206.
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  256
# Save model of Epoch 57
# Loading model, best epoch: 57.
# Final training C-index: 0.753, final validation C-index: 0.7398.
# Total time elapse: 1.45.
# L2: 0.001, LR: 0.01. dim: 32, dr1: 0.5, dr2: 0.5.
# Training C-index: 0.753, validation C-index: 0.7398.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.7712, validation C-index: 0.7249.
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# Training C-index: 0.7748, validation C-index: 0.727.
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  240
# Save model of Epoch 41
# Loading model, best epoch: 41.
# Final training C-index: 0.7585, final validation C-index: 0.7538.
# Total time elapse: 1.34.
# L2: 0.001, LR: 0.0075. dim: 8, dr1: 0.1, dr2: 0.1.
# Training C-index: 0.7585, validation C-index: 0.7538.
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.765, validation C-index: 0.721.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# Training C-index: 0.7644, validation C-index: 0.7036.
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# ...
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.7722, validation C-index: 0.7313.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  436
# Save model of Epoch 237
# Loading model, best epoch: 237.
# Final training C-index: 0.7694, final validation C-index: 0.7432.
# Total time elapse: 2.44.
# L2: 0.0005, LR: 0.01. dim: 32, dr1: 0.1, dr2: 0.5.
# Training C-index: 0.7694, validation C-index: 0.7432.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7673, validation C-index: 0.7419.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.771, validation C-index: 0.7462.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  225
# Save model of Epoch 26
# Loading model, best epoch: 26.
# Final training C-index: 0.7431, final validation C-index: 0.7687.
# Total time elapse: 1.34.
# L2: 0.0005, LR: 0.01. dim: 32, dr1: 0.3, dr2: 0.1.
# Training C-index: 0.7431, validation C-index: 0.7687.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7627, validation C-index: 0.7134.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.7629, validation C-index: 0.7321.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  229
# Save model of Epoch 30
# Loading model, best epoch: 30.
# Final training C-index: 0.7457, final validation C-index: 0.7517.
# Total time elapse: 1.56.
# L2: 0.0005, LR: 0.01. dim: 32, dr1: 0.3, dr2: 0.3.
# Training C-index: 0.7457, validation C-index: 0.7517.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.7507, validation C-index: 0.7244.
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# Training C-index: 0.7585, validation C-index: 0.7308.
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  257
# Save model of Epoch 58
# Loading model, best epoch: 58.
# Final training C-index: 0.7458, final validation C-index: 0.7491.
# Total time elapse: 1.37.
# L2: 0.0005, LR: 0.01. dim: 32, dr1: 0.3, dr2: 0.5.
# Training C-index: 0.7458, validation C-index: 0.7491.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7582, validation C-index: 0.7359.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.7632, validation C-index: 0.7317.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  237
# Save model of Epoch 38
# Loading model, best epoch: 38.
# Final training C-index: 0.7506, final validation C-index: 0.744.
# Total time elapse: 1.88.
# L2: 0.0005, LR: 0.01. dim: 32, dr1: 0.5, dr2: 0.1.
# Training C-index: 0.7506, validation C-index: 0.744.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.7602, validation C-index: 0.7236.
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# Training C-index: 0.7605, validation C-index: 0.7381.
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  243
# Save model of Epoch 44
# Loading model, best epoch: 44.
# Final training C-index: 0.7492, final validation C-index: 0.7496.
# Total time elapse: 1.75.
# L2: 0.0005, LR: 0.01. dim: 32, dr1: 0.5, dr2: 0.3.
# Training C-index: 0.7492, validation C-index: 0.7496.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7576, validation C-index: 0.7355.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.7622, validation C-index: 0.7142.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  236
# Save model of Epoch 37
# Loading model, best epoch: 37.
# Final training C-index: 0.737, final validation C-index: 0.75.
# Total time elapse: 1.17.
# L2: 0.0005, LR: 0.01. dim: 32, dr1: 0.5, dr2: 0.5.
# Training C-index: 0.737, validation C-index: 0.75.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.7796, validation C-index: 0.73.
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# Training C-index: 0.7942, validation C-index: 0.7368.
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.8123, validation C-index: 0.7283.
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.8239, validation C-index: 0.7291.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.8288, validation C-index: 0.7466.
# Loading model, best epoch: 405.
# Final training C-index: 0.8214, final validation C-index: 0.7568.
# Total time elapse: 2.65.
# L2: 0.0005, LR: 0.0075. dim: 8, dr1: 0.1, dr2: 0.1.
# Training C-index: 0.8214, validation C-index: 0.7568.
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.7608, validation C-index: 0.7355.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# Training C-index: 0.773, validation C-index: 0.721.
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  298
# Save model of Epoch 99
# Loading model, best epoch: 99.
# Final training C-index: 0.7606, final validation C-index: 0.7376.
# Total time elapse: 2.1.
# L2: 0.0005, LR: 0.0075. dim: 8, dr1: 0.1, dr2: 0.3.
# Training C-index: 0.7606, validation C-index: 0.7376.
# Training C-index: 0.7678, validation C-index: 0.7125.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7671, validation C-index: 0.7164.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.7698, validation C-index: 0.724.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  335
# Save model of Epoch 136
# Loading model, best epoch: 136.
# Final training C-index: 0.7681, final validation C-index: 0.7325.
# Total time elapse: 2.8.
# L2: 0.0005, LR: 0.0075. dim: 8, dr1: 0.1, dr2: 0.5.
# Training C-index: 0.7681, validation C-index: 0.7325.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.7634, validation C-index: 0.7313.
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# Training C-index: 0.7633, validation C-index: 0.7168.
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  250
# Save model of Epoch 51
# Loading model, best epoch: 51.
# Final training C-index: 0.7519, final validation C-index: 0.753.
# Total time elapse: 1.25.
# L2: 0.0005, LR: 0.0075. dim: 8, dr1: 0.3, dr2: 0.1.
# Training C-index: 0.7519, validation C-index: 0.753.
# Training C-index: 0.7549, validation C-index: 0.6912.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# Training C-index: 0.763, validation C-index: 0.7351.
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.764, validation C-index: 0.7274.
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# Training C-index: 0.7644, validation C-index: 0.733.
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  479
# Save model of Epoch 280
# Loading model, best epoch: 280.
# Final training C-index: 0.7647, final validation C-index: 0.7419.
# Total time elapse: 3.13.
# L2: 0.0005, LR: 0.0075. dim: 8, dr1: 0.3, dr2: 0.3.
# Training C-index: 0.7647, validation C-index: 0.7419.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7517, validation C-index: 0.6985.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training C-index: 0.7611, validation C-index: 0.7193.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  200
# Save model of Epoch 1
# Loading model, best epoch: 1.
# Final training C-index: 0.6659, final validation C-index: 0.7325.
# Total time elapse: 0.86.
# L2: 0.0005, LR: 0.0075. dim: 8, dr1: 0.3, dr2: 0.5.
# Training C-index: 0.6659, validation C-index: 0.7325.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.7565, validation C-index: 0.7411.
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# Training C-index: 0.7586, validation C-index: 0.7394.
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  247
# Save model of Epoch 48
# Loading model, best epoch: 48.
# Final training C-index: 0.7475, final validation C-index: 0.7658.
# Total time elapse: 1.41.
# L2: 0.0005, LR: 0.0075. dim: 8, dr1: 0.5, dr2: 0.1.
# Training C-index: 0.7475, validation C-index: 0.7658.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.7616, validation C-index: 0.7321.
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# Training C-index: 0.7613, validation C-index: 0.7253.
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  262
# Save model of Epoch 63
# Loading model, best epoch: 63.
# Final training C-index: 0.75, final validation C-index: 0.7538.
# Total time elapse: 1.4.
# L2: 0.0005, LR: 0.0075. dim: 8, dr1: 0.5, dr2: 0.3.
# Training C-index: 0.75, validation C-index: 0.7538.
# Training C-index: 0.7607, validation C-index: 0.7317.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7613, validation C-index: 0.7151.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training C-index: 0.7617, validation C-index: 0.7313.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  313
# Save model of Epoch 114
# Loading model, best epoch: 114.
# Final training C-index: 0.7593, final validation C-index: 0.7372.
# Total time elapse: 2.06.
# L2: 0.0005, LR: 0.0075. dim: 8, dr1: 0.5, dr2: 0.5.
# Training C-index: 0.7593, validation C-index: 0.7372.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7771, validation C-index: 0.7304.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.7979, validation C-index: 0.7372.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.8273, validation C-index: 0.75.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.8449, validation C-index: 0.7572.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.8446, validation C-index: 0.7598.
# Loading model, best epoch: 326.
# Final training C-index: 0.8289, final validation C-index: 0.7879.
# Total time elapse: 3.53.
# L2: 0.0005, LR: 0.0075. dim: 16, dr1: 0.1, dr2: 0.1.
# Training C-index: 0.8289, validation C-index: 0.7879.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7668, validation C-index: 0.7147.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training C-index: 0.7709, validation C-index: 0.7176.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  200
# Save model of Epoch 1
# Loading model, best epoch: 1.
# Final training C-index: 0.6383, final validation C-index: 0.75.
# Total time elapse: 0.86.
# L2: 0.0005, LR: 0.0075. dim: 16, dr1: 0.1, dr2: 0.3.
# Training C-index: 0.6383, validation C-index: 0.75.
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.7652, validation C-index: 0.7381.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# Training C-index: 0.7723, validation C-index: 0.7279.
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200

# %%
print("--- %s seconds ---" % (end_time - start_time))

# %%
train_y_pred, test_y_pred, cindex_train, cindex_test, best_epoch_num_overall = train_LFSurv(x_train_overall, age_train_overall, stage_i_train_overall, stage_ii_train_overall, race_white_train_overall, ytime_train_overall, yevent_train_overall,
                                                                                            x_test_overall, age_test_overall, stage_i_test_overall, stage_ii_test_overall, race_white_test_overall, ytime_test_overall, yevent_test_overall,
                                                                                            input_n, opt_dim, opt_dr1, opt_dr2, opt_lr, opt_l2, epoch_num, patience, dtype,
                                                                                            path = "sup_checkpoint_overall.pt")
print("Optimal L2: %s," %opt_l2, "optimal LR: %s," %opt_lr, "optimal dim: %s," %opt_dim, "optimal dr1: %s," %opt_dr1, "optimal dr2: %s," %opt_dr2, "best epoch number in tuning: %s." %best_epoch_num)
print("Optimal training C-index: %s," %opt_cindex_tr.round(4), "optimal validation C-index: %s." %opt_cindex_va.round(4))
print("Testing phase: training C-index: %s," %cindex_train.round(4), "testing C-index: %s." %cindex_test.round(4))
# Out:
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7424, validation C-index: 0.6939.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7512, validation C-index: 0.7117.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.7553, validation C-index: 0.7102.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  329
# Save model of Epoch 130
# Loading model, best epoch: 130.
# Final training C-index: 0.7502, final validation C-index: 0.7197.
# Total time elapse: 5.71.
# Optimal L2: 0.0001, optimal LR: 0.0025, optimal dim: 32, optimal dr1: 0.5, optimal dr2: 0.5, best epoch number in tuning: 0.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 6
#       1 train_y_pred, test_y_pred, cindex_train, cindex_test, best_epoch_num_overall = train_LFSurv(x_train_overall, age_train_overall, stage_i_train_overall, stage_ii_train_overall, race_white_train_overall, ytime_train_overall, yevent_train_overall,
#       2                                                                                             x_test_overall, age_test_overall, stage_i_test_overall, stage_ii_test_overall, race_white_test_overall, ytime_test_overall, yevent_test_overall,
#       3                                                                                             input_n, opt_dim, opt_dr1, opt_dr2, opt_lr, opt_l2, epoch_num, patience, dtype,
#       4                                                                                             path = "sup_checkpoint_overall.pt")
#       5 print("Optimal L2: %s," %opt_l2, "optimal LR: %s," %opt_lr, "optimal dim: %s," %opt_dim, "optimal dr1: %s," %opt_dr1, "optimal dr2: %s," %opt_dr2, "best epoch number in tuning: %s." %best_epoch_num)
# ----> 6 print("Optimal training C-index: %s," %opt_cindex_tr.round(4), "optimal validation C-index: %s." %opt_cindex_va.round(4))
#       7 print("Testing phase: training C-index: %s," %cindex_train.round(4), "testing C-index: %s." %cindex_test.round(4))
#
# NameError: name 'opt_cindex_tr' is not defined
