# %%
import math
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.nn.init as init
import torch.optim as optim
import time
import lifelines
from lifelines.utils import concordance_index
from LFSurv import LFSurv
from utils import sort_data, load_data, R_set, neg_par_log_likelihood, c_index, EarlyStopping
from train_LFSurv import train_LFSurv

dtype = torch.FloatTensor
os.chdir('/cloud-home/U1039935/Autosurv/autostat')

# %%
data_tune_train = pd.read_csv("processed_data_example/TCGA_BRCA/tune/minmax_normalized/data_train_gene_minmax_tune.csv")
data_tune_valid = pd.read_csv("processed_data_example/TCGA_BRCA/tune/minmax_normalized/data_valid_gene_minmax_tune.csv")
data_train = pd.read_csv("processed_data_example/TCGA_BRCA/train_test_split/minmax_normalized/data_train_gene_minmax_overall.csv")
data_valid = pd.read_csv("processed_data_example/TCGA_BRCA/train_test_split/minmax_normalized/data_test_gene_minmax_overall.csv")

# %%
data_train.shape
# Out:
# (857, 2706)

# %%
select_gene =['patient_id', 'OS.time', 'OS', 'age', 'stage_i', 'stage_ii', 'race_white',
 'ENSG00000169764',
 'ENSG00000115380',
 'ENSG00000168216',
 'ENSG00000131080',
 'ENSG00000154734',
 'ENSG00000184005',
 'ENSG00000154727',
 'ENSG00000185010',
 'ENSG00000069431',
 'ENSG00000171056',
 'ENSG00000137693',
 'ENSG00000140285',
 'ENSG00000138686',
 'ENSG00000138640',
 'ENSG00000005020',
 'ENSG00000157557']

# %%
tune_tr = data_tune_train[select_gene]
tune_val = data_tune_valid[select_gene]
tr = data_train[select_gene]
val = data_valid[select_gene]
tune_tr = pd.DataFrame(tune_tr)
tune_val = pd.DataFrame(tune_val)
tr = pd.DataFrame(tr)
val = pd.DataFrame(val)
print(tune_tr.shape, tune_val.shape, tr.shape, val.shape)
# Out:
# (669, 23) (188, 23) (857, 23) (201, 23)

# %%
tune_tr.to_csv('tune_tr_z_2omics.csv', index = False)
tune_val.to_csv("tune_val_z_2omics.csv", index = False)
tr.to_csv('tr_z_2omics.csv', index = False)
val.to_csv('tes_z_2omics.csv', index = False)

# %%
# modify input_n based on optim model
input_n = 16
level_2_dim = [8, 16, 32]
epoch_num = 500
patience = 200
Initial_Learning_Rate = [0.05, 0.01, 0.0075, 0.005, 0.0025]
# Initial_Learning_Rate = [0.05, 0.0075, 0.0025]
L2_Lambda = [0.001, 0.00075, 0.0005, 0.00025, 0.0001]
# L2_Lambda = [0.001, 0.0005, 0.0001]
Dropout_rate_1 = [0.1, 0.3, 0.5]
Dropout_rate_2 = [0.1, 0.3, 0.5]

best_epoch_num = 0


patient_id_train, x_train, ytime_train, yevent_train, age_train, stage_i_train, stage_ii_train, race_white_train = load_data("tune_tr_z_2omics.csv", dtype)
patient_id_valid, x_valid, ytime_valid, yevent_valid, age_valid, stage_i_valid, stage_ii_valid, race_white_valid = load_data("tune_val_z_2omics.csv", dtype)

patient_id_train_overall, x_train_overall, ytime_train_overall, yevent_train_overall, age_train_overall, stage_i_train_overall, stage_ii_train_overall, race_white_train_overall = load_data("tr_z_2omics.csv", dtype)
patient_id_test_overall, x_test_overall, ytime_test_overall, yevent_test_overall, age_test_overall, stage_i_test_overall, stage_ii_test_overall, race_white_test_overall = load_data("tes_z_2omics.csv", dtype)

# %%
x_train.shape
# Out:
# torch.Size([669, 16])

# %%
import time

# %%
start_time = time.time()
opt_l2 = 0
opt_lr = 0
opt_dim = 0
opt_dr1 = 0
opt_dr2 = 0

opt_cindex_va = float(0)
opt_cindex_tr = float(0)
for l2 in L2_Lambda:
    for lr in Initial_Learning_Rate:
        for dim in level_2_dim:
            for dr1 in Dropout_rate_1:
                for dr2 in Dropout_rate_2:
                    _, _, cindex_train, cindex_valid, best_epoch_num_tune = train_LFSurv(x_train, age_train, stage_i_train, stage_ii_train, race_white_train, ytime_train, yevent_train,
                                                                                         x_valid, age_valid, stage_i_valid, stage_ii_valid, race_white_valid, ytime_valid, yevent_valid,
                                                                                         input_n, dim, dr1, dr2, lr, l2, epoch_num, patience, dtype,
                                                                                         path = "sup_checkpoint_tune.pt")
                    
                    if cindex_valid > opt_cindex_va:
                        opt_l2 = l2
                        opt_lr = lr
                        opt_dim = dim
                        opt_dr1 = dr1
                        opt_dr2 = dr2
                        opt_cindex_tr = cindex_train
                        opt_cindex_va = cindex_valid
                        best_epoch_num = best_epoch_num_tune
                    print("L2: %s," %l2, "LR: %s." %lr, "dim: %s," %dim, "dr1: %s," %dr1, "dr2: %s." %dr2)
                    print("Training C-index: %s," %cindex_train.round(4), "validation C-index: %s." %cindex_valid.round(4))
end_time = time.time()
print("--- %s seconds ---" % (end_time - start_time))
# Out:
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7734, validation C-index: 0.7279.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training C-index: 0.7777, validation C-index: 0.7066.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7855, validation C-index: 0.7432.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.781, validation C-index: 0.727.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  420
# Save model of Epoch 221
# Loading model, best epoch: 221.
# Final training C-index: 0.7612, final validation C-index: 0.7807.
# Total time elapse: 2.61.
# L2: 0.001, LR: 0.05. dim: 8, dr1: 0.1, dr2: 0.1.
# Training C-index: 0.7612, validation C-index: 0.7807.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7616, validation C-index: 0.7308.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training C-index: 0.7541, validation C-index: 0.7342.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  210
# Save model of Epoch 11
# Loading model, best epoch: 11.
# Final training C-index: 0.7329, final validation C-index: 0.7802.
# Total time elapse: 1.23.
# L2: 0.001, LR: 0.05. dim: 8, dr1: 0.1, dr2: 0.3.
# Training C-index: 0.7329, validation C-index: 0.7802.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7512, validation C-index: 0.7398.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.7668, validation C-index: 0.7347.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  221
# Save model of Epoch 22
# Loading model, best epoch: 22.
# Final training C-index: 0.741, final validation C-index: 0.7619.
# Total time elapse: 1.25.
# L2: 0.001, LR: 0.05. dim: 8, dr1: 0.1, dr2: 0.5.
# Training C-index: 0.741, validation C-index: 0.7619.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7641, validation C-index: 0.7253.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.7675, validation C-index: 0.7138.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  226
# Save model of Epoch 27
# Loading model, best epoch: 27.
# Final training C-index: 0.7552, final validation C-index: 0.7428.
# Total time elapse: 1.39.
# L2: 0.001, LR: 0.05. dim: 8, dr1: 0.3, dr2: 0.1.
# Training C-index: 0.7552, validation C-index: 0.7428.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.766, validation C-index: 0.7287.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.7555, validation C-index: 0.7261.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  223
# Save model of Epoch 24
# Loading model, best epoch: 24.
# Final training C-index: 0.7489, final validation C-index: 0.756.
# Total time elapse: 1.37.
# L2: 0.001, LR: 0.05. dim: 8, dr1: 0.3, dr2: 0.3.
# Training C-index: 0.7489, validation C-index: 0.756.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7599, validation C-index: 0.7342.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training C-index: 0.7566, validation C-index: 0.73.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  202
# Save model of Epoch 3
# Loading model, best epoch: 3.
# Final training C-index: 0.6806, final validation C-index: 0.7611.
# Total time elapse: 1.15.
# L2: 0.001, LR: 0.05. dim: 8, dr1: 0.3, dr2: 0.5.
# Training C-index: 0.6806, validation C-index: 0.7611.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7527, validation C-index: 0.7394.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.7529, validation C-index: 0.7338.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  223
# Save model of Epoch 24
# Loading model, best epoch: 24.
# Final training C-index: 0.6972, final validation C-index: 0.756.
# Total time elapse: 1.3.
# L2: 0.001, LR: 0.05. dim: 8, dr1: 0.5, dr2: 0.1.
# Training C-index: 0.6972, validation C-index: 0.756.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7592, validation C-index: 0.7325.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training C-index: 0.761, validation C-index: 0.7317.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  217
# Save model of Epoch 18
# Loading model, best epoch: 18.
# Final training C-index: 0.7464, final validation C-index: 0.7585.
# Total time elapse: 1.28.
# L2: 0.001, LR: 0.05. dim: 8, dr1: 0.5, dr2: 0.3.
# Training C-index: 0.7464, validation C-index: 0.7585.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.761, validation C-index: 0.7368.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7584, validation C-index: 0.7249.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training C-index: 0.7591, validation C-index: 0.7078.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  313
# Save model of Epoch 114
# Loading model, best epoch: 114.
# Final training C-index: 0.756, final validation C-index: 0.7479.
# Total time elapse: 2.24.
# L2: 0.001, LR: 0.05. dim: 8, dr1: 0.5, dr2: 0.5.
# Training C-index: 0.756, validation C-index: 0.7479.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7669, validation C-index: 0.6934.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training C-index: 0.7659, validation C-index: 0.7087.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  207
# Save model of Epoch 8
# Loading model, best epoch: 8.
# Final training C-index: 0.7183, final validation C-index: 0.7734.
# Total time elapse: 1.29.
# L2: 0.001, LR: 0.05. dim: 16, dr1: 0.1, dr2: 0.1.
# Training C-index: 0.7183, validation C-index: 0.7734.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7734, validation C-index: 0.7168.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training C-index: 0.7596, validation C-index: 0.7244.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  211
# Save model of Epoch 12
# Loading model, best epoch: 12.
# Final training C-index: 0.734, final validation C-index: 0.7645.
# Total time elapse: 1.21.
# L2: 0.001, LR: 0.05. dim: 16, dr1: 0.1, dr2: 0.3.
# Training C-index: 0.734, validation C-index: 0.7645.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7571, validation C-index: 0.7347.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7609, validation C-index: 0.7423.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.7576, validation C-index: 0.7244.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  327
# Save model of Epoch 128
# Loading model, best epoch: 128.
# Final training C-index: 0.7636, final validation C-index: 0.7585.
# Total time elapse: 1.95.
# L2: 0.001, LR: 0.05. dim: 16, dr1: 0.1, dr2: 0.5.
# Training C-index: 0.7636, validation C-index: 0.7585.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7581, validation C-index: 0.7453.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training C-index: 0.7661, validation C-index: 0.73.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  207
# Save model of Epoch 8
# Loading model, best epoch: 8.
# Final training C-index: 0.7017, final validation C-index: 0.7538.
# Total time elapse: 1.4.
# L2: 0.001, LR: 0.05. dim: 16, dr1: 0.3, dr2: 0.1.
# Training C-index: 0.7017, validation C-index: 0.7538.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7629, validation C-index: 0.7087.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training C-index: 0.7569, validation C-index: 0.7428.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  215
# Save model of Epoch 16
# Loading model, best epoch: 16.
# Final training C-index: 0.7443, final validation C-index: 0.7551.
# Total time elapse: 1.3.
# L2: 0.001, LR: 0.05. dim: 16, dr1: 0.3, dr2: 0.3.
# Training C-index: 0.7443, validation C-index: 0.7551.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.7571, validation C-index: 0.7304.
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# Training C-index: 0.7592, validation C-index: 0.7394.
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  260
# Save model of Epoch 61
# Loading model, best epoch: 61.
# Final training C-index: 0.7488, final validation C-index: 0.7509.
# Total time elapse: 1.47.
# L2: 0.001, LR: 0.05. dim: 16, dr1: 0.3, dr2: 0.5.
# Training C-index: 0.7488, validation C-index: 0.7509.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7558, validation C-index: 0.7313.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training C-index: 0.753, validation C-index: 0.7325.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  212
# Save model of Epoch 13
# Loading model, best epoch: 13.
# Final training C-index: 0.7461, final validation C-index: 0.7555.
# Total time elapse: 1.28.
# L2: 0.001, LR: 0.05. dim: 16, dr1: 0.5, dr2: 0.1.
# Training C-index: 0.7461, validation C-index: 0.7555.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.756, validation C-index: 0.7355.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training C-index: 0.7578, validation C-index: 0.7415.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  202
# Save model of Epoch 3
# Loading model, best epoch: 3.
# Final training C-index: 0.684, final validation C-index: 0.7675.
# Total time elapse: 1.17.
# L2: 0.001, LR: 0.05. dim: 16, dr1: 0.5, dr2: 0.3.
# Training C-index: 0.684, validation C-index: 0.7675.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.7596, validation C-index: 0.7372.
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# Training C-index: 0.7548, validation C-index: 0.7423.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# Training C-index: 0.7586, validation C-index: 0.7142.
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  388
# Save model of Epoch 189
# Loading model, best epoch: 189.
# Final training C-index: 0.7535, final validation C-index: 0.7547.
# Total time elapse: 2.31.
# L2: 0.001, LR: 0.05. dim: 16, dr1: 0.5, dr2: 0.5.
# Training C-index: 0.7535, validation C-index: 0.7547.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7716, validation C-index: 0.7338.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.7676, validation C-index: 0.7453.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  225
# Save model of Epoch 26
# Loading model, best epoch: 26.
# Final training C-index: 0.743, final validation C-index: 0.7679.
# Total time elapse: 1.64.
# L2: 0.001, LR: 0.05. dim: 32, dr1: 0.1, dr2: 0.1.
# Training C-index: 0.743, validation C-index: 0.7679.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7699, validation C-index: 0.7095.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training C-index: 0.7623, validation C-index: 0.7568.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  206
# Save model of Epoch 7
# Loading model, best epoch: 7.
# Final training C-index: 0.7378, final validation C-index: 0.7619.
# Total time elapse: 1.19.
# L2: 0.001, LR: 0.05. dim: 32, dr1: 0.1, dr2: 0.3.
# Training C-index: 0.7378, validation C-index: 0.7619.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.7572, validation C-index: 0.7321.
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# Training C-index: 0.7622, validation C-index: 0.7202.
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  270
# Save model of Epoch 71
# Loading model, best epoch: 71.
# Final training C-index: 0.7528, final validation C-index: 0.7585.
# Total time elapse: 1.59.
# L2: 0.001, LR: 0.05. dim: 32, dr1: 0.1, dr2: 0.5.
# Training C-index: 0.7528, validation C-index: 0.7585.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.767, validation C-index: 0.7364.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training C-index: 0.7612, validation C-index: 0.7334.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  212
# Save model of Epoch 13
# Loading model, best epoch: 13.
# Final training C-index: 0.7392, final validation C-index: 0.7747.
# Total time elapse: 1.25.
# L2: 0.001, LR: 0.05. dim: 32, dr1: 0.3, dr2: 0.1.
# Training C-index: 0.7392, validation C-index: 0.7747.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7628, validation C-index: 0.7368.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.7598, validation C-index: 0.7291.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  226
# Save model of Epoch 27
# Loading model, best epoch: 27.
# Final training C-index: 0.7519, final validation C-index: 0.756.
# Total time elapse: 1.4.
# L2: 0.001, LR: 0.05. dim: 32, dr1: 0.3, dr2: 0.3.
# Training C-index: 0.7519, validation C-index: 0.756.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7533, validation C-index: 0.7432.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7586, validation C-index: 0.7415.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training C-index: 0.7573, validation C-index: 0.7296.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  301
# Save model of Epoch 102
# Loading model, best epoch: 102.
# Final training C-index: 0.7446, final validation C-index: 0.7709.
# Total time elapse: 1.85.
# L2: 0.001, LR: 0.05. dim: 32, dr1: 0.3, dr2: 0.5.
# Training C-index: 0.7446, validation C-index: 0.7709.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7667, validation C-index: 0.7172.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training C-index: 0.7508, validation C-index: 0.7376.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  212
# Save model of Epoch 13
# Loading model, best epoch: 13.
# Final training C-index: 0.7307, final validation C-index: 0.7662.
# Total time elapse: 1.2.
# L2: 0.001, LR: 0.05. dim: 32, dr1: 0.5, dr2: 0.1.
# Training C-index: 0.7307, validation C-index: 0.7662.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7561, validation C-index: 0.7249.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.7609, validation C-index: 0.7351.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  229
# Save model of Epoch 30
# Loading model, best epoch: 30.
# Final training C-index: 0.7473, final validation C-index: 0.7526.
# Total time elapse: 1.54.
# L2: 0.001, LR: 0.05. dim: 32, dr1: 0.5, dr2: 0.3.
# Training C-index: 0.7473, validation C-index: 0.7526.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7567, validation C-index: 0.7347.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.7581, validation C-index: 0.7364.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  230
# Save model of Epoch 31
# Loading model, best epoch: 31.
# Final training C-index: 0.7479, final validation C-index: 0.7589.
# Total time elapse: 1.38.
# L2: 0.001, LR: 0.05. dim: 32, dr1: 0.5, dr2: 0.5.
# Training C-index: 0.7479, validation C-index: 0.7589.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.775, validation C-index: 0.7496.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.7811, validation C-index: 0.7487.
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.786, validation C-index: 0.7304.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# Training C-index: 0.7926, validation C-index: 0.7274.
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  486
# Save model of Epoch 287
# Loading model, best epoch: 287.
# Final training C-index: 0.7867, final validation C-index: 0.7551.
# Total time elapse: 3.17.
# L2: 0.001, LR: 0.01. dim: 8, dr1: 0.1, dr2: 0.1.
# Training C-index: 0.7867, validation C-index: 0.7551.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.765, validation C-index: 0.7138.
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# Training C-index: 0.7679, validation C-index: 0.7147.
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  245
# Save model of Epoch 46
# Loading model, best epoch: 46.
# Final training C-index: 0.758, final validation C-index: 0.7355.
# Total time elapse: 1.74.
# L2: 0.001, LR: 0.01. dim: 8, dr1: 0.1, dr2: 0.3.
# Training C-index: 0.758, validation C-index: 0.7355.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.7653, validation C-index: 0.7376.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.7686, validation C-index: 0.7189.
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# Training C-index: 0.7642, validation C-index: 0.7164.
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  344
# Save model of Epoch 145
# Loading model, best epoch: 145.
# Final training C-index: 0.7677, final validation C-index: 0.7406.
# Total time elapse: 2.37.
# L2: 0.001, LR: 0.01. dim: 8, dr1: 0.1, dr2: 0.5.
# Training C-index: 0.7677, validation C-index: 0.7406.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7628, validation C-index: 0.7334.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.766, validation C-index: 0.7274.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  232
# Save model of Epoch 33
# Loading model, best epoch: 33.
# Final training C-index: 0.7546, final validation C-index: 0.7547.
# Total time elapse: 1.58.
# L2: 0.001, LR: 0.01. dim: 8, dr1: 0.3, dr2: 0.1.
# Training C-index: 0.7546, validation C-index: 0.7547.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.7591, validation C-index: 0.7313.
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# Training C-index: 0.7632, validation C-index: 0.7244.
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  257
# Save model of Epoch 58
# Loading model, best epoch: 58.
# Final training C-index: 0.7575, final validation C-index: 0.7445.
# Total time elapse: 1.77.
# L2: 0.001, LR: 0.01. dim: 8, dr1: 0.3, dr2: 0.3.
# Training C-index: 0.7575, validation C-index: 0.7445.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7619, validation C-index: 0.7185.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training C-index: 0.7623, validation C-index: 0.7261.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  206
# Save model of Epoch 7
# Loading model, best epoch: 7.
# Final training C-index: 0.6803, final validation C-index: 0.7589.
# Total time elapse: 1.34.
# L2: 0.001, LR: 0.01. dim: 8, dr1: 0.3, dr2: 0.5.
# Training C-index: 0.6803, validation C-index: 0.7589.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7606, validation C-index: 0.7253.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.7595, validation C-index: 0.7321.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  233
# Save model of Epoch 34
# Loading model, best epoch: 34.
# Final training C-index: 0.7285, final validation C-index: 0.7543.
# Total time elapse: 2.08.
# L2: 0.001, LR: 0.01. dim: 8, dr1: 0.5, dr2: 0.1.
# Training C-index: 0.7285, validation C-index: 0.7543.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.761, validation C-index: 0.7351.
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# Training C-index: 0.7587, validation C-index: 0.7364.
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  243
# Save model of Epoch 44
# Loading model, best epoch: 44.
# Final training C-index: 0.7518, final validation C-index: 0.7474.
# Total time elapse: 1.92.
# L2: 0.001, LR: 0.01. dim: 8, dr1: 0.5, dr2: 0.3.
# Training C-index: 0.7518, validation C-index: 0.7474.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.7588, validation C-index: 0.7381.
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# Training C-index: 0.7621, validation C-index: 0.7206.
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  262
# Save model of Epoch 63
# Loading model, best epoch: 63.
# Final training C-index: 0.7553, final validation C-index: 0.7462.
# Total time elapse: 1.84.
# L2: 0.001, LR: 0.01. dim: 8, dr1: 0.5, dr2: 0.5.
# Training C-index: 0.7553, validation C-index: 0.7462.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7722, validation C-index: 0.744.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.7728, validation C-index: 0.7487.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  236
# Save model of Epoch 37
# Loading model, best epoch: 37.
# Final training C-index: 0.7487, final validation C-index: 0.7606.
# Total time elapse: 1.91.
# L2: 0.001, LR: 0.01. dim: 16, dr1: 0.1, dr2: 0.1.
# Training C-index: 0.7487, validation C-index: 0.7606.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7669, validation C-index: 0.7376.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.7734, validation C-index: 0.7193.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  224
# Save model of Epoch 25
# Loading model, best epoch: 25.
# Final training C-index: 0.7457, final validation C-index: 0.7428.
# Total time elapse: 1.59.
# L2: 0.001, LR: 0.01. dim: 16, dr1: 0.1, dr2: 0.3.
# Training C-index: 0.7457, validation C-index: 0.7428.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.7575, validation C-index: 0.6946.
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.7658, validation C-index: 0.7236.
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# Training C-index: 0.7688, validation C-index: 0.7287.
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  342
# Save model of Epoch 143
# Loading model, best epoch: 143.
# Final training C-index: 0.7679, final validation C-index: 0.7334.
# Total time elapse: 2.5.
# L2: 0.001, LR: 0.01. dim: 16, dr1: 0.1, dr2: 0.5.
# Training C-index: 0.7679, validation C-index: 0.7334.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.764, validation C-index: 0.7342.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.7625, validation C-index: 0.7402.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  226
# Save model of Epoch 27
# Loading model, best epoch: 27.
# Final training C-index: 0.7354, final validation C-index: 0.7453.
# Total time elapse: 1.59.
# L2: 0.001, LR: 0.01. dim: 16, dr1: 0.3, dr2: 0.1.
# Training C-index: 0.7354, validation C-index: 0.7453.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.7602, validation C-index: 0.7266.
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# Training C-index: 0.7643, validation C-index: 0.7321.
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  249
# Save model of Epoch 50
# Loading model, best epoch: 50.
# Final training C-index: 0.7521, final validation C-index: 0.7521.
# Total time elapse: 2.09.
# L2: 0.001, LR: 0.01. dim: 16, dr1: 0.3, dr2: 0.3.
# Training C-index: 0.7521, validation C-index: 0.7521.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7611, validation C-index: 0.733.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training C-index: 0.7633, validation C-index: 0.7181.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  202
# Save model of Epoch 3
# Loading model, best epoch: 3.
# Final training C-index: 0.675, final validation C-index: 0.7509.
# Total time elapse: 1.18.
# L2: 0.001, LR: 0.01. dim: 16, dr1: 0.3, dr2: 0.5.
# Training C-index: 0.675, validation C-index: 0.7509.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7613, validation C-index: 0.7249.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.7596, validation C-index: 0.733.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  232
# Save model of Epoch 33
# Loading model, best epoch: 33.
# Final training C-index: 0.7413, final validation C-index: 0.7696.
# Total time elapse: 1.6.
# L2: 0.001, LR: 0.01. dim: 16, dr1: 0.5, dr2: 0.1.
# Training C-index: 0.7413, validation C-index: 0.7696.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.759, validation C-index: 0.7279.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.7609, validation C-index: 0.7138.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  236
# Save model of Epoch 37
# Loading model, best epoch: 37.
# Final training C-index: 0.7384, final validation C-index: 0.7504.
# Total time elapse: 1.52.
# L2: 0.001, LR: 0.01. dim: 16, dr1: 0.5, dr2: 0.3.
# Training C-index: 0.7384, validation C-index: 0.7504.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.7574, validation C-index: 0.7325.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7597, validation C-index: 0.7049.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.762, validation C-index: 0.7189.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  326
# Save model of Epoch 127
# Loading model, best epoch: 127.
# Final training C-index: 0.7575, final validation C-index: 0.7411.
# Total time elapse: 2.68.
# L2: 0.001, LR: 0.01. dim: 16, dr1: 0.5, dr2: 0.5.
# Training C-index: 0.7575, validation C-index: 0.7411.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.7774, validation C-index: 0.7249.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.799, validation C-index: 0.7176.
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# Training C-index: 0.8112, validation C-index: 0.7274.
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  375
# Save model of Epoch 176
# Loading model, best epoch: 176.
# Final training C-index: 0.7855, final validation C-index: 0.7632.
# Total time elapse: 2.74.
# L2: 0.001, LR: 0.01. dim: 32, dr1: 0.1, dr2: 0.1.
# Training C-index: 0.7855, validation C-index: 0.7632.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7643, validation C-index: 0.7317.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.7666, validation C-index: 0.7274.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.772, validation C-index: 0.7253.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.7753, validation C-index: 0.73.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# Training C-index: 0.7823, validation C-index: 0.7296.
# Loading model, best epoch: 394.
# Final training C-index: 0.7772, final validation C-index: 0.7585.
# Total time elapse: 3.43.
# L2: 0.001, LR: 0.01. dim: 32, dr1: 0.1, dr2: 0.3.
# Training C-index: 0.7772, validation C-index: 0.7585.
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.7619, validation C-index: 0.7057.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7694, validation C-index: 0.7313.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training C-index: 0.7711, validation C-index: 0.73.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  308
# Save model of Epoch 109
# Loading model, best epoch: 109.
# Final training C-index: 0.7707, final validation C-index: 0.7385.
# Total time elapse: 2.61.
# L2: 0.001, LR: 0.01. dim: 32, dr1: 0.1, dr2: 0.5.
# Training C-index: 0.7707, validation C-index: 0.7385.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.768, validation C-index: 0.7381.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.7704, validation C-index: 0.7376.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  228
# Save model of Epoch 29
# Loading model, best epoch: 29.
# Final training C-index: 0.7483, final validation C-index: 0.7615.
# Total time elapse: 1.67.
# L2: 0.001, LR: 0.01. dim: 32, dr1: 0.3, dr2: 0.1.
# Training C-index: 0.7483, validation C-index: 0.7615.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7604, validation C-index: 0.7253.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.765, validation C-index: 0.7266.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  235
# Save model of Epoch 36
# Loading model, best epoch: 36.
# Final training C-index: 0.748, final validation C-index: 0.7572.
# Total time elapse: 1.46.
# L2: 0.001, LR: 0.01. dim: 32, dr1: 0.3, dr2: 0.3.
# Training C-index: 0.748, validation C-index: 0.7572.
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.7615, validation C-index: 0.7347.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.764, validation C-index: 0.7359.
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# Training C-index: 0.7637, validation C-index: 0.7244.
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  373
# Save model of Epoch 174
# Loading model, best epoch: 174.
# Final training C-index: 0.7572, final validation C-index: 0.7406.
# Total time elapse: 3.42.
# L2: 0.001, LR: 0.01. dim: 32, dr1: 0.3, dr2: 0.5.
# Training C-index: 0.7572, validation C-index: 0.7406.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7607, validation C-index: 0.7287.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.7605, validation C-index: 0.7351.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  235
# Save model of Epoch 36
# Loading model, best epoch: 36.
# Final training C-index: 0.7533, final validation C-index: 0.7466.
# Total time elapse: 1.7.
# L2: 0.001, LR: 0.01. dim: 32, dr1: 0.5, dr2: 0.1.
# Training C-index: 0.7533, validation C-index: 0.7466.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7617, validation C-index: 0.7215.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training C-index: 0.761, validation C-index: 0.7266.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  202
# Save model of Epoch 3
# Loading model, best epoch: 3.
# Final training C-index: 0.7166, final validation C-index: 0.7611.
# Total time elapse: 1.18.
# L2: 0.001, LR: 0.01. dim: 32, dr1: 0.5, dr2: 0.3.
# Training C-index: 0.7166, validation C-index: 0.7611.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.7589, validation C-index: 0.7227.
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# Training C-index: 0.7625, validation C-index: 0.721.
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  247
# Save model of Epoch 48
# Loading model, best epoch: 48.
# Final training C-index: 0.7531, final validation C-index: 0.75.
# Total time elapse: 1.65.
# L2: 0.001, LR: 0.01. dim: 32, dr1: 0.5, dr2: 0.5.
# Training C-index: 0.7531, validation C-index: 0.75.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.7733, validation C-index: 0.7232.
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# Training C-index: 0.7764, validation C-index: 0.744.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7786, validation C-index: 0.7347.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.7761, validation C-index: 0.7462.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  435
# Save model of Epoch 236
# Loading model, best epoch: 236.
# Final training C-index: 0.7755, final validation C-index: 0.7487.
# Total time elapse: 3.41.
# L2: 0.001, LR: 0.0075. dim: 8, dr1: 0.1, dr2: 0.1.
# Training C-index: 0.7755, validation C-index: 0.7487.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7685, validation C-index: 0.6976.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# Training C-index: 0.7714, validation C-index: 0.7142.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# Training C-index: 0.7702, validation C-index: 0.7168.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7738, validation C-index: 0.7147.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training C-index: 0.7744, validation C-index: 0.7219.
# Loading model, best epoch: 306.
# Final training C-index: 0.7687, final validation C-index: 0.7355.
# Total time elapse: 3.21.
# ...
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7682, validation C-index: 0.7445.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.7825, validation C-index: 0.7372.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.7868, validation C-index: 0.7398.
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# Training C-index: 0.7907, validation C-index: 0.7406.
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  462
# Save model of Epoch 263
# Loading model, best epoch: 263.
# Final training C-index: 0.7812, final validation C-index: 0.7624.
# Total time elapse: 3.04.
# L2: 0.00025, LR: 0.0075. dim: 32, dr1: 0.3, dr2: 0.1.
# Training C-index: 0.7812, validation C-index: 0.7624.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.761, validation C-index: 0.7044.
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# Training C-index: 0.7655, validation C-index: 0.7334.
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  246
# Save model of Epoch 47
# Loading model, best epoch: 47.
# Final training C-index: 0.7547, final validation C-index: 0.7436.
# Total time elapse: 2.24.
# L2: 0.00025, LR: 0.0075. dim: 32, dr1: 0.3, dr2: 0.3.
# Training C-index: 0.7547, validation C-index: 0.7436.
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.7565, validation C-index: 0.73.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# Training C-index: 0.758, validation C-index: 0.7083.
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  296
# Save model of Epoch 97
# Loading model, best epoch: 97.
# Final training C-index: 0.7572, final validation C-index: 0.7415.
# Total time elapse: 2.05.
# L2: 0.00025, LR: 0.0075. dim: 32, dr1: 0.3, dr2: 0.5.
# Training C-index: 0.7572, validation C-index: 0.7415.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.7621, validation C-index: 0.7236.
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.7598, validation C-index: 0.7355.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# Training C-index: 0.7678, validation C-index: 0.7287.
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7655, validation C-index: 0.7419.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training C-index: 0.7677, validation C-index: 0.721.
# Loading model, best epoch: 307.
# Final training C-index: 0.7636, final validation C-index: 0.7445.
# Total time elapse: 3.53.
# L2: 0.00025, LR: 0.0075. dim: 32, dr1: 0.5, dr2: 0.1.
# Training C-index: 0.7636, validation C-index: 0.7445.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.7593, validation C-index: 0.7159.
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# Training C-index: 0.7615, validation C-index: 0.7138.
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  249
# Save model of Epoch 50
# Loading model, best epoch: 50.
# Final training C-index: 0.7518, final validation C-index: 0.7513.
# Total time elapse: 1.96.
# L2: 0.00025, LR: 0.0075. dim: 32, dr1: 0.5, dr2: 0.3.
# Training C-index: 0.7518, validation C-index: 0.7513.
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.7628, validation C-index: 0.7232.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.7597, validation C-index: 0.7308.
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# Training C-index: 0.7607, validation C-index: 0.7296.
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  378
# Save model of Epoch 179
# Loading model, best epoch: 179.
# Final training C-index: 0.7578, final validation C-index: 0.7432.
# Total time elapse: 2.89.
# L2: 0.00025, LR: 0.0075. dim: 32, dr1: 0.5, dr2: 0.5.
# Training C-index: 0.7578, validation C-index: 0.7432.
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.7707, validation C-index: 0.7232.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.7813, validation C-index: 0.7428.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.7854, validation C-index: 0.7372.
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.7886, validation C-index: 0.7649.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# Training C-index: 0.7932, validation C-index: 0.7394.
# Loading model, best epoch: 390.
# Final training C-index: 0.7891, final validation C-index: 0.7713.
# Total time elapse: 5.33.
# L2: 0.00025, LR: 0.005. dim: 8, dr1: 0.1, dr2: 0.1.
# Training C-index: 0.7891, validation C-index: 0.7713.
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.7667, validation C-index: 0.7074.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.7695, validation C-index: 0.7074.
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# Training C-index: 0.7695, validation C-index: 0.7066.
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.7756, validation C-index: 0.7325.
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# Training C-index: 0.7711, validation C-index: 0.7364.
# Loading model, best epoch: 498.
# Final training C-index: 0.7711, final validation C-index: 0.744.
# Total time elapse: 4.51.
# L2: 0.00025, LR: 0.005. dim: 8, dr1: 0.1, dr2: 0.3.
# Training C-index: 0.7711, validation C-index: 0.744.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7615, validation C-index: 0.7095.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training C-index: 0.7666, validation C-index: 0.7125.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  203
# Save model of Epoch 4
# Loading model, best epoch: 4.
# Final training C-index: 0.6774, final validation C-index: 0.7402.
# Total time elapse: 1.22.
# L2: 0.00025, LR: 0.005. dim: 8, dr1: 0.1, dr2: 0.5.
# Training C-index: 0.6774, validation C-index: 0.7402.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.7647, validation C-index: 0.7172.
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# Training C-index: 0.7647, validation C-index: 0.7436.
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.765, validation C-index: 0.7313.
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.7693, validation C-index: 0.7368.
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# Training C-index: 0.7694, validation C-index: 0.7317.
# Loading model, best epoch: 352.
# Final training C-index: 0.7656, final validation C-index: 0.7513.
# Total time elapse: 3.99.
# L2: 0.00025, LR: 0.005. dim: 8, dr1: 0.3, dr2: 0.1.
# Training C-index: 0.7656, validation C-index: 0.7513.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# Training C-index: 0.7602, validation C-index: 0.7036.
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# Training C-index: 0.7654, validation C-index: 0.7227.
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  205
# Save model of Epoch 6
# Loading model, best epoch: 6.
# Final training C-index: 0.6907, final validation C-index: 0.7385.
# Total time elapse: 1.32.
# L2: 0.00025, LR: 0.005. dim: 8, dr1: 0.3, dr2: 0.3.
# Training C-index: 0.6907, validation C-index: 0.7385.
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.747, validation C-index: 0.6746.
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.7613, validation C-index: 0.7057.
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# Training C-index: 0.7623, validation C-index: 0.7274.
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  357
# Save model of Epoch 158
# Loading model, best epoch: 158.
# Final training C-index: 0.762, final validation C-index: 0.7359.
# Total time elapse: 3.26.
# L2: 0.00025, LR: 0.005. dim: 8, dr1: 0.3, dr2: 0.5.
# Training C-index: 0.762, validation C-index: 0.7359.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.7602, validation C-index: 0.7347.
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# Training C-index: 0.76, validation C-index: 0.7351.
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  258
# Save model of Epoch 59
# Loading model, best epoch: 59.
# Final training C-index: 0.7449, final validation C-index: 0.7606.
# Total time elapse: 1.94.
# L2: 0.00025, LR: 0.005. dim: 8, dr1: 0.5, dr2: 0.1.
# Training C-index: 0.7449, validation C-index: 0.7606.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.7588, validation C-index: 0.704.
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# Training C-index: 0.761, validation C-index: 0.7304.
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  268
# Save model of Epoch 69
# Loading model, best epoch: 69.
# Final training C-index: 0.7489, final validation C-index: 0.7449.
# Total time elapse: 1.75.
# L2: 0.00025, LR: 0.005. dim: 8, dr1: 0.5, dr2: 0.3.
# Training C-index: 0.7489, validation C-index: 0.7449.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# Training C-index: 0.7543, validation C-index: 0.727.
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# Training C-index: 0.7609, validation C-index: 0.7198.
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  228
# Save model of Epoch 29
# Loading model, best epoch: 29.
# Final training C-index: 0.6833, final validation C-index: 0.7526.
# Total time elapse: 1.59.
# L2: 0.00025, LR: 0.005. dim: 8, dr1: 0.5, dr2: 0.5.
# Training C-index: 0.6833, validation C-index: 0.7526.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.7723, validation C-index: 0.7249.
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.7816, validation C-index: 0.7325.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.8002, validation C-index: 0.753.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# Training C-index: 0.8297, validation C-index: 0.7291.
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  499
# Save model of Epoch 300
# Loading model, best epoch: 300.
# Final training C-index: 0.8002, final validation C-index: 0.753.
# Total time elapse: 3.19.
# L2: 0.00025, LR: 0.005. dim: 16, dr1: 0.1, dr2: 0.1.
# Training C-index: 0.8002, validation C-index: 0.753.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.769, validation C-index: 0.7125.
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 20 out of 200
# Training C-index: 0.7716, validation C-index: 0.7257.
# EarlyStopping counter: 40 out of 200
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200

# %%
print("--- %s seconds ---" % (end_time - start_time))

# %%
#25-30 mins

# %%
train_y_pred, test_y_pred, cindex_train, cindex_test, best_epoch_num_overall = train_LFSurv(x_train_overall, age_train_overall, stage_i_train_overall, stage_ii_train_overall, race_white_train_overall, ytime_train_overall, yevent_train_overall,
                                                                                            x_test_overall, age_test_overall, stage_i_test_overall, stage_ii_test_overall, race_white_test_overall, ytime_test_overall, yevent_test_overall,
                                                                                            input_n, opt_dim, opt_dr1, opt_dr2, opt_lr, opt_l2, epoch_num, patience, dtype,
                                                                                            path = "sup_checkpoint_overall.pt")
print("Optimal L2: %s," %opt_l2, "optimal LR: %s," %opt_lr, "optimal dim: %s," %opt_dim, "optimal dr1: %s," %opt_dr1, "optimal dr2: %s," %opt_dr2, "best epoch number in tuning: %s." %best_epoch_num)
print("Optimal training C-index: %s," %opt_cindex_tr.round(4), "optimal validation C-index: %s." %opt_cindex_va.round(4))
print("Testing phase: training C-index: %s," %cindex_train.round(4), "testing C-index: %s." %cindex_test.round(4))
# Out:
# EarlyStopping counter: 20 out of 200
# EarlyStopping counter: 40 out of 200
# Training C-index: 0.7694, validation C-index: 0.7022.
# EarlyStopping counter: 60 out of 200
# EarlyStopping counter: 80 out of 200
# EarlyStopping counter: 100 out of 200
# EarlyStopping counter: 120 out of 200
# EarlyStopping counter: 140 out of 200
# Training C-index: 0.7771, validation C-index: 0.7062.
# EarlyStopping counter: 160 out of 200
# EarlyStopping counter: 180 out of 200
# EarlyStopping counter: 200 out of 200
# Early stopping, number of epochs:  248
# Save model of Epoch 49
# Loading model, best epoch: 49.
# Final training C-index: 0.7761, final validation C-index: 0.7262.
# Total time elapse: 2.5.
# Optimal L2: 0.0001, optimal LR: 0.05, optimal dim: 8, optimal dr1: 0.5, optimal dr2: 0.3, best epoch number in tuning: 4.
# Optimal training C-index: 0.6987, optimal validation C-index: 0.7841.
# Testing phase: training C-index: 0.7761, testing C-index: 0.7262.
